# %% [markdown]
# <a href="https://colab.research.google.com/github/rounak393/clab/blob/main/mobilenetv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install albumentations scikit-learn torchinfo -q

import os
import math
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import random
import copy

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import albumentations as A
import cv2
import warnings
import torch.nn.functional as F
from torchinfo import summary
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights

warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

BASE_DIR = "/kaggle/input/datasets/britikak/busi-dataset/Dataset_BUSI_with_GT"
CLASSES = ["benign", "malignant"]
IMG_SIZE = 256
BATCH_SIZE = 8
SEED = 42

torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = True

class BUSISegmentationDataset(Dataset):
    def __init__(self, base_dir, classes, transform=None):
        self.samples = []
        self.transform = transform

        for cls in classes:
            cls_dir = os.path.join(base_dir, cls)
            if not os.path.exists(cls_dir):
                continue

            images = [
                f for f in os.listdir(cls_dir)
                if f.endswith(".png") and "_mask" not in f
            ]

            for img_name in images:
                img_path = os.path.join(cls_dir, img_name)
                base_name = img_name.replace(".png", "")

                mask_files = [
                    f for f in os.listdir(cls_dir)
                    if f.startswith(base_name + "_mask") and f.endswith(".png")
                ]

                if len(mask_files) == 0:
                    continue

                mask_paths = [os.path.join(cls_dir, f) for f in mask_files]
                self.samples.append((img_path, mask_paths))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, mask_paths = self.samples[idx]

        image = np.array(Image.open(img_path).convert("RGB"))

        combined_mask = np.zeros(image.shape[:2], dtype=np.uint8)
        for mpath in mask_paths:
            mask = np.array(Image.open(mpath).convert("L"))
            mask = (mask > 0).astype(np.uint8)
            combined_mask = np.logical_or(combined_mask, mask)

        combined_mask = combined_mask.astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=combined_mask)
            image = augmented["image"]
            combined_mask = augmented["mask"]

        # Ensure binary mask (important!)
        combined_mask = (combined_mask > 0.5).astype(np.float32)

        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(combined_mask).unsqueeze(0).float()

        return image, mask

# ===================---------------------=======================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

test_transform = val_transform

# ===================------------------------==================
full_dataset = BUSISegmentationDataset(BASE_DIR, classes=CLASSES, transform=None)
total_size = len(full_dataset)
indices = list(range(total_size))
np.random.seed(SEED)
np.random.shuffle(indices)

train_size = int(0.8 * total_size)
val_size   = int(0.1 * total_size)

val_indices = indices[:val_size]
train_indices   = indices[val_size:train_size + val_size]
test_indices  = indices[train_size + val_size:]

train_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=train_transform),
    train_indices)

val_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=val_transform),
    val_indices)

test_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=test_transform),
    test_indices)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

# ==========================================
# CUSTOM MODULES (PCBAM, SGA)
# ==========================================
class PCBAM_Filter(nn.Module):
    def __init__(self, in_channels, reduction=8):
        super().__init__()
        self.cam = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels)
        )
        self.sam = nn.Conv2d(2, 1, kernel_size=7, padding=3, bias=False)

    def forward(self, x):
        b, c, _, _ = x.size()
        avg = self.cam(F.adaptive_avg_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        mxp = self.cam(F.adaptive_max_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        x_c = x * torch.sigmoid(avg + mxp)

        sp  = torch.cat([
            torch.mean(x_c, dim=1, keepdim=True),
            torch.max(x_c,  dim=1, keepdim=True)[0]
        ], dim=1)
        x_s = x_c * torch.sigmoid(self.sam(sp))
        return x_s

class SpatialGateAttention(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        mid = in_channels // 8
        self.q_conv   = nn.Conv2d(in_channels, mid, 1)
        self.k_conv   = nn.Conv2d(in_channels, mid, 1)
        self.v_conv   = nn.Conv2d(in_channels, in_channels, 1)
        self.gate     = nn.Conv2d(mid * 2 + in_channels, in_channels, 1)

    def forward(self, x):
        q = self.q_conv(x)
        k = self.k_conv(x)
        v = self.v_conv(x)
        A = torch.sigmoid(self.gate(torch.cat([q, k, v], dim=1)))
        return x + v * A

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

# ==========================================
# MOBILENET V2 U-NET ARCHITECTURE
# ==========================================
class MobileNetUNet(nn.Module):
    def __init__(self, n_classes=1):
        super().__init__()

        # --- Encoders (MobileNetV2) ---
        mobilenet = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1).features

        # Slicing MobileNetV2 to extract features at specific spatial resolutions:
        # Input is 256x256
        self.enc0 = nn.Sequential(*mobilenet[0:2])   # outputs 128x128, 16 channels
        self.enc1 = nn.Sequential(*mobilenet[2:4])   # outputs 64x64, 24 channels
        self.enc2 = nn.Sequential(*mobilenet[4:7])   # outputs 32x32, 32 channels
        self.enc3 = nn.Sequential(*mobilenet[7:14])  # outputs 16x16, 96 channels

        # Fix: Extract exactly up to the 320-channel block, avoiding the final 1280 Conv2d
        self.enc4 = nn.Sequential(*mobilenet[14:18]) # outputs 8x8, 320 channels

        # --- Skip Connection Filters ---
        self.pcbam1 = PCBAM_Filter(24)
        self.pcbam2 = PCBAM_Filter(32)
        self.pcbam3 = PCBAM_Filter(96)
        self.pcbam4 = PCBAM_Filter(320)

        # --- Bottleneck ---
        self.pool       = nn.MaxPool2d(2) # 8x8 -> 4x4
        self.bottleneck = DoubleConv(320, 1024)
        self.sga        = SpatialGateAttention(1024)

        # --- Decoder ---
        # Decoder 4: Up from 1024 (4x4) to 512 (8x8), concat with s4 (320)
        self.up4  = nn.ConvTranspose2d(1024, 512, 2, stride=2)
        self.dec4 = DoubleConv(512 + 320, 512)

        # Decoder 3: Up from 512 (8x8) to 256 (16x16), concat with s3 (96)
        self.up3  = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec3 = DoubleConv(256 + 96, 256)

        # Decoder 2: Up from 256 (16x16) to 128 (32x32), concat with s2 (32)
        self.up2  = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec2 = DoubleConv(128 + 32, 128)

        # Decoder 1: Up from 128 (32x32) to 64 (64x64), concat with s1 (24)
        self.up1  = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec1 = DoubleConv(64 + 24, 64)

        # Decoder 0: Up from 64 (64x64) to 64 (128x128), concat with x0 (16)
        self.up0  = nn.ConvTranspose2d(64, 64, 2, stride=2)
        self.dec0 = DoubleConv(64 + 16, 64)

        # Final Output: Up from 64 (128x128) to 32 (256x256)
        self.up_out  = nn.ConvTranspose2d(64, 32, 2, stride=2)
        self.dec_out = DoubleConv(32, 32)

        self.final   = nn.Conv2d(32, n_classes, 1)

    def forward(self, x):
        # 1. MobileNet Encoder
        x0 = self.enc0(x)  # 128x128, 16c
        e1 = self.enc1(x0) # 64x64, 24c
        e2 = self.enc2(e1) # 32x32, 32c
        e3 = self.enc3(e2) # 16x16, 96c
        e4 = self.enc4(e3) # 8x8, 320c

        # 2. Skip connections through PCBAM
        s1 = self.pcbam1(e1)
        s2 = self.pcbam2(e2)
        s3 = self.pcbam3(e3)
        s4 = self.pcbam4(e4)

        # 3. Bottleneck with SGA
        b = self.sga(self.bottleneck(self.pool(e4)))

        # 4. Decoder
        d4 = self.dec4(torch.cat([self.up4(b),  s4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), s3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), s2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), s1], dim=1))
        d0 = self.dec0(torch.cat([self.up0(d1), x0], dim=1))
        out = self.dec_out(self.up_out(d0))

        # RETURNS RAW LOGITS (Required for HybridLoss)
        return self.final(out)

# ==========================================
# HYBRID LOSS & METRICS
# ==========================================
class HybridLoss(nn.Module):
    def __init__(self, smooth=1.0, focal_gamma=2.0):
        super().__init__()
        self.smooth      = smooth
        self.focal_gamma = focal_gamma

    def forward(self, logits, targets):
        bce   = F.binary_cross_entropy_with_logits(logits, targets)
        probs = torch.sigmoid(logits).view(-1)
        tgt   = targets.view(-1)
        inter = (probs * tgt).sum()
        dice  = 1.0 - (2.0 * inter + self.smooth) / (probs.sum() + tgt.sum() + self.smooth)
        pt    = torch.where(tgt == 1, probs, 1.0 - probs)
        focal = (-(1.0 - pt) ** self.focal_gamma * torch.log(pt + 1e-8)).mean()
        return 0.4 * bce + 0.4 * dice + 0.2 * focal

# Dice Metric
def dice_coef(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    inter = (y_true_f * y_pred_f).sum()
    return (2. * inter + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

# IoU Metric
def iou_score(preds, masks, threshold=0.5, eps=1e-6):
    preds_bin = (preds > threshold).float()
    masks_bin = (masks > threshold).float()

    inter = (preds_bin * masks_bin).sum().item()
    union = preds_bin.sum().item() + masks_bin.sum().item() - inter

    return inter / (union + eps)

# ==========================================
# TRAINING FUNCTION
# ==========================================
def train_model(model, train_loader, val_loader, epochs=50):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)

    criterion = HybridLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',          # because we monitor val_loss
        factor=0.5,          # reduce LR by half
        patience=10,         # wait 10 epochs before reducing,
        min_lr=1e-6
    )

    train_losses, val_losses = [], []
    train_dice_scores, val_dice_scores = [], []
    train_iou_scores, val_iou_scores = [], []

    best_val_loss = float("inf")
    best_epoch = 0
    best_model_weights = None

    for epoch in range(epochs):
        model.train()
        train_loss = train_dice = train_iou = 0
        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs} [Train]"):
            images, masks = images.to(device), masks.to(device)

            # Outputs Logits
            preds_logits = model(images)
            loss = criterion(preds_logits, masks)

            optimizer.zero_grad()
            loss.backward()

            # Gradient clipping to prevent inf loss
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

            # Convert logits to probabilities for metric calculation
            preds_probs = torch.sigmoid(preds_logits)

            train_loss += loss.item()
            train_dice += dice_coef(masks, preds_probs).item()
            train_iou += iou_score(preds_probs, masks)

        # ------------------ VALIDATION ------------------
        model.eval()
        val_loss = val_dice = val_iou = 0

        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc=f"Epoch {epoch+1}/{epochs} [Val]"):
                images, masks = images.to(device), masks.to(device)

                preds_logits = model(images)
                loss = criterion(preds_logits, masks)

                preds_probs = torch.sigmoid(preds_logits)

                val_loss += loss.item()
                val_dice += dice_coef(masks, preds_probs).item()
                val_iou += iou_score(preds_probs, masks)

        # ------------------ AVERAGES ------------------
        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        avg_train_dice = train_dice / len(train_loader)
        avg_val_dice   = val_dice / len(val_loader)
        avg_train_iou  = train_iou / len(train_loader)
        avg_val_iou    = val_iou / len(val_loader)

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_dice_scores.append(avg_train_dice)
        val_dice_scores.append(avg_val_dice)
        train_iou_scores.append(avg_train_iou)
        val_iou_scores.append(avg_val_iou)

        # ------------------ PRINT ------------------
        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
        print(f"Train Dice: {avg_train_dice:.4f} | Val Dice: {avg_val_dice:.4f}")
        print(f"Train IoU : {avg_train_iou:.4f} | Val IoU : {avg_val_iou:.4f}")

        # ------------------ SAVE BEST ------------------
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch + 1
            best_model_weights = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), "best_mobilenet_unet.pth")
            print(f"✓ Best model saved (Epoch {epoch+1}, Val Loss {best_val_loss:.4f})")

        scheduler.step(avg_val_loss)

    # ------------------ LOAD BEST MODEL ------------------
    model.load_state_dict(best_model_weights)

    print("\n" + "="*60)
    print("Training Completed!")
    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val Loss: {best_val_loss:.4f}")
    print("="*60)

    return {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "train_dice": train_dice_scores,
        "val_dice": val_dice_scores,
        "train_iou": train_iou_scores,
        "val_iou": val_iou_scores,
    }

def plot_training(history):
    plt.figure(figsize=(17, 4))

    # Loss
    plt.subplot(1, 3, 1)
    plt.plot(history["train_losses"], label="Train Loss", linewidth=2)
    plt.plot(history["val_losses"], label="Val Loss", linewidth=2)
    plt.title("Loss Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Dice
    plt.subplot(1, 3, 2)
    plt.plot(history["train_dice"], label="Train Dice", linewidth=2)
    plt.plot(history["val_dice"], label="Val Dice", linewidth=2)
    plt.title("Dice Coefficient Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(history["train_iou"], label="Train IoU", linewidth=2)
    plt.plot(history["val_iou"], label="Val IoU", linewidth=2)
    plt.title("IoU Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("IoU Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=300, bbox_inches='tight')
    plt.show()

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    model = MobileNetUNet()
    model = model.to(device)

    print("\n================= MODEL SUMMARY =================\n")
    print(summary(model, input_size=(BATCH_SIZE, 3, IMG_SIZE, IMG_SIZE)))

    history = train_model(model, train_loader, val_loader, epochs=100)
    plot_training(history)

    def iou_coef(y_true, y_pred, smooth=1e-5):
        y_true_f = y_true.view(-1)
        y_pred_f = y_pred.view(-1)
        intersection = (y_true_f * y_pred_f).sum()
        union = y_true_f.sum() + y_pred_f.sum() - intersection
        return (intersection + smooth) / (union + smooth)

    print("Loading best model...")
    model.load_state_dict(torch.load("best_mobilenet_unet.pth", map_location=device))
    model.eval()

    test_dice, test_iou = 0, 0
    print("Evaluating on test set...")
    with torch.no_grad():
        for images, masks in tqdm(test_loader, desc="Evaluating Test Set"):
            images, masks = images.to(device), masks.to(device)

            # Use SIGMOID for raw logits output
            preds_probs = torch.sigmoid(model(images))
            preds_bin = (preds_probs > 0.4).float()

            test_dice += dice_coef(masks, preds_bin).item()
            test_iou += iou_coef(masks, preds_bin).item()

    num_batches = len(test_loader)
    avg_test_dice = test_dice / num_batches
    avg_test_iou = test_iou / num_batches

    print("\n" + "="*40)
    print("TEST SET EVALUATION")
    print("="*40)
    print(f"Dice Coefficient: {avg_test_dice:.4f}")
    print(f"IoU (Jaccard):    {avg_test_iou:.4f}")
    print("="*40)

    def dice_coef_single(y_true, y_pred, smooth=1e-5):
        y_true_f = y_true.flatten()
        y_pred_f = y_pred.flatten()
        intersection = np.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

    def iou_coef_single(y_true, y_pred, smooth=1e-5):
        intersection = np.sum(y_true * y_pred)
        union = np.sum(y_true) + np.sum(y_pred) - intersection
        return intersection / (union + smooth)

    def visualize_predictions_simple(model, dataset, num_samples=5, threshold=0.5):
        indices = random.sample(range(len(dataset)), num_samples)
        fig, axes = plt.subplots(num_samples, 4, figsize=(16, num_samples * 4))

        if num_samples == 1:
            axes = axes.reshape(1, -1)

        for i, idx in enumerate(indices):
            image, mask = dataset[idx]

            with torch.no_grad():
                pred_prob = torch.sigmoid(model(image.unsqueeze(0).to(device))).cpu().squeeze().numpy()

            pred_mask = (pred_prob > threshold).astype(np.uint8)
            true_mask = mask.squeeze().numpy().astype(np.uint8)

            dice_score = dice_coef_single(true_mask, pred_mask) * 100
            iou_score = iou_coef_single(true_mask, pred_mask) * 100

            error_map = np.zeros((*true_mask.shape, 3), dtype=np.uint8)
            true_positive = (true_mask == 1) & (pred_mask == 1)
            false_positive = (true_mask == 0) & (pred_mask == 1)
            false_negative = (true_mask == 1) & (pred_mask == 0)

            error_map[true_positive] = [255, 255, 255]
            error_map[false_positive] = [255, 0, 0]
            error_map[false_negative] = [0, 0, 255]

            axes[i, 0].imshow(image.permute(1, 2, 0) if image.shape[0] == 3 else image.squeeze(), cmap='gray')
            axes[i, 0].set_title(f"Input Image {idx}")
            axes[i, 0].axis("off")

            axes[i, 1].imshow(true_mask, cmap="gray")
            axes[i, 1].set_title("Ground Truth")
            axes[i, 1].axis("off")

            axes[i, 2].imshow(pred_mask, cmap="gray")
            axes[i, 2].set_title(f"Prediction\nDice: {dice_score:.1f}% | IoU: {iou_score:.1f}%")
            axes[i, 2].axis("off")

            axes[i, 3].imshow(error_map)
            axes[i, 3].set_title("Error Analysis\n(Red: FP, Blue: FN)")
            axes[i, 3].axis("off")

            if i == 0:
                from matplotlib.patches import Patch
                legend_elements = [
                    Patch(facecolor='white', label='True Positive'),
                    Patch(facecolor='red', label='False Positive'),
                    Patch(facecolor='blue', label='False Negative')
                ]
                axes[i, 3].legend(handles=legend_elements, loc='upper right', fontsize=8)

        plt.tight_layout()
        plt.show()

        return indices

    print("\nGenerating visualizations...")
    sampled_indices = visualize_predictions_simple(model, test_dataset, num_samples=7)
    print("\nEvaluation completed successfully!")
# Out:
# Using device: cuda
#
# ================= MODEL SUMMARY =================
#
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# MobileNetUNet                                      [8, 1, 256, 256]          --
# ├─Sequential: 1-1                                  [8, 16, 128, 128]         --
# │    └─Conv2dNormActivation: 2-1                   [8, 32, 128, 128]         --
# │    │    └─Conv2d: 3-1                            [8, 32, 128, 128]         864
# │    │    └─BatchNorm2d: 3-2                       [8, 32, 128, 128]         64
# │    │    └─ReLU6: 3-3                             [8, 32, 128, 128]         --
# │    └─InvertedResidual: 2-2                       [8, 16, 128, 128]         --
# │    │    └─Sequential: 3-4                        [8, 16, 128, 128]         896
# ├─Sequential: 1-2                                  [8, 24, 64, 64]           --
# │    └─InvertedResidual: 2-3                       [8, 24, 64, 64]           --
# │    │    └─Sequential: 3-5                        [8, 24, 64, 64]           5,136
# │    └─InvertedResidual: 2-4                       [8, 24, 64, 64]           --
# │    │    └─Sequential: 3-6                        [8, 24, 64, 64]           8,832
# ├─Sequential: 1-3                                  [8, 32, 32, 32]           --
# │    └─InvertedResidual: 2-5                       [8, 32, 32, 32]           --
# │    │    └─Sequential: 3-7                        [8, 32, 32, 32]           10,000
# │    └─InvertedResidual: 2-6                       [8, 32, 32, 32]           --
# │    │    └─Sequential: 3-8                        [8, 32, 32, 32]           14,848
# │    └─InvertedResidual: 2-7                       [8, 32, 32, 32]           --
# │    │    └─Sequential: 3-9                        [8, 32, 32, 32]           14,848
# ├─Sequential: 1-4                                  [8, 96, 16, 16]           --
# │    └─InvertedResidual: 2-8                       [8, 64, 16, 16]           --
# │    │    └─Sequential: 3-10                       [8, 64, 16, 16]           21,056
# │    └─InvertedResidual: 2-9                       [8, 64, 16, 16]           --
# │    │    └─Sequential: 3-11                       [8, 64, 16, 16]           54,272
# │    └─InvertedResidual: 2-10                      [8, 64, 16, 16]           --
# │    │    └─Sequential: 3-12                       [8, 64, 16, 16]           54,272
# │    └─InvertedResidual: 2-11                      [8, 64, 16, 16]           --
# │    │    └─Sequential: 3-13                       [8, 64, 16, 16]           54,272
# │    └─InvertedResidual: 2-12                      [8, 96, 16, 16]           --
# │    │    └─Sequential: 3-14                       [8, 96, 16, 16]           66,624
# │    └─InvertedResidual: 2-13                      [8, 96, 16, 16]           --
# │    │    └─Sequential: 3-15                       [8, 96, 16, 16]           118,272
# │    └─InvertedResidual: 2-14                      [8, 96, 16, 16]           --
# │    │    └─Sequential: 3-16                       [8, 96, 16, 16]           118,272
# ├─Sequential: 1-5                                  [8, 320, 8, 8]            --
# │    └─InvertedResidual: 2-15                      [8, 160, 8, 8]            --
# │    │    └─Sequential: 3-17                       [8, 160, 8, 8]            155,264
# │    └─InvertedResidual: 2-16                      [8, 160, 8, 8]            --
# │    │    └─Sequential: 3-18                       [8, 160, 8, 8]            320,000
# │    └─InvertedResidual: 2-17                      [8, 160, 8, 8]            --
# │    │    └─Sequential: 3-19                       [8, 160, 8, 8]            320,000
# │    └─InvertedResidual: 2-18                      [8, 320, 8, 8]            --
# │    │    └─Sequential: 3-20                       [8, 320, 8, 8]            473,920
# ├─PCBAM_Filter: 1-6                                [8, 24, 64, 64]           --
# │    └─Sequential: 2-19                            [8, 24]                   --
# │    │    └─Linear: 3-21                           [8, 3]                    75
# │    │    └─ReLU: 3-22                             [8, 3]                    --
# │    │    └─Linear: 3-23                           [8, 24]                   96
# │    └─Sequential: 2-20                            [8, 24]                   (recursive)
# │    │    └─Linear: 3-24                           [8, 3]                    (recursive)
# │    │    └─ReLU: 3-25                             [8, 3]                    --
# │    │    └─Linear: 3-26                           [8, 24]                   (recursive)
# │    └─Conv2d: 2-21                                [8, 1, 64, 64]            98
# ├─PCBAM_Filter: 1-7                                [8, 32, 32, 32]           --
# │    └─Sequential: 2-22                            [8, 32]                   --
# │    │    └─Linear: 3-27                           [8, 4]                    132
# │    │    └─ReLU: 3-28                             [8, 4]                    --
# │    │    └─Linear: 3-29                           [8, 32]                   160
# │    └─Sequential: 2-23                            [8, 32]                   (recursive)
# │    │    └─Linear: 3-30                           [8, 4]                    (recursive)
# │    │    └─ReLU: 3-31                             [8, 4]                    --
# │    │    └─Linear: 3-32                           [8, 32]                   (recursive)
# │    └─Conv2d: 2-24                                [8, 1, 32, 32]            98
# ├─PCBAM_Filter: 1-8                                [8, 96, 16, 16]           --
# │    └─Sequential: 2-25                            [8, 96]                   --
# │    │    └─Linear: 3-33                           [8, 12]                   1,164
# │    │    └─ReLU: 3-34                             [8, 12]                   --
# │    │    └─Linear: 3-35                           [8, 96]                   1,248
# │    └─Sequential: 2-26                            [8, 96]                   (recursive)
# │    │    └─Linear: 3-36                           [8, 12]                   (recursive)
# │    │    └─ReLU: 3-37                             [8, 12]                   --
# │    │    └─Linear: 3-38                           [8, 96]                   (recursive)
# │    └─Conv2d: 2-27                                [8, 1, 16, 16]            98
# ├─PCBAM_Filter: 1-9                                [8, 320, 8, 8]            --
# │    └─Sequential: 2-28                            [8, 320]                  --
# │    │    └─Linear: 3-39                           [8, 40]                   12,840
# │    │    └─ReLU: 3-40                             [8, 40]                   --
# │    │    └─Linear: 3-41                           [8, 320]                  13,120
# │    └─Sequential: 2-29                            [8, 320]                  (recursive)
# │    │    └─Linear: 3-42                           [8, 40]                   (recursive)
# │    │    └─ReLU: 3-43                             [8, 40]                   --
# │    │    └─Linear: 3-44                           [8, 320]                  (recursive)
# │    └─Conv2d: 2-30                                [8, 1, 8, 8]              98
# ├─MaxPool2d: 1-10                                  [8, 320, 4, 4]            --
# ├─DoubleConv: 1-11                                 [8, 1024, 4, 4]           --
# │    └─Sequential: 2-31                            [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-45                           [8, 1024, 4, 4]           2,949,120
# │    │    └─BatchNorm2d: 3-46                      [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-47                             [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-48                           [8, 1024, 4, 4]           9,437,184
# │    │    └─BatchNorm2d: 3-49                      [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-50                             [8, 1024, 4, 4]           --
# ├─SpatialGateAttention: 1-12                       [8, 1024, 4, 4]           --
# │    └─Conv2d: 2-32                                [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-33                                [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-34                                [8, 1024, 4, 4]           1,049,600
# │    └─Conv2d: 2-35                                [8, 1024, 4, 4]           1,311,744
# ├─ConvTranspose2d: 1-13                            [8, 512, 8, 8]            2,097,664
# ├─DoubleConv: 1-14                                 [8, 512, 8, 8]            --
# │    └─Sequential: 2-36                            [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-51                           [8, 512, 8, 8]            3,833,856
# │    │    └─BatchNorm2d: 3-52                      [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-53                             [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-54                           [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-55                      [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-56                             [8, 512, 8, 8]            --
# ├─ConvTranspose2d: 1-15                            [8, 256, 16, 16]          524,544
# ├─DoubleConv: 1-16                                 [8, 256, 16, 16]          --
# │    └─Sequential: 2-37                            [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-57                           [8, 256, 16, 16]          811,008
# │    │    └─BatchNorm2d: 3-58                      [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-59                             [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-60                           [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-61                      [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-62                             [8, 256, 16, 16]          --
# ├─ConvTranspose2d: 1-17                            [8, 128, 32, 32]          131,200
# ├─DoubleConv: 1-18                                 [8, 128, 32, 32]          --
# │    └─Sequential: 2-38                            [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-63                           [8, 128, 32, 32]          184,320
# │    │    └─BatchNorm2d: 3-64                      [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-65                             [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-66                           [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-67                      [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-68                             [8, 128, 32, 32]          --
# ├─ConvTranspose2d: 1-19                            [8, 64, 64, 64]           32,832
# ├─DoubleConv: 1-20                                 [8, 64, 64, 64]           --
# │    └─Sequential: 2-39                            [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-69                           [8, 64, 64, 64]           50,688
# │    │    └─BatchNorm2d: 3-70                      [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-71                             [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-72                           [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-73                      [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-74                             [8, 64, 64, 64]           --
# ├─ConvTranspose2d: 1-21                            [8, 64, 128, 128]         16,448
# ├─DoubleConv: 1-22                                 [8, 64, 128, 128]         --
# │    └─Sequential: 2-40                            [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-75                           [8, 64, 128, 128]         46,080
# │    │    └─BatchNorm2d: 3-76                      [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-77                             [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-78                           [8, 64, 128, 128]         36,864
# │    │    └─BatchNorm2d: 3-79                      [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-80                             [8, 64, 128, 128]         --
# ├─ConvTranspose2d: 1-23                            [8, 32, 256, 256]         8,224
# ├─DoubleConv: 1-24                                 [8, 32, 256, 256]         --
# │    └─Sequential: 2-41                            [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-81                           [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-82                      [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-83                             [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-84                           [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-85                      [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-86                             [8, 32, 256, 256]         --
# ├─Conv2d: 1-25                                     [8, 1, 256, 256]          33
# ====================================================================================================
# Total params: 27,784,940
# Trainable params: 27,784,940
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 47.79
# ====================================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 2281.07
# Params size (MB): 111.14
# Estimated Total Size (MB): 2398.50
# ====================================================================================================
# Epoch 1/100 [Train]: 100%|██████████| 65/65 [00:21<00:00,  2.98it/s]
# Epoch 1/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.92it/s]
# Epoch 1/100
# Train Loss: 0.5750 | Val Loss: 0.4927
# Train Dice: 0.2014 | Val Dice: 0.2417
# Train IoU : 0.2386 | Val IoU : 0.4453
# ✓ Best model saved (Epoch 1, Val Loss 0.4927)
# Epoch 2/100 [Train]: 100%|██████████| 65/65 [00:09<00:00,  6.65it/s]
# Epoch 2/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.27it/s]
# Epoch 2/100
# Train Loss: 0.4714 | Val Loss: 0.5094
# Train Dice: 0.2786 | Val Dice: 0.3076
# Train IoU : 0.4469 | Val IoU : 0.4260
# Epoch 3/100 [Train]: 100%|██████████| 65/65 [00:09<00:00,  6.59it/s]
# Epoch 3/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.59it/s]
# Epoch 3/100
# Train Loss: 0.4308 | Val Loss: 0.4576
# Train Dice: 0.3224 | Val Dice: 0.3072
# Train IoU : 0.5258 | Val IoU : 0.4469
# ✓ Best model saved (Epoch 3, Val Loss 0.4576)
# Epoch 4/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.45it/s]
# Epoch 4/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.24it/s]
# Epoch 4/100
# Train Loss: 0.4128 | Val Loss: 0.4206
# Train Dice: 0.3376 | Val Dice: 0.3274
# Train IoU : 0.5453 | Val IoU : 0.5405
# ✓ Best model saved (Epoch 4, Val Loss 0.4206)
# Epoch 5/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 5/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.52it/s]
# Epoch 5/100
# Train Loss: 0.3965 | Val Loss: 0.3971
# Train Dice: 0.3571 | Val Dice: 0.3478
# Train IoU : 0.5757 | Val IoU : 0.5755
# ✓ Best model saved (Epoch 5, Val Loss 0.3971)
# Epoch 6/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.16it/s]
# Epoch 6/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.70it/s]
# Epoch 6/100
# Train Loss: 0.3815 | Val Loss: 0.3950
# Train Dice: 0.3726 | Val Dice: 0.3536
# Train IoU : 0.5920 | Val IoU : 0.5707
# ✓ Best model saved (Epoch 6, Val Loss 0.3950)
# Epoch 7/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.07it/s]
# Epoch 7/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.78it/s]
# Epoch 7/100
# Train Loss: 0.3716 | Val Loss: 0.3943
# Train Dice: 0.3836 | Val Dice: 0.3633
# Train IoU : 0.5973 | Val IoU : 0.5626
# ✓ Best model saved (Epoch 7, Val Loss 0.3943)
# Epoch 8/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.17it/s]
# Epoch 8/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.05it/s]
# Epoch 8/100
# Train Loss: 0.3625 | Val Loss: 0.3807
# Train Dice: 0.3939 | Val Dice: 0.3568
# Train IoU : 0.6021 | Val IoU : 0.5608
# ✓ Best model saved (Epoch 8, Val Loss 0.3807)
# Epoch 9/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 9/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.33it/s]
# Epoch 9/100
# Train Loss: 0.3490 | Val Loss: 0.3821
# Train Dice: 0.4090 | Val Dice: 0.3754
# Train IoU : 0.6177 | Val IoU : 0.5634
# Epoch 10/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.37it/s]
# Epoch 10/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.04it/s]
# Epoch 10/100
# Train Loss: 0.3336 | Val Loss: 0.3558
# Train Dice: 0.4305 | Val Dice: 0.3840
# Train IoU : 0.6470 | Val IoU : 0.5773
# ✓ Best model saved (Epoch 10, Val Loss 0.3558)
# Epoch 11/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.41it/s]
# Epoch 11/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.06it/s]
# Epoch 11/100
# Train Loss: 0.3213 | Val Loss: 0.3453
# Train Dice: 0.4453 | Val Dice: 0.4173
# Train IoU : 0.6563 | Val IoU : 0.6033
# ✓ Best model saved (Epoch 11, Val Loss 0.3453)
# Epoch 12/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.39it/s]
# Epoch 12/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 13.08it/s]
# Epoch 12/100
# Train Loss: 0.3188 | Val Loss: 0.3485
# Train Dice: 0.4500 | Val Dice: 0.3969
# Train IoU : 0.6381 | Val IoU : 0.5717
# Epoch 13/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# Epoch 13/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.67it/s]
# Epoch 13/100
# Train Loss: 0.3073 | Val Loss: 0.3404
# Train Dice: 0.4662 | Val Dice: 0.4174
# Train IoU : 0.6577 | Val IoU : 0.5750
# ✓ Best model saved (Epoch 13, Val Loss 0.3404)
# Epoch 14/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 14/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.76it/s]
# Epoch 14/100
# Train Loss: 0.2968 | Val Loss: 0.3199
# Train Dice: 0.4778 | Val Dice: 0.4387
# Train IoU : 0.6706 | Val IoU : 0.5932
# ✓ Best model saved (Epoch 14, Val Loss 0.3199)
# Epoch 15/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.26it/s]
# Epoch 15/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.74it/s]
# Epoch 15/100
# Train Loss: 0.2816 | Val Loss: 0.3078
# Train Dice: 0.5022 | Val Dice: 0.4671
# Train IoU : 0.6846 | Val IoU : 0.6175
# ✓ Best model saved (Epoch 15, Val Loss 0.3078)
# Epoch 16/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.28it/s]
# Epoch 16/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.18it/s]
# Epoch 16/100
# Train Loss: 0.2777 | Val Loss: 0.3320
# Train Dice: 0.5091 | Val Dice: 0.4703
# Train IoU : 0.6805 | Val IoU : 0.5898
# Epoch 17/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 17/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 13.14it/s]
# Epoch 17/100
# Train Loss: 0.2657 | Val Loss: 0.3121
# Train Dice: 0.5248 | Val Dice: 0.4745
# Train IoU : 0.6946 | Val IoU : 0.5911
# Epoch 18/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# Epoch 18/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.01it/s]
# Epoch 18/100
# Train Loss: 0.2512 | Val Loss: 0.2913
# Train Dice: 0.5489 | Val Dice: 0.4946
# Train IoU : 0.7156 | Val IoU : 0.6159
# ✓ Best model saved (Epoch 18, Val Loss 0.2913)
# Epoch 19/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 19/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.30it/s]
# Epoch 19/100
# Train Loss: 0.2555 | Val Loss: 0.3070
# Train Dice: 0.5417 | Val Dice: 0.4930
# Train IoU : 0.6973 | Val IoU : 0.5762
# Epoch 20/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# Epoch 20/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.54it/s]
# Epoch 20/100
# Train Loss: 0.2430 | Val Loss: 0.2948
# Train Dice: 0.5614 | Val Dice: 0.5047
# Train IoU : 0.7029 | Val IoU : 0.5983
# Epoch 21/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.35it/s]
# Epoch 21/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.30it/s]
# Epoch 21/100
# Train Loss: 0.2366 | Val Loss: 0.2893
# Train Dice: 0.5742 | Val Dice: 0.5193
# Train IoU : 0.7067 | Val IoU : 0.6008
# ✓ Best model saved (Epoch 21, Val Loss 0.2893)
# Epoch 22/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.33it/s]
# Epoch 22/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.99it/s]
# Epoch 22/100
# Train Loss: 0.2238 | Val Loss: 0.2776
# Train Dice: 0.5951 | Val Dice: 0.5426
# Train IoU : 0.7243 | Val IoU : 0.6064
# ✓ Best model saved (Epoch 22, Val Loss 0.2776)
# Epoch 23/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.33it/s]
# Epoch 23/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.38it/s]
# Epoch 23/100
# Train Loss: 0.2238 | Val Loss: 0.2706
# Train Dice: 0.5930 | Val Dice: 0.5493
# Train IoU : 0.7197 | Val IoU : 0.6157
# ✓ Best model saved (Epoch 23, Val Loss 0.2706)
# Epoch 24/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 24/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.28it/s]
# Epoch 24/100
# Train Loss: 0.2132 | Val Loss: 0.2710
# Train Dice: 0.6120 | Val Dice: 0.5474
# Train IoU : 0.7342 | Val IoU : 0.5867
# Epoch 25/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 25/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.59it/s]
# Epoch 25/100
# Train Loss: 0.2020 | Val Loss: 0.2459
# Train Dice: 0.6325 | Val Dice: 0.5727
# Train IoU : 0.7462 | Val IoU : 0.6267
# ✓ Best model saved (Epoch 25, Val Loss 0.2459)
# Epoch 26/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 26/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.82it/s]
# Epoch 26/100
# Train Loss: 0.2006 | Val Loss: 0.2621
# Train Dice: 0.6395 | Val Dice: 0.5781
# Train IoU : 0.7360 | Val IoU : 0.6357
# Epoch 27/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 27/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.17it/s]
# Epoch 27/100
# Train Loss: 0.1858 | Val Loss: 0.2536
# Train Dice: 0.6604 | Val Dice: 0.5815
# Train IoU : 0.7611 | Val IoU : 0.6191
# Epoch 28/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.35it/s]
# Epoch 28/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.00it/s]
# Epoch 28/100
# Train Loss: 0.1888 | Val Loss: 0.2304
# Train Dice: 0.6593 | Val Dice: 0.5973
# Train IoU : 0.7490 | Val IoU : 0.6508
# ✓ Best model saved (Epoch 28, Val Loss 0.2304)
# Epoch 29/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 29/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.63it/s]
# Epoch 29/100
# Train Loss: 0.1798 | Val Loss: 0.2322
# Train Dice: 0.6764 | Val Dice: 0.5938
# Train IoU : 0.7569 | Val IoU : 0.6168
# Epoch 30/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 30/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.99it/s]
# Epoch 30/100
# Train Loss: 0.1739 | Val Loss: 0.2333
# Train Dice: 0.6838 | Val Dice: 0.6010
# Train IoU : 0.7616 | Val IoU : 0.6143
# Epoch 31/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 31/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.93it/s]
# Epoch 31/100
# Train Loss: 0.1697 | Val Loss: 0.2436
# Train Dice: 0.6926 | Val Dice: 0.5955
# Train IoU : 0.7654 | Val IoU : 0.5925
# Epoch 32/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 32/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.83it/s]
# Epoch 32/100
# Train Loss: 0.1683 | Val Loss: 0.2271
# Train Dice: 0.6978 | Val Dice: 0.6185
# Train IoU : 0.7581 | Val IoU : 0.6050
# ✓ Best model saved (Epoch 32, Val Loss 0.2271)
# Epoch 33/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 33/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.81it/s]
# Epoch 33/100
# Train Loss: 0.1616 | Val Loss: 0.2276
# Train Dice: 0.7082 | Val Dice: 0.6225
# Train IoU : 0.7646 | Val IoU : 0.6247
# Epoch 34/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 34/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.59it/s]
# Epoch 34/100
# Train Loss: 0.1555 | Val Loss: 0.2387
# Train Dice: 0.7204 | Val Dice: 0.6161
# Train IoU : 0.7755 | Val IoU : 0.6133
# Epoch 35/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 35/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.23it/s]
# Epoch 35/100
# Train Loss: 0.1558 | Val Loss: 0.2139
# Train Dice: 0.7221 | Val Dice: 0.6435
# Train IoU : 0.7626 | Val IoU : 0.6344
# ✓ Best model saved (Epoch 35, Val Loss 0.2139)
# Epoch 36/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 36/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.39it/s]
# Epoch 36/100
# Train Loss: 0.1492 | Val Loss: 0.2013
# Train Dice: 0.7336 | Val Dice: 0.6578
# Train IoU : 0.7821 | Val IoU : 0.6490
# ✓ Best model saved (Epoch 36, Val Loss 0.2013)
# Epoch 37/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 37/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.64it/s]
# Epoch 37/100
# Train Loss: 0.1412 | Val Loss: 0.2291
# Train Dice: 0.7449 | Val Dice: 0.6477
# Train IoU : 0.7773 | Val IoU : 0.6283
# Epoch 38/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 38/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.06it/s]
# Epoch 38/100
# Train Loss: 0.1425 | Val Loss: 0.2174
# Train Dice: 0.7458 | Val Dice: 0.6515
# Train IoU : 0.7752 | Val IoU : 0.6255
# Epoch 39/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 39/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.13it/s]
# Epoch 39/100
# Train Loss: 0.1400 | Val Loss: 0.2058
# Train Dice: 0.7540 | Val Dice: 0.6663
# Train IoU : 0.7833 | Val IoU : 0.6441
# Epoch 40/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 40/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.67it/s]
# Epoch 40/100
# Train Loss: 0.1372 | Val Loss: 0.2228
# Train Dice: 0.7555 | Val Dice: 0.6494
# Train IoU : 0.7819 | Val IoU : 0.6140
# Epoch 41/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 41/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.05it/s]
# Epoch 41/100
# Train Loss: 0.1274 | Val Loss: 0.2093
# Train Dice: 0.7747 | Val Dice: 0.6617
# Train IoU : 0.7918 | Val IoU : 0.6320
# Epoch 42/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 42/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.04it/s]
# Epoch 42/100
# Train Loss: 0.1281 | Val Loss: 0.1958
# Train Dice: 0.7740 | Val Dice: 0.6788
# Train IoU : 0.7888 | Val IoU : 0.6467
# ✓ Best model saved (Epoch 42, Val Loss 0.1958)
# Epoch 43/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 43/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.48it/s]
# Epoch 43/100
# Train Loss: 0.1288 | Val Loss: 0.2070
# Train Dice: 0.7740 | Val Dice: 0.6770
# Train IoU : 0.7869 | Val IoU : 0.6309
# Epoch 44/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.28it/s]
# Epoch 44/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.77it/s]
# Epoch 44/100
# Train Loss: 0.1248 | Val Loss: 0.2429
# Train Dice: 0.7776 | Val Dice: 0.6517
# Train IoU : 0.7927 | Val IoU : 0.5867
# Epoch 45/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 45/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.70it/s]
# Epoch 45/100
# Train Loss: 0.1206 | Val Loss: 0.1929
# Train Dice: 0.7925 | Val Dice: 0.6955
# Train IoU : 0.7977 | Val IoU : 0.6404
# ✓ Best model saved (Epoch 45, Val Loss 0.1929)
# Epoch 46/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 46/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.54it/s]
# Epoch 46/100
# Train Loss: 0.1153 | Val Loss: 0.2248
# Train Dice: 0.7982 | Val Dice: 0.6732
# Train IoU : 0.7998 | Val IoU : 0.6117
# Epoch 47/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 47/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.71it/s]
# Epoch 47/100
# Train Loss: 0.1138 | Val Loss: 0.1930
# Train Dice: 0.8010 | Val Dice: 0.6989
# Train IoU : 0.7992 | Val IoU : 0.6392
# Epoch 48/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# Epoch 48/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.13it/s]
# Epoch 48/100
# Train Loss: 0.1108 | Val Loss: 0.1874
# Train Dice: 0.8061 | Val Dice: 0.7025
# Train IoU : 0.8073 | Val IoU : 0.6383
# ✓ Best model saved (Epoch 48, Val Loss 0.1874)
# Epoch 49/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.35it/s]
# Epoch 49/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.62it/s]
# Epoch 49/100
# Train Loss: 0.1042 | Val Loss: 0.1947
# Train Dice: 0.8171 | Val Dice: 0.7022
# Train IoU : 0.8163 | Val IoU : 0.6336
# Epoch 50/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# Epoch 50/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.15it/s]
# Epoch 50/100
# Train Loss: 0.1051 | Val Loss: 0.2031
# Train Dice: 0.8180 | Val Dice: 0.6949
# Train IoU : 0.8069 | Val IoU : 0.6270
# Epoch 51/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 51/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.70it/s]
# Epoch 51/100
# Train Loss: 0.1049 | Val Loss: 0.2146
# Train Dice: 0.8162 | Val Dice: 0.6857
# Train IoU : 0.8082 | Val IoU : 0.6146
# Epoch 52/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 52/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.32it/s]
# Epoch 52/100
# Train Loss: 0.1096 | Val Loss: 0.2040
# Train Dice: 0.8137 | Val Dice: 0.6979
# Train IoU : 0.8012 | Val IoU : 0.6254
# Epoch 53/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 53/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.99it/s]
# Epoch 53/100
# Train Loss: 0.1011 | Val Loss: 0.1917
# Train Dice: 0.8240 | Val Dice: 0.7112
# Train IoU : 0.8112 | Val IoU : 0.6411
# Epoch 54/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 54/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.93it/s]
# Epoch 54/100
# Train Loss: 0.0935 | Val Loss: 0.1948
# Train Dice: 0.8375 | Val Dice: 0.7081
# Train IoU : 0.8257 | Val IoU : 0.6288
# Epoch 55/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 55/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.18it/s]
# Epoch 55/100
# Train Loss: 0.1023 | Val Loss: 0.1827
# Train Dice: 0.8251 | Val Dice: 0.7200
# Train IoU : 0.8020 | Val IoU : 0.6417
# ✓ Best model saved (Epoch 55, Val Loss 0.1827)
# Epoch 56/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 56/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.27it/s]
# Epoch 56/100
# Train Loss: 0.0966 | Val Loss: 0.2044
# Train Dice: 0.8361 | Val Dice: 0.7019
# Train IoU : 0.8164 | Val IoU : 0.6144
# Epoch 57/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 57/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.03it/s]
# Epoch 57/100
# Train Loss: 0.0936 | Val Loss: 0.2229
# Train Dice: 0.8422 | Val Dice: 0.6787
# Train IoU : 0.8231 | Val IoU : 0.5862
# Epoch 58/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 58/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.49it/s]
# Epoch 58/100
# Train Loss: 0.0926 | Val Loss: 0.2115
# Train Dice: 0.8426 | Val Dice: 0.6991
# Train IoU : 0.8219 | Val IoU : 0.6132
# Epoch 59/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 59/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.78it/s]
# Epoch 59/100
# Train Loss: 0.0875 | Val Loss: 0.2064
# Train Dice: 0.8530 | Val Dice: 0.7028
# Train IoU : 0.8290 | Val IoU : 0.6118
# Epoch 60/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 60/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.11it/s]
# Epoch 60/100
# Train Loss: 0.0869 | Val Loss: 0.2186
# Train Dice: 0.8510 | Val Dice: 0.7005
# Train IoU : 0.8291 | Val IoU : 0.6101
# Epoch 61/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 61/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.27it/s]
# Epoch 61/100
# Train Loss: 0.0895 | Val Loss: 0.1965
# Train Dice: 0.8492 | Val Dice: 0.7097
# Train IoU : 0.8202 | Val IoU : 0.6157
# Epoch 62/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 62/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.89it/s]
# Epoch 62/100
# Train Loss: 0.0828 | Val Loss: 0.1861
# Train Dice: 0.8603 | Val Dice: 0.7321
# Train IoU : 0.8355 | Val IoU : 0.6435
# Epoch 63/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 63/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.97it/s]
# Epoch 63/100
# Train Loss: 0.0818 | Val Loss: 0.1918
# Train Dice: 0.8628 | Val Dice: 0.7257
# Train IoU : 0.8368 | Val IoU : 0.6344
# Epoch 64/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 64/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.06it/s]
# Epoch 64/100
# Train Loss: 0.0893 | Val Loss: 0.1837
# Train Dice: 0.8511 | Val Dice: 0.7292
# Train IoU : 0.8193 | Val IoU : 0.6382
# Epoch 65/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 65/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.93it/s]
# Epoch 65/100
# Train Loss: 0.0840 | Val Loss: 0.2065
# Train Dice: 0.8590 | Val Dice: 0.7122
# Train IoU : 0.8291 | Val IoU : 0.6167
# Epoch 66/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 66/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.27it/s]
# Epoch 66/100
# Train Loss: 0.0783 | Val Loss: 0.1842
# Train Dice: 0.8685 | Val Dice: 0.7352
# Train IoU : 0.8384 | Val IoU : 0.6378
# Epoch 67/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 67/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.17it/s]
# Epoch 67/100
# Train Loss: 0.0781 | Val Loss: 0.1889
# Train Dice: 0.8690 | Val Dice: 0.7228
# Train IoU : 0.8422 | Val IoU : 0.6239
# Epoch 68/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.28it/s]
# Epoch 68/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.49it/s]
# Epoch 68/100
# Train Loss: 0.0739 | Val Loss: 0.2046
# Train Dice: 0.8762 | Val Dice: 0.7151
# Train IoU : 0.8492 | Val IoU : 0.6101
# Epoch 69/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.28it/s]
# Epoch 69/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.95it/s]
# Epoch 69/100
# Train Loss: 0.0767 | Val Loss: 0.2018
# Train Dice: 0.8703 | Val Dice: 0.7222
# Train IoU : 0.8417 | Val IoU : 0.6233
# Epoch 70/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 70/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.10it/s]
# Epoch 70/100
# Train Loss: 0.0716 | Val Loss: 0.2146
# Train Dice: 0.8778 | Val Dice: 0.7058
# Train IoU : 0.8500 | Val IoU : 0.5986
# Epoch 71/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 71/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.19it/s]
# Epoch 71/100
# Train Loss: 0.0743 | Val Loss: 0.1933
# Train Dice: 0.8774 | Val Dice: 0.7218
# Train IoU : 0.8487 | Val IoU : 0.6165
# Epoch 72/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 72/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.79it/s]
# Epoch 72/100
# Train Loss: 0.0723 | Val Loss: 0.1946
# Train Dice: 0.8776 | Val Dice: 0.7205
# Train IoU : 0.8484 | Val IoU : 0.6165
# Epoch 73/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 73/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.71it/s]
# Epoch 73/100
# Train Loss: 0.0690 | Val Loss: 0.2050
# Train Dice: 0.8829 | Val Dice: 0.7192
# Train IoU : 0.8553 | Val IoU : 0.6144
# Epoch 74/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 74/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.77it/s]
# Epoch 74/100
# Train Loss: 0.0662 | Val Loss: 0.1964
# Train Dice: 0.8886 | Val Dice: 0.7282
# Train IoU : 0.8614 | Val IoU : 0.6258
# Epoch 75/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 75/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.92it/s]
# Epoch 75/100
# Train Loss: 0.0684 | Val Loss: 0.2003
# Train Dice: 0.8835 | Val Dice: 0.7214
# Train IoU : 0.8574 | Val IoU : 0.6184
# Epoch 76/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 76/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.05it/s]
# Epoch 76/100
# Train Loss: 0.0686 | Val Loss: 0.1873
# Train Dice: 0.8870 | Val Dice: 0.7313
# Train IoU : 0.8556 | Val IoU : 0.6289
# Epoch 77/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 77/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.37it/s]
# Epoch 77/100
# Train Loss: 0.0690 | Val Loss: 0.1956
# Train Dice: 0.8847 | Val Dice: 0.7250
# Train IoU : 0.8538 | Val IoU : 0.6186
# Epoch 78/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 78/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.47it/s]
# Epoch 78/100
# Train Loss: 0.0616 | Val Loss: 0.2046
# Train Dice: 0.8955 | Val Dice: 0.7229
# Train IoU : 0.8704 | Val IoU : 0.6160
# Epoch 79/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.28it/s]
# Epoch 79/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.82it/s]
# Epoch 79/100
# Train Loss: 0.0678 | Val Loss: 0.2163
# Train Dice: 0.8857 | Val Dice: 0.7162
# Train IoU : 0.8564 | Val IoU : 0.6090
# Epoch 80/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 80/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.78it/s]
# Epoch 80/100
# Train Loss: 0.0638 | Val Loss: 0.2013
# Train Dice: 0.8913 | Val Dice: 0.7312
# Train IoU : 0.8630 | Val IoU : 0.6258
# Epoch 81/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 81/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.12it/s]
# Epoch 81/100
# Train Loss: 0.0607 | Val Loss: 0.2016
# Train Dice: 0.8983 | Val Dice: 0.7249
# Train IoU : 0.8727 | Val IoU : 0.6167
# Epoch 82/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 82/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.11it/s]
# Epoch 82/100
# Train Loss: 0.0626 | Val Loss: 0.1949
# Train Dice: 0.8939 | Val Dice: 0.7291
# Train IoU : 0.8681 | Val IoU : 0.6189
# Epoch 83/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.27it/s]
# Epoch 83/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.20it/s]
# Epoch 83/100
# Train Loss: 0.0597 | Val Loss: 0.2022
# Train Dice: 0.8989 | Val Dice: 0.7298
# Train IoU : 0.8738 | Val IoU : 0.6239
# Epoch 84/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.27it/s]
# Epoch 84/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.22it/s]
# Epoch 84/100
# Train Loss: 0.0603 | Val Loss: 0.1986
# Train Dice: 0.9003 | Val Dice: 0.7321
# Train IoU : 0.8728 | Val IoU : 0.6232
# Epoch 85/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 85/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.54it/s]
# Epoch 85/100
# Train Loss: 0.0606 | Val Loss: 0.2007
# Train Dice: 0.8991 | Val Dice: 0.7275
# Train IoU : 0.8722 | Val IoU : 0.6176
# Epoch 86/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# Epoch 86/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.25it/s]
# Epoch 86/100
# Train Loss: 0.0596 | Val Loss: 0.2056
# Train Dice: 0.8995 | Val Dice: 0.7313
# Train IoU : 0.8724 | Val IoU : 0.6270
# Epoch 87/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# Epoch 87/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.49it/s]
# Epoch 87/100
# Train Loss: 0.0604 | Val Loss: 0.2070
# Train Dice: 0.8987 | Val Dice: 0.7269
# Train IoU : 0.8714 | Val IoU : 0.6187
# Epoch 88/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 88/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.42it/s]
# Epoch 88/100
# Train Loss: 0.0600 | Val Loss: 0.2092
# Train Dice: 0.8998 | Val Dice: 0.7293
# Train IoU : 0.8718 | Val IoU : 0.6227
# Epoch 89/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 89/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.98it/s]
# Epoch 89/100
# Train Loss: 0.0593 | Val Loss: 0.2044
# Train Dice: 0.9006 | Val Dice: 0.7323
# Train IoU : 0.8728 | Val IoU : 0.6239
# Epoch 90/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 90/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.58it/s]
# Epoch 90/100
# Train Loss: 0.0556 | Val Loss: 0.2046
# Train Dice: 0.9064 | Val Dice: 0.7314
# Train IoU : 0.8821 | Val IoU : 0.6221
# Epoch 91/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 91/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.17it/s]
# Epoch 91/100
# Train Loss: 0.0598 | Val Loss: 0.2000
# Train Dice: 0.9002 | Val Dice: 0.7339
# Train IoU : 0.8719 | Val IoU : 0.6247
# Epoch 92/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.29it/s]
# Epoch 92/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.25it/s]
# Epoch 92/100
# Train Loss: 0.0609 | Val Loss: 0.2041
# Train Dice: 0.8974 | Val Dice: 0.7284
# Train IoU : 0.8708 | Val IoU : 0.6179
# Epoch 93/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 93/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.17it/s]
# Epoch 93/100
# Train Loss: 0.0562 | Val Loss: 0.2041
# Train Dice: 0.9051 | Val Dice: 0.7308
# Train IoU : 0.8806 | Val IoU : 0.6192
# Epoch 94/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.28it/s]
# Epoch 94/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.49it/s]
# Epoch 94/100
# Train Loss: 0.0562 | Val Loss: 0.2033
# Train Dice: 0.9060 | Val Dice: 0.7313
# Train IoU : 0.8797 | Val IoU : 0.6218
# Epoch 95/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 95/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.16it/s]
# Epoch 95/100
# Train Loss: 0.0580 | Val Loss: 0.1996
# Train Dice: 0.9015 | Val Dice: 0.7344
# Train IoU : 0.8739 | Val IoU : 0.6245
# Epoch 96/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.33it/s]
# Epoch 96/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.24it/s]
# Epoch 96/100
# Train Loss: 0.0553 | Val Loss: 0.2169
# Train Dice: 0.9071 | Val Dice: 0.7219
# Train IoU : 0.8815 | Val IoU : 0.6109
# Epoch 97/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.32it/s]
# Epoch 97/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.68it/s]
# Epoch 97/100
# Train Loss: 0.0534 | Val Loss: 0.2044
# Train Dice: 0.9097 | Val Dice: 0.7309
# Train IoU : 0.8857 | Val IoU : 0.6195
# Epoch 98/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.30it/s]
# Epoch 98/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.76it/s]
# Epoch 98/100
# Train Loss: 0.0573 | Val Loss: 0.2001
# Train Dice: 0.9052 | Val Dice: 0.7330
# Train IoU : 0.8766 | Val IoU : 0.6219
# Epoch 99/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.33it/s]
# Epoch 99/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 12.00it/s]
# Epoch 99/100
# Train Loss: 0.0554 | Val Loss: 0.1929
# Train Dice: 0.9074 | Val Dice: 0.7425
# Train IoU : 0.8785 | Val IoU : 0.6326
# Epoch 100/100 [Train]: 100%|██████████| 65/65 [00:10<00:00,  6.31it/s]
# Epoch 100/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.95it/s]
# Epoch 100/100
# Train Loss: 0.0548 | Val Loss: 0.1992
# Train Dice: 0.9076 | Val Dice: 0.7358
# Train IoU : 0.8823 | Val IoU : 0.6253
#
# ============================================================
# Training Completed!
# Best Epoch: 55
# Best Val Loss: 0.1827
# ============================================================
# Loading best model...
# Evaluating on test set...
# Evaluating Test Set: 100%|██████████| 9/9 [00:02<00:00,  3.25it/s]
# ========================================
# TEST SET EVALUATION
# ========================================
# Dice Coefficient: 0.8321
# IoU (Jaccard):    0.7242
# ========================================
#
# Generating visualizations...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.2042701].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0836544..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Evaluation completed successfully!
