# %% [markdown]
# <a href="https://colab.research.google.com/github/rounak393/clab/blob/main/resnet34_80_10_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install albumentations scikit-learn torchinfo -q

import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import random
import copy

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import albumentations as A
import cv2
import warnings
import torch.nn.functional as F
from torchinfo import summary
from torchvision.models import resnet34, ResNet34_Weights

warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

BASE_DIR = "/kaggle/input/datasets/britikak/busi-dataset/Dataset_BUSI_with_GT"
CLASSES = ["benign", "malignant"]
IMG_SIZE = 256
BATCH_SIZE = 8
SEED = 42

torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = True

class BUSISegmentationDataset(Dataset):
    def __init__(self, base_dir, classes, transform=None):
        self.samples = []
        self.transform = transform

        for cls in classes:
            cls_dir = os.path.join(base_dir, cls)
            if not os.path.exists(cls_dir):
                continue

            images = [
                f for f in os.listdir(cls_dir)
                if f.endswith(".png") and "_mask" not in f
            ]

            for img_name in images:
                img_path = os.path.join(cls_dir, img_name)
                base_name = img_name.replace(".png", "")

                mask_files = [
                    f for f in os.listdir(cls_dir)
                    if f.startswith(base_name + "_mask") and f.endswith(".png")
                ]

                if len(mask_files) == 0:
                    continue

                mask_paths = [os.path.join(cls_dir, f) for f in mask_files]
                self.samples.append((img_path, mask_paths))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, mask_paths = self.samples[idx]

        image = np.array(Image.open(img_path).convert("RGB"))

        combined_mask = np.zeros(image.shape[:2], dtype=np.uint8)
        for mpath in mask_paths:
            mask = np.array(Image.open(mpath).convert("L"))
            mask = (mask > 0).astype(np.uint8)
            combined_mask = np.logical_or(combined_mask, mask)

        combined_mask = combined_mask.astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=combined_mask)
            image = augmented["image"]
            combined_mask = augmented["mask"]

        # Ensure binary mask (important!)
        combined_mask = (combined_mask > 0.5).astype(np.float32)

        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(combined_mask).unsqueeze(0).float()

        return image, mask

# ===================---------------------=======================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

test_transform = val_transform

# ===================------------------------==================
full_dataset = BUSISegmentationDataset(BASE_DIR, classes=CLASSES, transform=None)
total_size = len(full_dataset)
indices = list(range(total_size))
np.random.seed(SEED)
np.random.shuffle(indices)

train_size = int(0.8 * total_size)
val_size   = int(0.1 * total_size)

val_indices = indices[:val_size]
train_indices   = indices[val_size:train_size + val_size]
test_indices  = indices[train_size + val_size:]

train_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=train_transform),
    train_indices)

val_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=val_transform),
    val_indices)

test_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=test_transform),
    test_indices)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)


# ==========================================
# CUSTOM RESNET34 UNET (PCBAM + SGA)
# ==========================================
class PCBAM_Filter(nn.Module):
    """
    Parallel Channel-and-Spatial Attention Module.
    """
    def __init__(self, in_channels, reduction=8):
        super().__init__()
        self.cam = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels)
        )
        self.sam = nn.Conv2d(2, 1, kernel_size=7, padding=3, bias=False)

    def forward(self, x):
        b, c, _, _ = x.size()
        avg = self.cam(F.adaptive_avg_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        mxp = self.cam(F.adaptive_max_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        x_c = x * torch.sigmoid(avg + mxp)

        sp  = torch.cat([
            torch.mean(x_c, dim=1, keepdim=True),
            torch.max(x_c,  dim=1, keepdim=True)[0]
        ], dim=1)
        x_s = x_c * torch.sigmoid(self.sam(sp))
        return x_s

class SpatialGateAttention(nn.Module):
    """
    Spatial Gate Attention at the bottleneck.
    """
    def __init__(self, in_channels):
        super().__init__()
        mid = in_channels // 8
        self.q_conv   = nn.Conv2d(in_channels, mid, 1)
        self.k_conv   = nn.Conv2d(in_channels, mid, 1)
        self.v_conv   = nn.Conv2d(in_channels, in_channels, 1)
        self.gate     = nn.Conv2d(mid * 2 + in_channels, in_channels, 1)

    def forward(self, x):
        q = self.q_conv(x)
        k = self.k_conv(x)
        v = self.v_conv(x)
        A = torch.sigmoid(self.gate(torch.cat([q, k, v], dim=1)))
        return x + v * A

class DoubleConv(nn.Module):
    """Standard double 3×3 conv block with BN and ReLU."""
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

class CustomResNetUNet(nn.Module):
    def __init__(self):
        super().__init__()

        # --- ResNet34 backbone ---
        resnet = resnet34(weights=ResNet34_Weights.IMAGENET1K_V1)

        # Standard 3-channel input
        self.conv1   = resnet.conv1
        self.bn1     = resnet.bn1
        self.relu    = resnet.relu
        self.maxpool = resnet.maxpool

        self.layer1 = resnet.layer1
        self.layer2 = resnet.layer2
        self.layer3 = resnet.layer3
        self.layer4 = resnet.layer4

        # Attention on Skip Connections
        self.pcbam1 = PCBAM_Filter(64)
        self.pcbam2 = PCBAM_Filter(128)
        self.pcbam3 = PCBAM_Filter(256)
        self.pcbam4 = PCBAM_Filter(512)

        self.pool       = nn.MaxPool2d(2)
        self.bottleneck = DoubleConv(512, 1024)
        self.sga        = SpatialGateAttention(1024)

        # Decoder
        self.up4  = nn.ConvTranspose2d(1024, 512, 2, stride=2)
        self.dec4 = DoubleConv(1024, 512)
        self.up3  = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec3 = DoubleConv(512, 256)
        self.up2  = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec2 = DoubleConv(256, 128)
        self.up1  = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec1 = DoubleConv(128, 64)
        self.up0  = nn.ConvTranspose2d(64, 64, 2, stride=2)
        self.dec0 = DoubleConv(128, 64)
        self.up_out  = nn.ConvTranspose2d(64, 32, 2, stride=2)
        self.dec_out = DoubleConv(32, 32)
        self.final   = nn.Conv2d(32, 1, 1)

    def forward(self, x):
        # 1. ResNet Encoder
        x0 = self.relu(self.bn1(self.conv1(x)))
        x1 = self.maxpool(x0)

        e1 = self.layer1(x1)
        e2 = self.layer2(e1)
        e3 = self.layer3(e2)
        e4 = self.layer4(e3)

        # 2. Skip connections through PCBAM
        s1 = self.pcbam1(e1)
        s2 = self.pcbam2(e2)
        s3 = self.pcbam3(e3)
        s4 = self.pcbam4(e4)

        # 3. Bottleneck with SGA
        b = self.sga(self.bottleneck(self.pool(e4)))

        # 4. Decoder
        d4 = self.dec4(torch.cat([self.up4(b),  s4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), s3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), s2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), s1], dim=1))
        d0  = self.dec0(torch.cat([self.up0(d1), x0], dim=1))
        out = self.dec_out(self.up_out(d0))

        # RETURNS RAW LOGITS (Required for HybridLoss)
        return self.final(out)

# ==========================================
# HYBRID LOSS & METRICS
# ==========================================
class HybridLoss(nn.Module):
    def __init__(self, smooth=1.0, focal_gamma=2.0):
        super().__init__()
        self.smooth      = smooth
        self.focal_gamma = focal_gamma

    def forward(self, logits, targets):
        bce   = F.binary_cross_entropy_with_logits(logits, targets)
        probs = torch.sigmoid(logits).view(-1)
        tgt   = targets.view(-1)
        inter = (probs * tgt).sum()
        dice  = 1.0 - (2.0 * inter + self.smooth) / (probs.sum() + tgt.sum() + self.smooth)
        pt    = torch.where(tgt == 1, probs, 1.0 - probs)
        focal = (-(1.0 - pt) ** self.focal_gamma * torch.log(pt + 1e-8)).mean()
        return 0.4 * bce + 0.4 * dice + 0.2 * focal

# Dice Metric
def dice_coef(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    inter = (y_true_f * y_pred_f).sum()
    return (2. * inter + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

# IoU Metric
def iou_score(preds, masks, threshold=0.5, eps=1e-6):
    preds_bin = (preds > threshold).float()
    masks_bin = (masks > threshold).float()

    inter = (preds_bin * masks_bin).sum().item()
    union = preds_bin.sum().item() + masks_bin.sum().item() - inter

    return inter / (union + eps)

# ==========================================
# TRAINING FUNCTION
# ==========================================
def train_model(model, train_loader, val_loader, epochs=50):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)

    criterion = HybridLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',          # because we monitor val_loss
        factor=0.5,          # reduce LR by half
        patience=10,         # wait 10 epochs before reducing,
        min_lr=1e-6
    )

    train_losses, val_losses = [], []
    train_dice_scores, val_dice_scores = [], []
    train_iou_scores, val_iou_scores = [], []

    best_val_loss = float("inf")
    best_epoch = 0
    best_model_weights = None

    for epoch in range(epochs):
        model.train()
        train_loss = train_dice = train_iou = 0
        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs} [Train]"):
            images, masks = images.to(device), masks.to(device)

            # Outputs Logits
            preds_logits = model(images)
            loss = criterion(preds_logits, masks)

            optimizer.zero_grad()
            loss.backward()

            # Gradient clipping to prevent inf loss
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

            # Convert logits to probabilities for metric calculation
            preds_probs = torch.sigmoid(preds_logits)

            train_loss += loss.item()
            train_dice += dice_coef(masks, preds_probs).item()
            train_iou += iou_score(preds_probs, masks)

        # ------------------ VALIDATION ------------------
        model.eval()
        val_loss = val_dice = val_iou = 0

        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc=f"Epoch {epoch+1}/{epochs} [Val]"):
                images, masks = images.to(device), masks.to(device)

                preds_logits = model(images)
                loss = criterion(preds_logits, masks)

                preds_probs = torch.sigmoid(preds_logits)

                val_loss += loss.item()
                val_dice += dice_coef(masks, preds_probs).item()
                val_iou += iou_score(preds_probs, masks)

        # ------------------ AVERAGES ------------------
        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        avg_train_dice = train_dice / len(train_loader)
        avg_val_dice   = val_dice / len(val_loader)
        avg_train_iou  = train_iou / len(train_loader)
        avg_val_iou    = val_iou / len(val_loader)

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_dice_scores.append(avg_train_dice)
        val_dice_scores.append(avg_val_dice)
        train_iou_scores.append(avg_train_iou)
        val_iou_scores.append(avg_val_iou)

        # ------------------ PRINT ------------------
        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
        print(f"Train Dice: {avg_train_dice:.4f} | Val Dice: {avg_val_dice:.4f}")
        print(f"Train IoU : {avg_train_iou:.4f} | Val IoU : {avg_val_iou:.4f}")

        # ------------------ SAVE BEST ------------------
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch + 1
            best_model_weights = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), "best_custom_unet.pth")
            print(f"✓ Best model saved (Epoch {epoch+1}, Val Loss {best_val_loss:.4f})")

        scheduler.step(avg_val_loss)

    # ------------------ LOAD BEST MODEL ------------------
    model.load_state_dict(best_model_weights)

    print("\n" + "="*60)
    print("Training Completed!")
    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val Loss: {best_val_loss:.4f}")
    print("="*60)

    return {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "train_dice": train_dice_scores,
        "val_dice": val_dice_scores,
        "train_iou": train_iou_scores,
        "val_iou": val_iou_scores,
    }

def plot_training(history):
    plt.figure(figsize=(17, 4))

    # Loss
    plt.subplot(1, 3, 1)
    plt.plot(history["train_losses"], label="Train Loss", linewidth=2)
    plt.plot(history["val_losses"], label="Val Loss", linewidth=2)
    plt.title("Loss Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Dice
    plt.subplot(1, 3, 2)
    plt.plot(history["train_dice"], label="Train Dice", linewidth=2)
    plt.plot(history["val_dice"], label="Val Dice", linewidth=2)
    plt.title("Dice Coefficient Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(history["train_iou"], label="Train IoU", linewidth=2)
    plt.plot(history["val_iou"], label="Val IoU", linewidth=2)
    plt.title("IoU Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("IoU Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=300, bbox_inches='tight')
    plt.show()

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    model = CustomResNetUNet()
    model = model.to(device)

    print("\n================= MODEL SUMMARY =================\n")
    print(summary(model, input_size=(BATCH_SIZE, 3, IMG_SIZE, IMG_SIZE)))

    history = train_model(model, train_loader, val_loader, epochs=100)
    plot_training(history)

    def iou_coef(y_true, y_pred, smooth=1e-5):
        y_true_f = y_true.view(-1)
        y_pred_f = y_pred.view(-1)
        intersection = (y_true_f * y_pred_f).sum()
        union = y_true_f.sum() + y_pred_f.sum() - intersection
        return (intersection + smooth) / (union + smooth)

    print("Loading best model...")
    model.load_state_dict(torch.load("best_custom_unet.pth", map_location=device))
    model.eval()

    test_dice, test_iou = 0, 0
    print("Evaluating on test set...")
    with torch.no_grad():
        for images, masks in tqdm(test_loader, desc="Evaluating Test Set"):
            images, masks = images.to(device), masks.to(device)

            # Use SIGMOID for raw logits output
            preds_probs = torch.sigmoid(model(images))
            preds_bin = (preds_probs > 0.4).float()

            test_dice += dice_coef(masks, preds_bin).item()
            test_iou += iou_coef(masks, preds_bin).item()

    num_batches = len(test_loader)
    avg_test_dice = test_dice / num_batches
    avg_test_iou = test_iou / num_batches

    print("\n" + "="*40)
    print("TEST SET EVALUATION")
    print("="*40)
    print(f"Dice Coefficient: {avg_test_dice:.4f}")
    print(f"IoU (Jaccard):    {avg_test_iou:.4f}")
    print("="*40)

    def dice_coef_single(y_true, y_pred, smooth=1e-5):
        y_true_f = y_true.flatten()
        y_pred_f = y_pred.flatten()
        intersection = np.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

    def iou_coef_single(y_true, y_pred, smooth=1e-5):
        intersection = np.sum(y_true * y_pred)
        union = np.sum(y_true) + np.sum(y_pred) - intersection
        return intersection / (union + smooth)

    def visualize_predictions_simple(model, dataset, num_samples=5, threshold=0.5):
        indices = random.sample(range(len(dataset)), num_samples)
        fig, axes = plt.subplots(num_samples, 4, figsize=(16, num_samples * 4))

        if num_samples == 1:
            axes = axes.reshape(1, -1)

        for i, idx in enumerate(indices):
            image, mask = dataset[idx]

            with torch.no_grad():
                pred_prob = torch.sigmoid(model(image.unsqueeze(0).to(device))).cpu().squeeze().numpy()

            pred_mask = (pred_prob > threshold).astype(np.uint8)
            true_mask = mask.squeeze().numpy().astype(np.uint8)

            dice_score = dice_coef_single(true_mask, pred_mask) * 100
            iou_score = iou_coef_single(true_mask, pred_mask) * 100

            error_map = np.zeros((*true_mask.shape, 3), dtype=np.uint8)
            true_positive = (true_mask == 1) & (pred_mask == 1)
            false_positive = (true_mask == 0) & (pred_mask == 1)
            false_negative = (true_mask == 1) & (pred_mask == 0)

            error_map[true_positive] = [255, 255, 255]
            error_map[false_positive] = [255, 0, 0]
            error_map[false_negative] = [0, 0, 255]

            axes[i, 0].imshow(image.permute(1, 2, 0) if image.shape[0] == 3 else image.squeeze(), cmap='gray')
            axes[i, 0].set_title(f"Input Image {idx}")
            axes[i, 0].axis("off")

            axes[i, 1].imshow(true_mask, cmap="gray")
            axes[i, 1].set_title("Ground Truth")
            axes[i, 1].axis("off")

            axes[i, 2].imshow(pred_mask, cmap="gray")
            axes[i, 2].set_title(f"Prediction\nDice: {dice_score:.1f}% | IoU: {iou_score:.1f}%")
            axes[i, 2].axis("off")

            axes[i, 3].imshow(error_map)
            axes[i, 3].set_title("Error Analysis\n(Red: FP, Blue: FN)")
            axes[i, 3].axis("off")

            if i == 0:
                from matplotlib.patches import Patch
                legend_elements = [
                    Patch(facecolor='white', label='True Positive'),
                    Patch(facecolor='red', label='False Positive'),
                    Patch(facecolor='blue', label='False Negative')
                ]
                axes[i, 3].legend(handles=legend_elements, loc='upper right', fontsize=8)

        plt.tight_layout()
        plt.show()

        return indices

    print("\nGenerating visualizations...")
    sampled_indices = visualize_predictions_simple(model, test_dataset, num_samples=7)
    print("\nEvaluation completed successfully!")
# Out:
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 135MB/s]
# ================= MODEL SUMMARY =================
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomResNetUNet                         [8, 1, 256, 256]          --
# ├─Conv2d: 1-1                            [8, 64, 128, 128]         9,408
# ├─BatchNorm2d: 1-2                       [8, 64, 128, 128]         128
# ├─ReLU: 1-3                              [8, 64, 128, 128]         --
# ├─MaxPool2d: 1-4                         [8, 64, 64, 64]           --
# ├─Sequential: 1-5                        [8, 64, 64, 64]           --
# │    └─BasicBlock: 2-1                   [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-1                  [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-2             [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-3                    [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-4                  [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-5             [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-6                    [8, 64, 64, 64]           --
# │    └─BasicBlock: 2-2                   [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-7                  [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-8             [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-9                    [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-10                 [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-11            [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-12                   [8, 64, 64, 64]           --
# │    └─BasicBlock: 2-3                   [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-13                 [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-14            [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-15                   [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-16                 [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-17            [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-18                   [8, 64, 64, 64]           --
# ├─Sequential: 1-6                        [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-4                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-19                 [8, 128, 32, 32]          73,728
# │    │    └─BatchNorm2d: 3-20            [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-21                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-22                 [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-23            [8, 128, 32, 32]          256
# │    │    └─Sequential: 3-24             [8, 128, 32, 32]          8,448
# │    │    └─ReLU: 3-25                   [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-5                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-26                 [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-27            [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-28                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-29                 [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-30            [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-31                   [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-6                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-32                 [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-33            [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-34                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-35                 [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-36            [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-37                   [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-7                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-38                 [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-39            [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-40                   [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-41                 [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-42            [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-43                   [8, 128, 32, 32]          --
# ├─Sequential: 1-7                        [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-8                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-44                 [8, 256, 16, 16]          294,912
# │    │    └─BatchNorm2d: 3-45            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-46                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-47                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-48            [8, 256, 16, 16]          512
# │    │    └─Sequential: 3-49             [8, 256, 16, 16]          33,280
# │    │    └─ReLU: 3-50                   [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-9                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-51                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-52            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-53                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-54                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-55            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-56                   [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-10                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-57                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-58            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-59                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-60                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-61            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-62                   [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-11                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-63                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-64            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-65                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-66                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-67            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-68                   [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-12                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-69                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-70            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-71                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-72                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-73            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-74                   [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-13                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-75                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-76            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-77                   [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-78                 [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-79            [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-80                   [8, 256, 16, 16]          --
# ├─Sequential: 1-8                        [8, 512, 8, 8]            --
# │    └─BasicBlock: 2-14                  [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-81                 [8, 512, 8, 8]            1,179,648
# │    │    └─BatchNorm2d: 3-82            [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-83                   [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-84                 [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-85            [8, 512, 8, 8]            1,024
# │    │    └─Sequential: 3-86             [8, 512, 8, 8]            132,096
# │    │    └─ReLU: 3-87                   [8, 512, 8, 8]            --
# │    └─BasicBlock: 2-15                  [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-88                 [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-89            [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-90                   [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-91                 [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-92            [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-93                   [8, 512, 8, 8]            --
# │    └─BasicBlock: 2-16                  [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-94                 [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-95            [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-96                   [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-97                 [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-98            [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-99                   [8, 512, 8, 8]            --
# ├─PCBAM_Filter: 1-9                      [8, 64, 64, 64]           --
# │    └─Sequential: 2-17                  [8, 64]                   --
# │    │    └─Linear: 3-100                [8, 8]                    520
# │    │    └─ReLU: 3-101                  [8, 8]                    --
# │    │    └─Linear: 3-102                [8, 64]                   576
# │    └─Sequential: 2-18                  [8, 64]                   (recursive)
# │    │    └─Linear: 3-103                [8, 8]                    (recursive)
# │    │    └─ReLU: 3-104                  [8, 8]                    --
# │    │    └─Linear: 3-105                [8, 64]                   (recursive)
# │    └─Conv2d: 2-19                      [8, 1, 64, 64]            98
# ├─PCBAM_Filter: 1-10                     [8, 128, 32, 32]          --
# │    └─Sequential: 2-20                  [8, 128]                  --
# │    │    └─Linear: 3-106                [8, 16]                   2,064
# │    │    └─ReLU: 3-107                  [8, 16]                   --
# │    │    └─Linear: 3-108                [8, 128]                  2,176
# │    └─Sequential: 2-21                  [8, 128]                  (recursive)
# │    │    └─Linear: 3-109                [8, 16]                   (recursive)
# │    │    └─ReLU: 3-110                  [8, 16]                   --
# │    │    └─Linear: 3-111                [8, 128]                  (recursive)
# │    └─Conv2d: 2-22                      [8, 1, 32, 32]            98
# ├─PCBAM_Filter: 1-11                     [8, 256, 16, 16]          --
# │    └─Sequential: 2-23                  [8, 256]                  --
# │    │    └─Linear: 3-112                [8, 32]                   8,224
# │    │    └─ReLU: 3-113                  [8, 32]                   --
# │    │    └─Linear: 3-114                [8, 256]                  8,448
# │    └─Sequential: 2-24                  [8, 256]                  (recursive)
# │    │    └─Linear: 3-115                [8, 32]                   (recursive)
# │    │    └─ReLU: 3-116                  [8, 32]                   --
# │    │    └─Linear: 3-117                [8, 256]                  (recursive)
# │    └─Conv2d: 2-25                      [8, 1, 16, 16]            98
# ├─PCBAM_Filter: 1-12                     [8, 512, 8, 8]            --
# │    └─Sequential: 2-26                  [8, 512]                  --
# │    │    └─Linear: 3-118                [8, 64]                   32,832
# │    │    └─ReLU: 3-119                  [8, 64]                   --
# │    │    └─Linear: 3-120                [8, 512]                  33,280
# │    └─Sequential: 2-27                  [8, 512]                  (recursive)
# │    │    └─Linear: 3-121                [8, 64]                   (recursive)
# │    │    └─ReLU: 3-122                  [8, 64]                   --
# │    │    └─Linear: 3-123                [8, 512]                  (recursive)
# │    └─Conv2d: 2-28                      [8, 1, 8, 8]              98
# ├─MaxPool2d: 1-13                        [8, 512, 4, 4]            --
# ├─DoubleConv: 1-14                       [8, 1024, 4, 4]           --
# │    └─Sequential: 2-29                  [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-124                [8, 1024, 4, 4]           4,718,592
# │    │    └─BatchNorm2d: 3-125           [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-126                  [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-127                [8, 1024, 4, 4]           9,437,184
# │    │    └─BatchNorm2d: 3-128           [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-129                  [8, 1024, 4, 4]           --
# ├─SpatialGateAttention: 1-15             [8, 1024, 4, 4]           --
# │    └─Conv2d: 2-30                      [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-31                      [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-32                      [8, 1024, 4, 4]           1,049,600
# │    └─Conv2d: 2-33                      [8, 1024, 4, 4]           1,311,744
# ├─ConvTranspose2d: 1-16                  [8, 512, 8, 8]            2,097,664
# ├─DoubleConv: 1-17                       [8, 512, 8, 8]            --
# │    └─Sequential: 2-34                  [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-130                [8, 512, 8, 8]            4,718,592
# │    │    └─BatchNorm2d: 3-131           [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-132                  [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-133                [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-134           [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-135                  [8, 512, 8, 8]            --
# ├─ConvTranspose2d: 1-18                  [8, 256, 16, 16]          524,544
# ├─DoubleConv: 1-19                       [8, 256, 16, 16]          --
# │    └─Sequential: 2-35                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-136                [8, 256, 16, 16]          1,179,648
# │    │    └─BatchNorm2d: 3-137           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-138                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-139                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-140           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-141                  [8, 256, 16, 16]          --
# ├─ConvTranspose2d: 1-20                  [8, 128, 32, 32]          131,200
# ├─DoubleConv: 1-21                       [8, 128, 32, 32]          --
# │    └─Sequential: 2-36                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-142                [8, 128, 32, 32]          294,912
# │    │    └─BatchNorm2d: 3-143           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-144                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-145                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-146           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-147                  [8, 128, 32, 32]          --
# ├─ConvTranspose2d: 1-22                  [8, 64, 64, 64]           32,832
# ├─DoubleConv: 1-23                       [8, 64, 64, 64]           --
# │    └─Sequential: 2-37                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-148                [8, 64, 64, 64]           73,728
# │    │    └─BatchNorm2d: 3-149           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-150                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-151                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-152           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-153                  [8, 64, 64, 64]           --
# ├─ConvTranspose2d: 1-24                  [8, 64, 128, 128]         16,448
# ├─DoubleConv: 1-25                       [8, 64, 128, 128]         --
# │    └─Sequential: 2-38                  [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-154                [8, 64, 128, 128]         73,728
# │    │    └─BatchNorm2d: 3-155           [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-156                  [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-157                [8, 64, 128, 128]         36,864
# │    │    └─BatchNorm2d: 3-158           [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-159                  [8, 64, 128, 128]         --
# ├─ConvTranspose2d: 1-26                  [8, 32, 256, 256]         8,224
# ├─DoubleConv: 1-27                       [8, 32, 256, 256]         --
# │    └─Sequential: 2-39                  [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-160                [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-161           [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-162                  [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-163                [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-164           [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-165                  [8, 32, 256, 256]         --
# ├─Conv2d: 1-28                           [8, 1, 256, 256]          33
# ==========================================================================================
# Total params: 50,501,313
# Trainable params: 50,501,313
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 89.87
# ==========================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 1800.10
# Params size (MB): 202.01
# Estimated Total Size (MB): 2008.40
# ==========================================================================================
# Epoch 1/100 [Train]: 100%|██████████| 65/65 [00:26<00:00,  2.49it/s]
# Epoch 1/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  5.27it/s]
# Epoch 1/100
# Train Loss: 0.5551 | Val Loss: 0.5142
# Train Dice: 0.2298 | Val Dice: 0.2787
# Train IoU : 0.3389 | Val IoU : 0.4656
# ✓ Best model saved (Epoch 1, Val Loss 0.5142)
# Epoch 2/100 [Train]: 100%|██████████| 65/65 [00:11<00:00,  5.61it/s]
# Epoch 2/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.50it/s]
# Epoch 2/100
# Train Loss: 0.4671 | Val Loss: 0.4642
# Train Dice: 0.2918 | Val Dice: 0.3092
# Train IoU : 0.4952 | Val IoU : 0.4686
# ✓ Best model saved (Epoch 2, Val Loss 0.4642)
# Epoch 3/100 [Train]: 100%|██████████| 65/65 [00:11<00:00,  5.51it/s]
# Epoch 3/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.49it/s]
# Epoch 3/100
# Train Loss: 0.4346 | Val Loss: 0.4554
# Train Dice: 0.3182 | Val Dice: 0.3066
# Train IoU : 0.5423 | Val IoU : 0.5095
# ✓ Best model saved (Epoch 3, Val Loss 0.4554)
# Epoch 4/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.41it/s]
# Epoch 4/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.24it/s]
# Epoch 4/100
# Train Loss: 0.4123 | Val Loss: 0.4069
# Train Dice: 0.3410 | Val Dice: 0.3426
# Train IoU : 0.5772 | Val IoU : 0.5803
# ✓ Best model saved (Epoch 4, Val Loss 0.4069)
# Epoch 5/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.32it/s]
# Epoch 5/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.25it/s]
# Epoch 5/100
# Train Loss: 0.3916 | Val Loss: 0.3933
# Train Dice: 0.3646 | Val Dice: 0.3458
# Train IoU : 0.6076 | Val IoU : 0.6023
# ✓ Best model saved (Epoch 5, Val Loss 0.3933)
# Epoch 6/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.20it/s]
# Epoch 6/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.68it/s]
# Epoch 6/100
# Train Loss: 0.3788 | Val Loss: 0.3883
# Train Dice: 0.3765 | Val Dice: 0.3316
# Train IoU : 0.6223 | Val IoU : 0.6145
# ✓ Best model saved (Epoch 6, Val Loss 0.3883)
# Epoch 7/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.12it/s]
# Epoch 7/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.38it/s]
# Epoch 7/100
# Train Loss: 0.3689 | Val Loss: 0.3822
# Train Dice: 0.3894 | Val Dice: 0.3582
# Train IoU : 0.6130 | Val IoU : 0.5952
# ✓ Best model saved (Epoch 7, Val Loss 0.3822)
# Epoch 8/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.17it/s]
# Epoch 8/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.66it/s]
# Epoch 8/100
# Train Loss: 0.3457 | Val Loss: 0.3702
# Train Dice: 0.4144 | Val Dice: 0.3766
# Train IoU : 0.6679 | Val IoU : 0.6171
# ✓ Best model saved (Epoch 8, Val Loss 0.3702)
# Epoch 9/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 9/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.25it/s]
# Epoch 9/100
# Train Loss: 0.3358 | Val Loss: 0.3570
# Train Dice: 0.4292 | Val Dice: 0.3957
# Train IoU : 0.6558 | Val IoU : 0.5830
# ✓ Best model saved (Epoch 9, Val Loss 0.3570)
# Epoch 10/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.30it/s]
# Epoch 10/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.65it/s]
# Epoch 10/100
# Train Loss: 0.3164 | Val Loss: 0.3406
# Train Dice: 0.4506 | Val Dice: 0.3944
# Train IoU : 0.6889 | Val IoU : 0.5941
# ✓ Best model saved (Epoch 10, Val Loss 0.3406)
# Epoch 11/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.30it/s]
# Epoch 11/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.48it/s]
# Epoch 11/100
# Train Loss: 0.3106 | Val Loss: 0.3395
# Train Dice: 0.4598 | Val Dice: 0.4241
# Train IoU : 0.6769 | Val IoU : 0.5977
# ✓ Best model saved (Epoch 11, Val Loss 0.3395)
# Epoch 12/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 12/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.58it/s]
# Epoch 12/100
# Train Loss: 0.2947 | Val Loss: 0.3294
# Train Dice: 0.4811 | Val Dice: 0.4294
# Train IoU : 0.6908 | Val IoU : 0.5941
# ✓ Best model saved (Epoch 12, Val Loss 0.3294)
# Epoch 13/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.20it/s]
# Epoch 13/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.87it/s]
# Epoch 13/100
# Train Loss: 0.2794 | Val Loss: 0.3091
# Train Dice: 0.5047 | Val Dice: 0.4590
# Train IoU : 0.7215 | Val IoU : 0.6103
# ✓ Best model saved (Epoch 13, Val Loss 0.3091)
# Epoch 14/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 14/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.19it/s]
# Epoch 14/100
# Train Loss: 0.2687 | Val Loss: 0.3071
# Train Dice: 0.5199 | Val Dice: 0.4588
# Train IoU : 0.7193 | Val IoU : 0.6163
# ✓ Best model saved (Epoch 14, Val Loss 0.3071)
# Epoch 15/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 15/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.29it/s]
# Epoch 15/100
# Train Loss: 0.2630 | Val Loss: 0.2944
# Train Dice: 0.5318 | Val Dice: 0.4925
# Train IoU : 0.7085 | Val IoU : 0.6125
# ✓ Best model saved (Epoch 15, Val Loss 0.2944)
# Epoch 16/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.27it/s]
# Epoch 16/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.77it/s]
# Epoch 16/100
# Train Loss: 0.2495 | Val Loss: 0.3069
# Train Dice: 0.5518 | Val Dice: 0.4806
# Train IoU : 0.7301 | Val IoU : 0.5873
# Epoch 17/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.27it/s]
# Epoch 17/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.23it/s]
# Epoch 17/100
# Train Loss: 0.2435 | Val Loss: 0.2930
# Train Dice: 0.5614 | Val Dice: 0.4933
# Train IoU : 0.7221 | Val IoU : 0.5854
# ✓ Best model saved (Epoch 17, Val Loss 0.2930)
# Epoch 18/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 18/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.18it/s]
# Epoch 18/100
# Train Loss: 0.2370 | Val Loss: 0.2732
# Train Dice: 0.5708 | Val Dice: 0.5170
# Train IoU : 0.7186 | Val IoU : 0.6245
# ✓ Best model saved (Epoch 18, Val Loss 0.2732)
# Epoch 19/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 19/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.62it/s]
# Epoch 19/100
# Train Loss: 0.2203 | Val Loss: 0.2649
# Train Dice: 0.5992 | Val Dice: 0.5255
# Train IoU : 0.7433 | Val IoU : 0.6167
# ✓ Best model saved (Epoch 19, Val Loss 0.2649)
# Epoch 20/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 20/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.32it/s]
# Epoch 20/100
# Train Loss: 0.2091 | Val Loss: 0.2821
# Train Dice: 0.6197 | Val Dice: 0.5469
# Train IoU : 0.7545 | Val IoU : 0.6066
# Epoch 21/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 21/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.59it/s]
# Epoch 21/100
# Train Loss: 0.2033 | Val Loss: 0.2922
# Train Dice: 0.6269 | Val Dice: 0.5425
# Train IoU : 0.7569 | Val IoU : 0.5930
# Epoch 22/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 22/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.44it/s]
# Epoch 22/100
# Train Loss: 0.1978 | Val Loss: 0.2689
# Train Dice: 0.6392 | Val Dice: 0.5631
# Train IoU : 0.7594 | Val IoU : 0.5923
# Epoch 23/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 23/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.49it/s]
# Epoch 23/100
# Train Loss: 0.1954 | Val Loss: 0.2580
# Train Dice: 0.6460 | Val Dice: 0.5640
# Train IoU : 0.7409 | Val IoU : 0.6081
# ✓ Best model saved (Epoch 23, Val Loss 0.2580)
# Epoch 24/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 24/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.65it/s]
# Epoch 24/100
# Train Loss: 0.1800 | Val Loss: 0.2229
# Train Dice: 0.6712 | Val Dice: 0.6046
# Train IoU : 0.7674 | Val IoU : 0.6700
# ✓ Best model saved (Epoch 24, Val Loss 0.2229)
# Epoch 25/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 25/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.67it/s]
# Epoch 25/100
# Train Loss: 0.1710 | Val Loss: 0.2218
# Train Dice: 0.6878 | Val Dice: 0.6030
# Train IoU : 0.7800 | Val IoU : 0.6508
# ✓ Best model saved (Epoch 25, Val Loss 0.2218)
# Epoch 26/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 26/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.50it/s]
# Epoch 26/100
# Train Loss: 0.1731 | Val Loss: 0.2373
# Train Dice: 0.6834 | Val Dice: 0.5798
# Train IoU : 0.7634 | Val IoU : 0.6185
# Epoch 27/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 27/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.67it/s]
# Epoch 27/100
# Train Loss: 0.1659 | Val Loss: 0.2160
# Train Dice: 0.7006 | Val Dice: 0.6161
# Train IoU : 0.7694 | Val IoU : 0.6201
# ✓ Best model saved (Epoch 27, Val Loss 0.2160)
# Epoch 28/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 28/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.95it/s]
# Epoch 28/100
# Train Loss: 0.1604 | Val Loss: 0.2522
# Train Dice: 0.7094 | Val Dice: 0.5968
# Train IoU : 0.7766 | Val IoU : 0.5779
# Epoch 29/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 29/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.56it/s]
# Epoch 29/100
# Train Loss: 0.1611 | Val Loss: 0.2371
# Train Dice: 0.7101 | Val Dice: 0.5955
# Train IoU : 0.7596 | Val IoU : 0.5869
# Epoch 30/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 30/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.79it/s]
# Epoch 30/100
# Train Loss: 0.1459 | Val Loss: 0.2084
# Train Dice: 0.7341 | Val Dice: 0.6488
# Train IoU : 0.7922 | Val IoU : 0.6388
# ✓ Best model saved (Epoch 30, Val Loss 0.2084)
# Epoch 31/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 31/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.13it/s]
# Epoch 31/100
# Train Loss: 0.1410 | Val Loss: 0.2176
# Train Dice: 0.7468 | Val Dice: 0.6352
# Train IoU : 0.7952 | Val IoU : 0.6182
# Epoch 32/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 32/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.56it/s]
# Epoch 32/100
# Train Loss: 0.1400 | Val Loss: 0.2051
# Train Dice: 0.7502 | Val Dice: 0.6691
# Train IoU : 0.7949 | Val IoU : 0.6481
# ✓ Best model saved (Epoch 32, Val Loss 0.2051)
# Epoch 33/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 33/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.85it/s]
# Epoch 33/100
# Train Loss: 0.1261 | Val Loss: 0.2006
# Train Dice: 0.7722 | Val Dice: 0.6598
# Train IoU : 0.8088 | Val IoU : 0.6280
# ✓ Best model saved (Epoch 33, Val Loss 0.2006)
# Epoch 34/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 34/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.68it/s]
# Epoch 34/100
# Train Loss: 0.1190 | Val Loss: 0.2008
# Train Dice: 0.7823 | Val Dice: 0.6704
# Train IoU : 0.8235 | Val IoU : 0.6374
# Epoch 35/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 35/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.13it/s]
# Epoch 35/100
# Train Loss: 0.1243 | Val Loss: 0.2045
# Train Dice: 0.7818 | Val Dice: 0.6677
# Train IoU : 0.8072 | Val IoU : 0.6143
# Epoch 36/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 36/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.57it/s]
# Epoch 36/100
# Train Loss: 0.1217 | Val Loss: 0.2100
# Train Dice: 0.7847 | Val Dice: 0.6713
# Train IoU : 0.8021 | Val IoU : 0.6212
# Epoch 37/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 37/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.04it/s]
# Epoch 37/100
# Train Loss: 0.1159 | Val Loss: 0.2053
# Train Dice: 0.7932 | Val Dice: 0.6729
# Train IoU : 0.8159 | Val IoU : 0.6250
# Epoch 38/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 38/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.84it/s]
# Epoch 38/100
# Train Loss: 0.1143 | Val Loss: 0.1952
# Train Dice: 0.7989 | Val Dice: 0.6932
# Train IoU : 0.8105 | Val IoU : 0.6229
# ✓ Best model saved (Epoch 38, Val Loss 0.1952)
# Epoch 39/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 39/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.96it/s]
# Epoch 39/100
# Train Loss: 0.1112 | Val Loss: 0.1970
# Train Dice: 0.8041 | Val Dice: 0.6836
# Train IoU : 0.8148 | Val IoU : 0.6182
# Epoch 40/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 40/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.40it/s]
# Epoch 40/100
# Train Loss: 0.1079 | Val Loss: 0.2358
# Train Dice: 0.8097 | Val Dice: 0.6606
# Train IoU : 0.8146 | Val IoU : 0.5943
# Epoch 41/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 41/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.11it/s]
# Epoch 41/100
# Train Loss: 0.1111 | Val Loss: 0.2387
# Train Dice: 0.8081 | Val Dice: 0.6635
# Train IoU : 0.8116 | Val IoU : 0.5852
# Epoch 42/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 42/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.16it/s]
# Epoch 42/100
# Train Loss: 0.1042 | Val Loss: 0.2009
# Train Dice: 0.8211 | Val Dice: 0.6930
# Train IoU : 0.8224 | Val IoU : 0.6173
# Epoch 43/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 43/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.46it/s]
# Epoch 43/100
# Train Loss: 0.1007 | Val Loss: 0.1961
# Train Dice: 0.8284 | Val Dice: 0.6991
# Train IoU : 0.8254 | Val IoU : 0.6264
# Epoch 44/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 44/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.67it/s]
# Epoch 44/100
# Train Loss: 0.0945 | Val Loss: 0.2504
# Train Dice: 0.8370 | Val Dice: 0.6623
# Train IoU : 0.8311 | Val IoU : 0.5629
# Epoch 45/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 45/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.57it/s]
# Epoch 45/100
# Train Loss: 0.1020 | Val Loss: 0.1919
# Train Dice: 0.8264 | Val Dice: 0.7077
# Train IoU : 0.8160 | Val IoU : 0.6258
# ✓ Best model saved (Epoch 45, Val Loss 0.1919)
# Epoch 46/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.27it/s]
# Epoch 46/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.85it/s]
# Epoch 46/100
# Train Loss: 0.0971 | Val Loss: 0.1983
# Train Dice: 0.8350 | Val Dice: 0.7097
# Train IoU : 0.8215 | Val IoU : 0.6228
# Epoch 47/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 47/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.49it/s]
# Epoch 47/100
# Train Loss: 0.0914 | Val Loss: 0.1824
# Train Dice: 0.8436 | Val Dice: 0.7178
# Train IoU : 0.8298 | Val IoU : 0.6350
# ✓ Best model saved (Epoch 47, Val Loss 0.1824)
# Epoch 48/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 48/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.31it/s]
# Epoch 48/100
# Train Loss: 0.0949 | Val Loss: 0.1869
# Train Dice: 0.8385 | Val Dice: 0.7138
# Train IoU : 0.8183 | Val IoU : 0.6294
# Epoch 49/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 49/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.59it/s]
# Epoch 49/100
# Train Loss: 0.0822 | Val Loss: 0.1905
# Train Dice: 0.8596 | Val Dice: 0.7093
# Train IoU : 0.8464 | Val IoU : 0.6166
# Epoch 50/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 50/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.70it/s]
# Epoch 50/100
# Train Loss: 0.0859 | Val Loss: 0.1898
# Train Dice: 0.8537 | Val Dice: 0.7066
# Train IoU : 0.8369 | Val IoU : 0.6063
# Epoch 51/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 51/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.22it/s]
# Epoch 51/100
# Train Loss: 0.0862 | Val Loss: 0.1965
# Train Dice: 0.8509 | Val Dice: 0.7018
# Train IoU : 0.8342 | Val IoU : 0.6041
# Epoch 52/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 52/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.73it/s]
# Epoch 52/100
# Train Loss: 0.0850 | Val Loss: 0.2278
# Train Dice: 0.8597 | Val Dice: 0.6921
# Train IoU : 0.8374 | Val IoU : 0.5858
# Epoch 53/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 53/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.04it/s]
# Epoch 53/100
# Train Loss: 0.0851 | Val Loss: 0.2314
# Train Dice: 0.8573 | Val Dice: 0.6987
# Train IoU : 0.8335 | Val IoU : 0.5925
# Epoch 54/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 54/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.54it/s]
# Epoch 54/100
# Train Loss: 0.0878 | Val Loss: 0.2125
# Train Dice: 0.8523 | Val Dice: 0.6988
# Train IoU : 0.8253 | Val IoU : 0.5915
# Epoch 55/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 55/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.76it/s]
# Epoch 55/100
# Train Loss: 0.0841 | Val Loss: 0.1925
# Train Dice: 0.8645 | Val Dice: 0.7088
# Train IoU : 0.8383 | Val IoU : 0.6068
# Epoch 56/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 56/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.02it/s]
# Epoch 56/100
# Train Loss: 0.0808 | Val Loss: 0.1773
# Train Dice: 0.8639 | Val Dice: 0.7399
# Train IoU : 0.8384 | Val IoU : 0.6454
# ✓ Best model saved (Epoch 56, Val Loss 0.1773)
# Epoch 57/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 57/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.93it/s]
# Epoch 57/100
# Train Loss: 0.0772 | Val Loss: 0.2062
# Train Dice: 0.8698 | Val Dice: 0.7016
# Train IoU : 0.8485 | Val IoU : 0.5902
# Epoch 58/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 58/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.62it/s]
# Epoch 58/100
# Train Loss: 0.0786 | Val Loss: 0.1689
# Train Dice: 0.8707 | Val Dice: 0.7430
# Train IoU : 0.8424 | Val IoU : 0.6394
# ✓ Best model saved (Epoch 58, Val Loss 0.1689)
# Epoch 59/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 59/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.35it/s]
# Epoch 59/100
# Train Loss: 0.0737 | Val Loss: 0.1991
# Train Dice: 0.8749 | Val Dice: 0.7208
# Train IoU : 0.8489 | Val IoU : 0.6114
# Epoch 60/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 60/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.70it/s]
# Epoch 60/100
# Train Loss: 0.0755 | Val Loss: 0.1777
# Train Dice: 0.8753 | Val Dice: 0.7401
# Train IoU : 0.8453 | Val IoU : 0.6352
# Epoch 61/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 61/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.19it/s]
# Epoch 61/100
# Train Loss: 0.0702 | Val Loss: 0.1665
# Train Dice: 0.8829 | Val Dice: 0.7529
# Train IoU : 0.8550 | Val IoU : 0.6517
# ✓ Best model saved (Epoch 61, Val Loss 0.1665)
# Epoch 62/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 62/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.60it/s]
# Epoch 62/100
# Train Loss: 0.0704 | Val Loss: 0.1955
# Train Dice: 0.8821 | Val Dice: 0.7281
# Train IoU : 0.8538 | Val IoU : 0.6221
# Epoch 63/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 63/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.08it/s]
# Epoch 63/100
# Train Loss: 0.0684 | Val Loss: 0.1812
# Train Dice: 0.8872 | Val Dice: 0.7369
# Train IoU : 0.8556 | Val IoU : 0.6236
# Epoch 64/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 64/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.48it/s]
# Epoch 64/100
# Train Loss: 0.0645 | Val Loss: 0.1645
# Train Dice: 0.8935 | Val Dice: 0.7639
# Train IoU : 0.8660 | Val IoU : 0.6582
# ✓ Best model saved (Epoch 64, Val Loss 0.1645)
# Epoch 65/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 65/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.92it/s]
# Epoch 65/100
# Train Loss: 0.0663 | Val Loss: 0.2088
# Train Dice: 0.8928 | Val Dice: 0.7176
# Train IoU : 0.8593 | Val IoU : 0.6008
# Epoch 66/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.22it/s]
# Epoch 66/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.14it/s]
# Epoch 66/100
# Train Loss: 0.0639 | Val Loss: 0.2025
# Train Dice: 0.8968 | Val Dice: 0.7256
# Train IoU : 0.8668 | Val IoU : 0.6148
# Epoch 67/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 67/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.83it/s]
# Epoch 67/100
# Train Loss: 0.0696 | Val Loss: 0.1776
# Train Dice: 0.8860 | Val Dice: 0.7402
# Train IoU : 0.8512 | Val IoU : 0.6273
# Epoch 68/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 68/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.73it/s]
# Epoch 68/100
# Train Loss: 0.0649 | Val Loss: 0.1947
# Train Dice: 0.8937 | Val Dice: 0.7319
# Train IoU : 0.8609 | Val IoU : 0.6222
# Epoch 69/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 69/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.40it/s]
# Epoch 69/100
# Train Loss: 0.0655 | Val Loss: 0.1959
# Train Dice: 0.8943 | Val Dice: 0.7407
# Train IoU : 0.8601 | Val IoU : 0.6323
# Epoch 70/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 70/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.71it/s]
# Epoch 70/100
# Train Loss: 0.0648 | Val Loss: 0.1797
# Train Dice: 0.8956 | Val Dice: 0.7364
# Train IoU : 0.8607 | Val IoU : 0.6274
# Epoch 71/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 71/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.64it/s]
# Epoch 71/100
# Train Loss: 0.0649 | Val Loss: 0.1902
# Train Dice: 0.8949 | Val Dice: 0.7351
# Train IoU : 0.8603 | Val IoU : 0.6224
# Epoch 72/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 72/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.87it/s]
# Epoch 72/100
# Train Loss: 0.0664 | Val Loss: 0.1728
# Train Dice: 0.8936 | Val Dice: 0.7517
# Train IoU : 0.8540 | Val IoU : 0.6447
# Epoch 73/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 73/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.96it/s]
# Epoch 73/100
# Train Loss: 0.0646 | Val Loss: 0.2006
# Train Dice: 0.8964 | Val Dice: 0.7272
# Train IoU : 0.8587 | Val IoU : 0.6061
# Epoch 74/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 74/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.43it/s]
# Epoch 74/100
# Train Loss: 0.0612 | Val Loss: 0.1886
# Train Dice: 0.9010 | Val Dice: 0.7300
# Train IoU : 0.8658 | Val IoU : 0.6132
# Epoch 75/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 75/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.53it/s]
# Epoch 75/100
# Train Loss: 0.0628 | Val Loss: 0.2129
# Train Dice: 0.8981 | Val Dice: 0.7148
# Train IoU : 0.8588 | Val IoU : 0.5919
# Epoch 76/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 76/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.94it/s]
# Epoch 76/100
# Train Loss: 0.0521 | Val Loss: 0.2209
# Train Dice: 0.9131 | Val Dice: 0.7176
# Train IoU : 0.8823 | Val IoU : 0.5969
# Epoch 77/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 77/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.10it/s]
# Epoch 77/100
# Train Loss: 0.0550 | Val Loss: 0.1688
# Train Dice: 0.9113 | Val Dice: 0.7584
# Train IoU : 0.8778 | Val IoU : 0.6419
# Epoch 78/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.27it/s]
# Epoch 78/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.92it/s]
# Epoch 78/100
# Train Loss: 0.0516 | Val Loss: 0.2025
# Train Dice: 0.9152 | Val Dice: 0.7313
# Train IoU : 0.8864 | Val IoU : 0.6116
# Epoch 79/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 79/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.05it/s]
# Epoch 79/100
# Train Loss: 0.0506 | Val Loss: 0.2023
# Train Dice: 0.9164 | Val Dice: 0.7299
# Train IoU : 0.8867 | Val IoU : 0.6106
# Epoch 80/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 80/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.82it/s]
# Epoch 80/100
# Train Loss: 0.0485 | Val Loss: 0.1986
# Train Dice: 0.9196 | Val Dice: 0.7348
# Train IoU : 0.8909 | Val IoU : 0.6158
# Epoch 81/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 81/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.54it/s]
# Epoch 81/100
# Train Loss: 0.0524 | Val Loss: 0.1974
# Train Dice: 0.9164 | Val Dice: 0.7389
# Train IoU : 0.8853 | Val IoU : 0.6224
# Epoch 82/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 82/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.97it/s]
# Epoch 82/100
# Train Loss: 0.0485 | Val Loss: 0.1960
# Train Dice: 0.9204 | Val Dice: 0.7394
# Train IoU : 0.8913 | Val IoU : 0.6230
# Epoch 83/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.23it/s]
# Epoch 83/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.45it/s]
# Epoch 83/100
# Train Loss: 0.0464 | Val Loss: 0.1984
# Train Dice: 0.9247 | Val Dice: 0.7390
# Train IoU : 0.8960 | Val IoU : 0.6209
# Epoch 84/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 84/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.64it/s]
# Epoch 84/100
# Train Loss: 0.0500 | Val Loss: 0.2035
# Train Dice: 0.9187 | Val Dice: 0.7319
# Train IoU : 0.8882 | Val IoU : 0.6092
# Epoch 85/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 85/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.85it/s]
# Epoch 85/100
# Train Loss: 0.0520 | Val Loss: 0.2145
# Train Dice: 0.9178 | Val Dice: 0.7175
# Train IoU : 0.8859 | Val IoU : 0.5916
# Epoch 86/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 86/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.77it/s]
# Epoch 86/100
# Train Loss: 0.0463 | Val Loss: 0.1954
# Train Dice: 0.9236 | Val Dice: 0.7409
# Train IoU : 0.8929 | Val IoU : 0.6238
# Epoch 87/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 87/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.79it/s]
# Epoch 87/100
# Train Loss: 0.0493 | Val Loss: 0.1933
# Train Dice: 0.9220 | Val Dice: 0.7408
# Train IoU : 0.8902 | Val IoU : 0.6209
# Epoch 88/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 88/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.03it/s]
# Epoch 88/100
# Train Loss: 0.0427 | Val Loss: 0.1918
# Train Dice: 0.9290 | Val Dice: 0.7397
# Train IoU : 0.9032 | Val IoU : 0.6187
# Epoch 89/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 89/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.02it/s]
# Epoch 89/100
# Train Loss: 0.0450 | Val Loss: 0.1829
# Train Dice: 0.9251 | Val Dice: 0.7554
# Train IoU : 0.8974 | Val IoU : 0.6368
# Epoch 90/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 90/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.24it/s]
# Epoch 90/100
# Train Loss: 0.0443 | Val Loss: 0.2086
# Train Dice: 0.9270 | Val Dice: 0.7350
# Train IoU : 0.8991 | Val IoU : 0.6154
# Epoch 91/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 91/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.54it/s]
# Epoch 91/100
# Train Loss: 0.0450 | Val Loss: 0.2054
# Train Dice: 0.9274 | Val Dice: 0.7356
# Train IoU : 0.8986 | Val IoU : 0.6144
# Epoch 92/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 92/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.04it/s]
# Epoch 92/100
# Train Loss: 0.0433 | Val Loss: 0.2080
# Train Dice: 0.9287 | Val Dice: 0.7332
# Train IoU : 0.9018 | Val IoU : 0.6123
# Epoch 93/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 93/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.77it/s]
# Epoch 93/100
# Train Loss: 0.0461 | Val Loss: 0.2060
# Train Dice: 0.9246 | Val Dice: 0.7367
# Train IoU : 0.8951 | Val IoU : 0.6143
# Epoch 94/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 94/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.24it/s]
# Epoch 94/100
# Train Loss: 0.0425 | Val Loss: 0.2017
# Train Dice: 0.9297 | Val Dice: 0.7413
# Train IoU : 0.9029 | Val IoU : 0.6185
# Epoch 95/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 95/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.34it/s]
# Epoch 95/100
# Train Loss: 0.0436 | Val Loss: 0.2007
# Train Dice: 0.9275 | Val Dice: 0.7399
# Train IoU : 0.8982 | Val IoU : 0.6183
# Epoch 96/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.25it/s]
# Epoch 96/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.63it/s]
# Epoch 96/100
# Train Loss: 0.0397 | Val Loss: 0.2062
# Train Dice: 0.9344 | Val Dice: 0.7365
# Train IoU : 0.9094 | Val IoU : 0.6127
# Epoch 97/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.22it/s]
# Epoch 97/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.20it/s]
# Epoch 97/100
# Train Loss: 0.0419 | Val Loss: 0.2039
# Train Dice: 0.9322 | Val Dice: 0.7371
# Train IoU : 0.9047 | Val IoU : 0.6117
# Epoch 98/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.26it/s]
# Epoch 98/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.68it/s]
# Epoch 98/100
# Train Loss: 0.0391 | Val Loss: 0.2075
# Train Dice: 0.9357 | Val Dice: 0.7378
# Train IoU : 0.9101 | Val IoU : 0.6121
# Epoch 99/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 99/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 11.19it/s]
# Epoch 99/100
# Train Loss: 0.0417 | Val Loss: 0.2042
# Train Dice: 0.9314 | Val Dice: 0.7386
# Train IoU : 0.9052 | Val IoU : 0.6133
# Epoch 100/100 [Train]: 100%|██████████| 65/65 [00:12<00:00,  5.24it/s]
# Epoch 100/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.98it/s]
# Epoch 100/100
# Train Loss: 0.0427 | Val Loss: 0.2052
# Train Dice: 0.9281 | Val Dice: 0.7404
# Train IoU : 0.9007 | Val IoU : 0.6172
#
# ============================================================
# Training Completed!
# Best Epoch: 64
# Best Val Loss: 0.1645
# ============================================================
# Loading best model...
# Evaluating on test set...
# Evaluating Test Set: 100%|██████████| 9/9 [00:02<00:00,  3.32it/s]
# ========================================
# TEST SET EVALUATION
# ========================================
# Dice Coefficient: 0.7989
# IoU (Jaccard):    0.6790
# ========================================
#
# Generating visualizations...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.2042701].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0836544..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Evaluation completed successfully!
