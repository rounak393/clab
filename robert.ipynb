# %% [markdown]
# <a href="https://colab.research.google.com/github/rounak393/clab/blob/main/robert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import glob
import copy
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Subset
import albumentations as A
from torchinfo import summary

warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


BATCH_SIZE = 8
EPOCHS = 100
LR = 1e-4
IMG_SIZE = 256
SEED = 42
SAVE_PATH = "/kaggle/working/best_native_roberts_unet.pth"
BASE_DIR = "/kaggle/input/datasets/britikak/busi-dataset/Dataset_BUSI_with_GT"

CLASSES = ["benign", "malignant"]

torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.backends.cudnn.benchmark = True




train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

test_transform = val_transform

class BasicBUSIDataset(Dataset):
    def __init__(self, base_dir, classes, transform=None):
        self.samples = []
        self.transform = transform

        for cls in classes:
            cls_dir = os.path.join(base_dir, cls)
            images = [f for f in os.listdir(cls_dir) if f.endswith(".png") and "_mask" not in f]

            for img_name in images:
                img_path = os.path.join(cls_dir, img_name)
                base_name = img_name.replace(".png", "")
                mask_files = [f for f in os.listdir(cls_dir) if f.startswith(base_name + "_mask") and f.endswith(".png")]

                if len(mask_files) == 0: continue

                mask_paths = [os.path.join(cls_dir, f) for f in mask_files]
                self.samples.append((img_path, mask_paths))

        assert len(self.samples) > 0, "No valid image-mask pairs found!"

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, mask_paths = self.samples[idx]

        # Load Standard RGB Image
        image = np.array(Image.open(img_path).convert("RGB"))

        combined_mask = np.zeros(image.shape[:2], dtype=np.uint8)
        for mpath in mask_paths:
            mask = np.array(Image.open(mpath).convert("L"))
            mask = (mask > 0).astype(np.uint8)
            combined_mask = np.logical_or(combined_mask, mask)

        combined_mask = combined_mask.astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=combined_mask)
            image = augmented["image"]
            combined_mask = augmented["mask"]

        combined_mask = (combined_mask > 0.5).astype(np.float32)

        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(combined_mask).unsqueeze(0).float()

        return image, mask

full_dataset = BasicBUSIDataset(BASE_DIR, classes=CLASSES, transform=None)
total_size = len(full_dataset)
indices = list(range(total_size))

np.random.shuffle(indices)

train_size = int(0.8 * total_size)
val_size   = int(0.1 * total_size)

val_indices = indices[:val_size]
train_indices   = indices[val_size:train_size + val_size]
test_indices  = indices[train_size + val_size:]

train_dataset = Subset(BasicBUSIDataset(BASE_DIR, CLASSES, transform=train_transform), train_indices)
val_dataset = Subset(BasicBUSIDataset(BASE_DIR, CLASSES, transform=val_transform), val_indices)
test_dataset = Subset(BasicBUSIDataset(BASE_DIR, CLASSES, transform=test_transform), test_indices)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)




class RobertsEdgeOperator(nn.Module):
    def __init__(self):
        super().__init__()
        # 2x2 Roberts Cross Kernels
        kx = torch.tensor([[[[1.0, 0.0], [0.0, -1.0]]]])
        ky = torch.tensor([[[[0.0, 1.0], [-1.0, 0.0]]]])

        # Registers to GPU automatically, optimizer ignores them
        self.register_buffer('kx', kx)
        self.register_buffer('ky', ky)

    def forward(self, x):
        # Convert RGB to Grayscale
        gray = 0.2989 * x[:, 0:1, :, :] + 0.5870 * x[:, 1:2, :, :] + 0.1140 * x[:, 2:3, :, :]

        # Pad to preserve 256x256 dimensions during 2x2 convolution
        gray_padded = F.pad(gray, (0, 1, 0, 1), mode='replicate')

        grad_x = F.conv2d(gray_padded, self.kx)
        grad_y = F.conv2d(gray_padded, self.ky)

        # Calculate Magnitude
        edge = torch.sqrt(grad_x**2 + grad_y**2 + 1e-8)

        # Duplicate to 3 channels for the Encoder
        return edge.repeat(1, 3, 1, 1)

# ==========================================
# 4. U-NET ARCHITECTURE
# ==========================================
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )
    def forward(self, x): return self.double_conv(x)

class UNet(nn.Module):
    def __init__(self, n_channels=3, n_classes=1):
        super().__init__()

        # Inject the Native Roberts Layer
        self.roberts = RobertsEdgeOperator()

        self.enc1 = DoubleConv(n_channels, 64)
        self.enc2 = DoubleConv(64, 128)
        self.enc3 = DoubleConv(128, 256)
        self.enc4 = DoubleConv(256, 512)
        self.pool = nn.MaxPool2d(2)

        self.bottleneck = DoubleConv(512, 1024)

        self.up1 = nn.ConvTranspose2d(1024, 512, 2, stride=2)
        self.dec1 = DoubleConv(1024, 512)
        self.up2 = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec2 = DoubleConv(512, 256)
        self.up3 = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec3 = DoubleConv(256, 128)
        self.up4 = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec4 = DoubleConv(128, 64)
        self.final = nn.Conv2d(64, n_classes, 1)

    def forward(self, x):
        # 1. Transform Raw Image to Edge Map natively on the GPU
        x_edge = self.roberts(x)

        # 2. Standard U-Net Path using the Edge Map
        c1 = self.enc1(x_edge)
        c2 = self.enc2(self.pool(c1))
        c3 = self.enc3(self.pool(c2))
        c4 = self.enc4(self.pool(c3))
        b = self.bottleneck(self.pool(c4))

        d1 = self.up1(b)
        d1 = torch.cat([d1, c4], dim=1)
        d1 = self.dec1(d1)

        d2 = self.up2(d1)
        d2 = torch.cat([d2, c3], dim=1)
        d2 = self.dec2(d2)

        d3 = self.up3(d2)
        d3 = torch.cat([d3, c2], dim=1)
        d3 = self.dec3(d3)

        d4 = self.up4(d3)
        d4 = torch.cat([d4, c1], dim=1)
        d4 = self.dec4(d4)

        return torch.sigmoid(self.final(d4))

if __name__ == "__main__":
    model = UNet(n_channels=3, n_classes=1).to(device)
    print("\n================= MODEL SUMMARY =================\n")
    print(summary(model, input_size=(BATCH_SIZE, 3, IMG_SIZE, IMG_SIZE)))

# ==========================================
# 5. LOSS & METRICS
# ==========================================
class BCEDiceLoss(nn.Module):
    def __init__(self, smooth=1e-5):
        super().__init__()
        self.smooth = smooth
        self.bce = nn.BCELoss()

    def forward(self, preds, targets):
        bce_loss = self.bce(preds, targets)
        preds_f = preds.view(-1)
        targets_f = targets.view(-1)
        inter = (preds_f * targets_f).sum()
        dice_loss = 1 - (2 * inter + self.smooth) / (preds_f.sum() + targets_f.sum() + self.smooth)
        return 0.5 * bce_loss + 0.5 * dice_loss

def dice_coef(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    inter = (y_true_f * y_pred_f).sum()
    return (2. * inter + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

def iou_score(preds, masks, threshold=0.5, eps=1e-6):
    preds_bin = (preds > threshold).float()
    masks_bin = (masks > threshold).float()
    inter = (preds_bin * masks_bin).sum().item()
    union = preds_bin.sum().item() + masks_bin.sum().item() - inter
    return inter / (union + eps)

# ==========================================
# 6. TRAINING ENGINE
# ==========================================
def train_model(model, train_loader, val_loader, epochs=100):
    criterion = BCEDiceLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=10, min_lr=1e-6)

    train_losses, val_losses = [], []
    train_dice_scores, val_dice_scores = [], []
    train_iou_scores, val_iou_scores = [], []

    best_val_loss = float("inf")
    best_epoch = 0
    best_model_weights = None

    for epoch in range(epochs):
        model.train()
        train_loss = train_dice = train_iou = 0
        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs} [Train]"):
            images, masks = images.to(device), masks.to(device)

            preds = model(images)
            loss = criterion(preds, masks)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_dice += dice_coef(masks, preds).item()
            train_iou += iou_score(preds, masks)

        model.eval()
        val_loss = val_dice = val_iou = 0
        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc=f"Epoch {epoch+1}/{epochs} [Val]"):
                images, masks = images.to(device), masks.to(device)
                preds = model(images)
                val_loss += criterion(preds, masks).item()
                val_dice += dice_coef(masks, preds).item()
                val_iou += iou_score(preds, masks)

        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        avg_train_dice = train_dice / len(train_loader)
        avg_val_dice   = val_dice / len(val_loader)
        avg_train_iou  = train_iou / len(train_loader)
        avg_val_iou    = val_iou / len(val_loader)

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_dice_scores.append(avg_train_dice)
        val_dice_scores.append(avg_val_dice)
        train_iou_scores.append(avg_train_iou)
        val_iou_scores.append(avg_val_iou)

        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
        print(f"Train Dice: {avg_train_dice:.4f} | Val Dice: {avg_val_dice:.4f}")
        print(f"Train IoU : {avg_train_iou:.4f} | Val IoU : {avg_val_iou:.4f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch + 1
            best_model_weights = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), SAVE_PATH)
            print(f"✓ Best model saved (Epoch {epoch+1}, Val Loss {best_val_loss:.4f})")

        scheduler.step(avg_val_loss)

    model.load_state_dict(best_model_weights)

    print("\n" + "="*60)
    print("Training Completed!")
    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val Loss: {best_val_loss:.4f}")
    print("="*60)

    return {
        "train_losses": train_losses, "val_losses": val_losses,
        "train_dice": train_dice_scores, "val_dice": val_dice_scores,
        "train_iou": train_iou_scores, "val_iou": val_iou_scores,
    }

def plot_training(history):
    plt.figure(figsize=(17, 4))
    plt.subplot(1, 3, 1)
    plt.plot(history["train_losses"], label="Train Loss", linewidth=2)
    plt.plot(history["val_losses"], label="Val Loss", linewidth=2)
    plt.title("Loss Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 2)
    plt.plot(history["train_dice"], label="Train Dice", linewidth=2)
    plt.plot(history["val_dice"], label="Val Dice", linewidth=2)
    plt.title("Dice Coefficient Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 3)
    plt.plot(history["train_iou"], label="Train IoU", linewidth=2)
    plt.plot(history["val_iou"], label="Val IoU", linewidth=2)
    plt.title("IoU Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("IoU Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=300, bbox_inches='tight')
    plt.show()

history = train_model(model, train_loader, val_loader, epochs=EPOCHS)
plot_training(history)

# ==========================================
# 7. UNSEEN TEST SET EVALUATION
# ==========================================
def iou_coef_test(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    intersection = (y_true_f * y_pred_f).sum()
    union = y_true_f.sum() + y_pred_f.sum() - intersection
    return (intersection + smooth) / (union + smooth)

print("Loading best model...")
model.load_state_dict(torch.load(SAVE_PATH, map_location=device))
model.eval()

test_dice, test_iou = 0, 0
print("Evaluating on test set...")
with torch.no_grad():
    for images, masks in tqdm(test_loader, desc="Evaluating Test Set"):
        images, masks = images.to(device), masks.to(device)
        preds = model(images)
        preds_bin = (preds > 0.4).float()
        test_dice += dice_coef(masks, preds_bin).item()
        test_iou += iou_coef_test(masks, preds_bin).item()

avg_test_dice = test_dice / len(test_loader)
avg_test_iou = test_iou / len(test_loader)

print("\n" + "="*40)
print("TEST SET EVALUATION")
print("="*40)
print(f"Dice Coefficient: {avg_test_dice:.4f}")
print(f"IoU (Jaccard):    {avg_test_iou:.4f}")
print("="*40)

# ==========================================
# 8. VISUALIZATION
# ==========================================
def dice_coef_single(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

def iou_coef_single(y_true, y_pred, smooth=1e-5):
    intersection = np.sum(y_true * y_pred)
    union = np.sum(y_true) + np.sum(y_pred) - intersection
    return intersection / (union + smooth)

def visualize_predictions_simple(model, dataset, num_samples=5, threshold=0.5):
    indices = random.sample(range(len(dataset)), num_samples)
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, num_samples * 4))

    if num_samples == 1:
        axes = axes.reshape(1, -1)

    for i, idx in enumerate(indices):
        image, mask = dataset[idx]

        with torch.no_grad():
            image_tensor = image.unsqueeze(0).to(device)
            pred_prob = model(image_tensor).cpu().squeeze().numpy()

            # Extract the Roberts edge map internally just for the visualization plot
            edge_map_vis = model.roberts(image_tensor).cpu().squeeze().numpy()[0] # take 1 channel

        pred_mask = (pred_prob > threshold).astype(np.uint8)
        true_mask = mask.squeeze().numpy().astype(np.uint8)

        dice_score = dice_coef_single(true_mask, pred_mask) * 100
        iou_score = iou_coef_single(true_mask, pred_mask) * 100

        error_map = np.zeros((*true_mask.shape, 3), dtype=np.uint8)
        true_positive = (true_mask == 1) & (pred_mask == 1)
        false_positive = (true_mask == 0) & (pred_mask == 1)
        false_negative = (true_mask == 1) & (pred_mask == 0)

        error_map[true_positive] = [255, 255, 255]
        error_map[false_positive] = [255, 0, 0]
        error_map[false_negative] = [0, 0, 255]

        # Plot 1: Show the Roberts Edge Map that the Encoder actually sees
        axes[i, 0].imshow(edge_map_vis, cmap='gray')
        axes[i, 0].set_title(f"Roberts Edge Input {idx}")
        axes[i, 0].axis("off")

        axes[i, 1].imshow(true_mask, cmap="gray")
        axes[i, 1].set_title("Ground Truth")
        axes[i, 1].axis("off")

        axes[i, 2].imshow(pred_mask, cmap="gray")
        axes[i, 2].set_title(f"Prediction\nDice: {dice_score:.1f}% | IoU: {iou_score:.1f}%")
        axes[i, 2].axis("off")

        axes[i, 3].imshow(error_map)
        axes[i, 3].set_title("Error Analysis\n(Red: FP, Blue: FN)")
        axes[i, 3].axis("off")

        if i == 0:
            from matplotlib.patches import Patch
            legend_elements = [
                Patch(facecolor='white', label='True Positive'),
                Patch(facecolor='red', label='False Positive'),
                Patch(facecolor='blue', label='False Negative')
            ]
            axes[i, 3].legend(handles=legend_elements, loc='upper right', fontsize=8)

    plt.tight_layout()
    plt.show()
    return indices

print("\nGenerating visualizations...")
sampled_indices = visualize_predictions_simple(model, test_dataset, num_samples=7)
print("\nEvaluation completed successfully!")
# Out:
# Using device: cuda
#
# ================= MODEL SUMMARY =================
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# UNet                                     [8, 1, 256, 256]          --
# ├─RobertsEdgeOperator: 1-1               [8, 3, 256, 256]          --
# ├─DoubleConv: 1-2                        [8, 64, 256, 256]         --
# │    └─Sequential: 2-1                   [8, 64, 256, 256]         --
# │    │    └─Conv2d: 3-1                  [8, 64, 256, 256]         1,792
# │    │    └─BatchNorm2d: 3-2             [8, 64, 256, 256]         128
# │    │    └─ReLU: 3-3                    [8, 64, 256, 256]         --
# │    │    └─Conv2d: 3-4                  [8, 64, 256, 256]         36,928
# │    │    └─BatchNorm2d: 3-5             [8, 64, 256, 256]         128
# │    │    └─ReLU: 3-6                    [8, 64, 256, 256]         --
# ├─MaxPool2d: 1-3                         [8, 64, 128, 128]         --
# ├─DoubleConv: 1-4                        [8, 128, 128, 128]        --
# │    └─Sequential: 2-2                   [8, 128, 128, 128]        --
# │    │    └─Conv2d: 3-7                  [8, 128, 128, 128]        73,856
# │    │    └─BatchNorm2d: 3-8             [8, 128, 128, 128]        256
# │    │    └─ReLU: 3-9                    [8, 128, 128, 128]        --
# │    │    └─Conv2d: 3-10                 [8, 128, 128, 128]        147,584
# │    │    └─BatchNorm2d: 3-11            [8, 128, 128, 128]        256
# │    │    └─ReLU: 3-12                   [8, 128, 128, 128]        --
# ├─MaxPool2d: 1-5                         [8, 128, 64, 64]          --
# ├─DoubleConv: 1-6                        [8, 256, 64, 64]          --
# │    └─Sequential: 2-3                   [8, 256, 64, 64]          --
# │    │    └─Conv2d: 3-13                 [8, 256, 64, 64]          295,168
# │    │    └─BatchNorm2d: 3-14            [8, 256, 64, 64]          512
# │    │    └─ReLU: 3-15                   [8, 256, 64, 64]          --
# │    │    └─Conv2d: 3-16                 [8, 256, 64, 64]          590,080
# │    │    └─BatchNorm2d: 3-17            [8, 256, 64, 64]          512
# │    │    └─ReLU: 3-18                   [8, 256, 64, 64]          --
# ├─MaxPool2d: 1-7                         [8, 256, 32, 32]          --
# ├─DoubleConv: 1-8                        [8, 512, 32, 32]          --
# │    └─Sequential: 2-4                   [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-19                 [8, 512, 32, 32]          1,180,160
# │    │    └─BatchNorm2d: 3-20            [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-21                   [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-22                 [8, 512, 32, 32]          2,359,808
# │    │    └─BatchNorm2d: 3-23            [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-24                   [8, 512, 32, 32]          --
# ├─MaxPool2d: 1-9                         [8, 512, 16, 16]          --
# ├─DoubleConv: 1-10                       [8, 1024, 16, 16]         --
# │    └─Sequential: 2-5                   [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-25                 [8, 1024, 16, 16]         4,719,616
# │    │    └─BatchNorm2d: 3-26            [8, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-27                   [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-28                 [8, 1024, 16, 16]         9,438,208
# │    │    └─BatchNorm2d: 3-29            [8, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-30                   [8, 1024, 16, 16]         --
# ├─ConvTranspose2d: 1-11                  [8, 512, 32, 32]          2,097,664
# ├─DoubleConv: 1-12                       [8, 512, 32, 32]          --
# │    └─Sequential: 2-6                   [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-31                 [8, 512, 32, 32]          4,719,104
# │    │    └─BatchNorm2d: 3-32            [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-33                   [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-34                 [8, 512, 32, 32]          2,359,808
# │    │    └─BatchNorm2d: 3-35            [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-36                   [8, 512, 32, 32]          --
# ├─ConvTranspose2d: 1-13                  [8, 256, 64, 64]          524,544
# ├─DoubleConv: 1-14                       [8, 256, 64, 64]          --
# │    └─Sequential: 2-7                   [8, 256, 64, 64]          --
# │    │    └─Conv2d: 3-37                 [8, 256, 64, 64]          1,179,904
# │    │    └─BatchNorm2d: 3-38            [8, 256, 64, 64]          512
# │    │    └─ReLU: 3-39                   [8, 256, 64, 64]          --
# │    │    └─Conv2d: 3-40                 [8, 256, 64, 64]          590,080
# │    │    └─BatchNorm2d: 3-41            [8, 256, 64, 64]          512
# │    │    └─ReLU: 3-42                   [8, 256, 64, 64]          --
# ├─ConvTranspose2d: 1-15                  [8, 128, 128, 128]        131,200
# ├─DoubleConv: 1-16                       [8, 128, 128, 128]        --
# │    └─Sequential: 2-8                   [8, 128, 128, 128]        --
# │    │    └─Conv2d: 3-43                 [8, 128, 128, 128]        295,040
# │    │    └─BatchNorm2d: 3-44            [8, 128, 128, 128]        256
# │    │    └─ReLU: 3-45                   [8, 128, 128, 128]        --
# │    │    └─Conv2d: 3-46                 [8, 128, 128, 128]        147,584
# │    │    └─BatchNorm2d: 3-47            [8, 128, 128, 128]        256
# │    │    └─ReLU: 3-48                   [8, 128, 128, 128]        --
# ├─ConvTranspose2d: 1-17                  [8, 64, 256, 256]         32,832
# ├─DoubleConv: 1-18                       [8, 64, 256, 256]         --
# │    └─Sequential: 2-9                   [8, 64, 256, 256]         --
# │    │    └─Conv2d: 3-49                 [8, 64, 256, 256]         73,792
# │    │    └─BatchNorm2d: 3-50            [8, 64, 256, 256]         128
# │    │    └─ReLU: 3-51                   [8, 64, 256, 256]         --
# │    │    └─Conv2d: 3-52                 [8, 64, 256, 256]         36,928
# │    │    └─BatchNorm2d: 3-53            [8, 64, 256, 256]         128
# │    │    └─ReLU: 3-54                   [8, 64, 256, 256]         --
# ├─Conv2d: 1-19                           [8, 1, 256, 256]          65
# ==========================================================================================
# Total params: 31,043,521
# Trainable params: 31,043,521
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 437.20
# ==========================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 4601.15
# Params size (MB): 124.17
# Estimated Total Size (MB): 4731.62
# ==========================================================================================
# Epoch 1/100 [Train]: 100%|██████████| 65/65 [01:01<00:00,  1.06it/s]
# Epoch 1/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.48it/s]
# Epoch 1/100
# Train Loss: 0.6502 | Val Loss: 0.7086
# Train Dice: 0.1810 | Val Dice: 0.2283
# Train IoU : 0.1332 | Val IoU : 0.1874
# ✓ Best model saved (Epoch 1, Val Loss 0.7086)
# Epoch 2/100 [Train]: 100%|██████████| 65/65 [00:36<00:00,  1.78it/s]
# Epoch 2/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.56it/s]
# Epoch 2/100
# Train Loss: 0.5648 | Val Loss: 1.3120
# Train Dice: 0.2480 | Val Dice: 0.2304
# Train IoU : 0.2572 | Val IoU : 0.1518
# Epoch 3/100 [Train]: 100%|██████████| 65/65 [00:34<00:00,  1.88it/s]
# Epoch 3/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.72it/s]
# Epoch 3/100
# Train Loss: 0.5199 | Val Loss: 0.5108
# Train Dice: 0.2891 | Val Dice: 0.3175
# Train IoU : 0.3168 | Val IoU : 0.3065
# ✓ Best model saved (Epoch 3, Val Loss 0.5108)
# Epoch 4/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 4/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.56it/s]
# Epoch 4/100
# Train Loss: 0.4953 | Val Loss: 0.4801
# Train Dice: 0.3145 | Val Dice: 0.3100
# Train IoU : 0.3285 | Val IoU : 0.3534
# ✓ Best model saved (Epoch 4, Val Loss 0.4801)
# Epoch 5/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 5/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.66it/s]
# Epoch 5/100
# Train Loss: 0.4661 | Val Loss: 0.4660
# Train Dice: 0.3466 | Val Dice: 0.3599
# Train IoU : 0.3626 | Val IoU : 0.3373
# ✓ Best model saved (Epoch 5, Val Loss 0.4660)
# Epoch 6/100 [Train]: 100%|██████████| 65/65 [00:34<00:00,  1.87it/s]
# Epoch 6/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.56it/s]
# Epoch 6/100
# Train Loss: 0.4515 | Val Loss: 0.4943
# Train Dice: 0.3631 | Val Dice: 0.3674
# Train IoU : 0.3703 | Val IoU : 0.3169
# Epoch 7/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 7/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 7/100
# Train Loss: 0.4322 | Val Loss: 0.4291
# Train Dice: 0.3876 | Val Dice: 0.3861
# Train IoU : 0.3847 | Val IoU : 0.3914
# ✓ Best model saved (Epoch 7, Val Loss 0.4291)
# Epoch 8/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 8/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 8/100
# Train Loss: 0.4162 | Val Loss: 0.4160
# Train Dice: 0.4032 | Val Dice: 0.4287
# Train IoU : 0.3925 | Val IoU : 0.3926
# ✓ Best model saved (Epoch 8, Val Loss 0.4160)
# Epoch 9/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 9/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.65it/s]
# Epoch 9/100
# Train Loss: 0.3941 | Val Loss: 0.3627
# Train Dice: 0.4343 | Val Dice: 0.4612
# Train IoU : 0.4174 | Val IoU : 0.4495
# ✓ Best model saved (Epoch 9, Val Loss 0.3627)
# Epoch 10/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 10/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.63it/s]
# Epoch 10/100
# Train Loss: 0.3804 | Val Loss: 0.3552
# Train Dice: 0.4526 | Val Dice: 0.4901
# Train IoU : 0.4285 | Val IoU : 0.4464
# ✓ Best model saved (Epoch 10, Val Loss 0.3552)
# Epoch 11/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 11/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.58it/s]
# Epoch 11/100
# Train Loss: 0.3707 | Val Loss: 0.3480
# Train Dice: 0.4662 | Val Dice: 0.4968
# Train IoU : 0.4332 | Val IoU : 0.4603
# ✓ Best model saved (Epoch 11, Val Loss 0.3480)
# Epoch 12/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 12/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.64it/s]
# Epoch 12/100
# Train Loss: 0.3555 | Val Loss: 0.3424
# Train Dice: 0.4892 | Val Dice: 0.4925
# Train IoU : 0.4467 | Val IoU : 0.4747
# ✓ Best model saved (Epoch 12, Val Loss 0.3424)
# Epoch 13/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.86it/s]
# Epoch 13/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 13/100
# Train Loss: 0.3386 | Val Loss: 0.3124
# Train Dice: 0.5164 | Val Dice: 0.5371
# Train IoU : 0.4703 | Val IoU : 0.5167
# ✓ Best model saved (Epoch 13, Val Loss 0.3124)
# Epoch 14/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.86it/s]
# Epoch 14/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 14/100
# Train Loss: 0.3320 | Val Loss: 0.2999
# Train Dice: 0.5261 | Val Dice: 0.5638
# Train IoU : 0.4761 | Val IoU : 0.5097
# ✓ Best model saved (Epoch 14, Val Loss 0.2999)
# Epoch 15/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 15/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 15/100
# Train Loss: 0.3228 | Val Loss: 0.3435
# Train Dice: 0.5418 | Val Dice: 0.5250
# Train IoU : 0.4844 | Val IoU : 0.4368
# Epoch 16/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 16/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.64it/s]
# Epoch 16/100
# Train Loss: 0.3186 | Val Loss: 0.2957
# Train Dice: 0.5458 | Val Dice: 0.5635
# Train IoU : 0.4797 | Val IoU : 0.4964
# ✓ Best model saved (Epoch 16, Val Loss 0.2957)
# Epoch 17/100 [Train]: 100%|██████████| 65/65 [00:34<00:00,  1.86it/s]
# Epoch 17/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.64it/s]
# Epoch 17/100
# Train Loss: 0.2997 | Val Loss: 0.2770
# Train Dice: 0.5767 | Val Dice: 0.5842
# Train IoU : 0.5127 | Val IoU : 0.5397
# ✓ Best model saved (Epoch 17, Val Loss 0.2770)
# Epoch 18/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.86it/s]
# Epoch 18/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 18/100
# Train Loss: 0.3039 | Val Loss: 0.2899
# Train Dice: 0.5729 | Val Dice: 0.5753
# Train IoU : 0.4953 | Val IoU : 0.4820
# Epoch 19/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 19/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 19/100
# Train Loss: 0.2914 | Val Loss: 0.3148
# Train Dice: 0.5893 | Val Dice: 0.5653
# Train IoU : 0.5141 | Val IoU : 0.4561
# Epoch 20/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 20/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.63it/s]
# Epoch 20/100
# Train Loss: 0.2885 | Val Loss: 0.3504
# Train Dice: 0.5969 | Val Dice: 0.4836
# Train IoU : 0.5190 | Val IoU : 0.3912
# Epoch 21/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 21/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 21/100
# Train Loss: 0.2876 | Val Loss: 0.2860
# Train Dice: 0.5982 | Val Dice: 0.5965
# Train IoU : 0.5162 | Val IoU : 0.4987
# Epoch 22/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 22/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 22/100
# Train Loss: 0.2798 | Val Loss: 0.2626
# Train Dice: 0.6085 | Val Dice: 0.6228
# Train IoU : 0.5209 | Val IoU : 0.5294
# ✓ Best model saved (Epoch 22, Val Loss 0.2626)
# Epoch 23/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 23/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 23/100
# Train Loss: 0.2662 | Val Loss: 0.2900
# Train Dice: 0.6300 | Val Dice: 0.6007
# Train IoU : 0.5472 | Val IoU : 0.4868
# Epoch 24/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 24/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.63it/s]
# Epoch 24/100
# Train Loss: 0.2719 | Val Loss: 0.2884
# Train Dice: 0.6253 | Val Dice: 0.6017
# Train IoU : 0.5362 | Val IoU : 0.4853
# Epoch 25/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 25/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 25/100
# Train Loss: 0.2610 | Val Loss: 0.4816
# Train Dice: 0.6405 | Val Dice: 0.4711
# Train IoU : 0.5499 | Val IoU : 0.3252
# Epoch 26/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 26/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 26/100
# Train Loss: 0.2631 | Val Loss: 0.3518
# Train Dice: 0.6357 | Val Dice: 0.5477
# Train IoU : 0.5452 | Val IoU : 0.4205
# Epoch 27/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 27/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 27/100
# Train Loss: 0.2731 | Val Loss: 0.2564
# Train Dice: 0.6270 | Val Dice: 0.6366
# Train IoU : 0.5303 | Val IoU : 0.5267
# ✓ Best model saved (Epoch 27, Val Loss 0.2564)
# Epoch 28/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 28/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 28/100
# Train Loss: 0.2671 | Val Loss: 0.2852
# Train Dice: 0.6337 | Val Dice: 0.5982
# Train IoU : 0.5384 | Val IoU : 0.4841
# Epoch 29/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 29/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 29/100
# Train Loss: 0.2410 | Val Loss: 0.2478
# Train Dice: 0.6714 | Val Dice: 0.6474
# Train IoU : 0.5783 | Val IoU : 0.5498
# ✓ Best model saved (Epoch 29, Val Loss 0.2478)
# Epoch 30/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 30/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 30/100
# Train Loss: 0.2420 | Val Loss: 0.2752
# Train Dice: 0.6674 | Val Dice: 0.6197
# Train IoU : 0.5714 | Val IoU : 0.5054
# Epoch 31/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 31/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 31/100
# Train Loss: 0.2500 | Val Loss: 0.2552
# Train Dice: 0.6618 | Val Dice: 0.6435
# Train IoU : 0.5631 | Val IoU : 0.5250
# Epoch 32/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 32/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 32/100
# Train Loss: 0.2312 | Val Loss: 0.2584
# Train Dice: 0.6846 | Val Dice: 0.6377
# Train IoU : 0.5907 | Val IoU : 0.5235
# Epoch 33/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 33/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 33/100
# Train Loss: 0.2310 | Val Loss: 0.2570
# Train Dice: 0.6861 | Val Dice: 0.6456
# Train IoU : 0.5891 | Val IoU : 0.5241
# Epoch 34/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 34/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 34/100
# Train Loss: 0.2244 | Val Loss: 0.2607
# Train Dice: 0.6973 | Val Dice: 0.6504
# Train IoU : 0.6029 | Val IoU : 0.5202
# Epoch 35/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 35/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.50it/s]
# Epoch 35/100
# Train Loss: 0.2269 | Val Loss: 0.2774
# Train Dice: 0.6939 | Val Dice: 0.6232
# Train IoU : 0.5934 | Val IoU : 0.5028
# Epoch 36/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 36/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.63it/s]
# Epoch 36/100
# Train Loss: 0.2219 | Val Loss: 0.2752
# Train Dice: 0.7043 | Val Dice: 0.6320
# Train IoU : 0.6087 | Val IoU : 0.5041
# Epoch 37/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 37/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 37/100
# Train Loss: 0.2134 | Val Loss: 0.2381
# Train Dice: 0.7132 | Val Dice: 0.6779
# Train IoU : 0.6185 | Val IoU : 0.5577
# ✓ Best model saved (Epoch 37, Val Loss 0.2381)
# Epoch 38/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 38/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 38/100
# Train Loss: 0.2188 | Val Loss: 0.2607
# Train Dice: 0.7095 | Val Dice: 0.6525
# Train IoU : 0.6085 | Val IoU : 0.5293
# Epoch 39/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 39/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.54it/s]
# Epoch 39/100
# Train Loss: 0.2187 | Val Loss: 0.2820
# Train Dice: 0.7051 | Val Dice: 0.6212
# Train IoU : 0.6062 | Val IoU : 0.4928
# Epoch 40/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 40/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.52it/s]
# Epoch 40/100
# Train Loss: 0.2140 | Val Loss: 0.2418
# Train Dice: 0.7133 | Val Dice: 0.6726
# Train IoU : 0.6149 | Val IoU : 0.5456
# Epoch 41/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 41/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 41/100
# Train Loss: 0.2237 | Val Loss: 0.2539
# Train Dice: 0.6998 | Val Dice: 0.6599
# Train IoU : 0.5997 | Val IoU : 0.5298
# Epoch 42/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 42/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.53it/s]
# Epoch 42/100
# Train Loss: 0.1999 | Val Loss: 0.2434
# Train Dice: 0.7342 | Val Dice: 0.6698
# Train IoU : 0.6378 | Val IoU : 0.5476
# Epoch 43/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 43/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 43/100
# Train Loss: 0.1949 | Val Loss: 0.2522
# Train Dice: 0.7435 | Val Dice: 0.6630
# Train IoU : 0.6437 | Val IoU : 0.5376
# Epoch 44/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 44/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 44/100
# Train Loss: 0.1979 | Val Loss: 0.2334
# Train Dice: 0.7368 | Val Dice: 0.6781
# Train IoU : 0.6378 | Val IoU : 0.5551
# ✓ Best model saved (Epoch 44, Val Loss 0.2334)
# Epoch 45/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 45/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 45/100
# Train Loss: 0.2022 | Val Loss: 0.2387
# Train Dice: 0.7329 | Val Dice: 0.6758
# Train IoU : 0.6328 | Val IoU : 0.5528
# Epoch 46/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 46/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 46/100
# Train Loss: 0.1872 | Val Loss: 0.2651
# Train Dice: 0.7511 | Val Dice: 0.6507
# Train IoU : 0.6561 | Val IoU : 0.5127
# Epoch 47/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 47/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.65it/s]
# Epoch 47/100
# Train Loss: 0.1873 | Val Loss: 0.2446
# Train Dice: 0.7519 | Val Dice: 0.6734
# Train IoU : 0.6505 | Val IoU : 0.5455
# Epoch 48/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 48/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 48/100
# Train Loss: 0.1943 | Val Loss: 0.2437
# Train Dice: 0.7432 | Val Dice: 0.6610
# Train IoU : 0.6463 | Val IoU : 0.5345
# Epoch 49/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 49/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.54it/s]
# Epoch 49/100
# Train Loss: 0.1788 | Val Loss: 0.2789
# Train Dice: 0.7610 | Val Dice: 0.6261
# Train IoU : 0.6668 | Val IoU : 0.4937
# Epoch 50/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 50/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 50/100
# Train Loss: 0.1830 | Val Loss: 0.2684
# Train Dice: 0.7561 | Val Dice: 0.6484
# Train IoU : 0.6584 | Val IoU : 0.5116
# Epoch 51/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 51/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.62it/s]
# Epoch 51/100
# Train Loss: 0.1862 | Val Loss: 0.2666
# Train Dice: 0.7522 | Val Dice: 0.6458
# Train IoU : 0.6564 | Val IoU : 0.5129
# Epoch 52/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 52/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 52/100
# Train Loss: 0.1924 | Val Loss: 0.2599
# Train Dice: 0.7439 | Val Dice: 0.6528
# Train IoU : 0.6431 | Val IoU : 0.5156
# Epoch 53/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 53/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.64it/s]
# Epoch 53/100
# Train Loss: 0.1824 | Val Loss: 0.2395
# Train Dice: 0.7599 | Val Dice: 0.6641
# Train IoU : 0.6642 | Val IoU : 0.5499
# Epoch 54/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 54/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 54/100
# Train Loss: 0.1739 | Val Loss: 0.2348
# Train Dice: 0.7713 | Val Dice: 0.6778
# Train IoU : 0.6773 | Val IoU : 0.5545
# Epoch 55/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 55/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 55/100
# Train Loss: 0.1731 | Val Loss: 0.2301
# Train Dice: 0.7716 | Val Dice: 0.6845
# Train IoU : 0.6776 | Val IoU : 0.5627
# ✓ Best model saved (Epoch 55, Val Loss 0.2301)
# Epoch 56/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 56/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.51it/s]
# Epoch 56/100
# Train Loss: 0.1666 | Val Loss: 0.2535
# Train Dice: 0.7806 | Val Dice: 0.6635
# Train IoU : 0.6872 | Val IoU : 0.5323
# Epoch 57/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 57/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 57/100
# Train Loss: 0.1723 | Val Loss: 0.2314
# Train Dice: 0.7739 | Val Dice: 0.6903
# Train IoU : 0.6803 | Val IoU : 0.5634
# Epoch 58/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 58/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 58/100
# Train Loss: 0.1708 | Val Loss: 0.2459
# Train Dice: 0.7759 | Val Dice: 0.6672
# Train IoU : 0.6800 | Val IoU : 0.5393
# Epoch 59/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 59/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 59/100
# Train Loss: 0.1702 | Val Loss: 0.2567
# Train Dice: 0.7758 | Val Dice: 0.6711
# Train IoU : 0.6816 | Val IoU : 0.5318
# Epoch 60/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 60/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 60/100
# Train Loss: 0.1728 | Val Loss: 0.2483
# Train Dice: 0.7736 | Val Dice: 0.6702
# Train IoU : 0.6770 | Val IoU : 0.5336
# Epoch 61/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 61/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 61/100
# Train Loss: 0.1666 | Val Loss: 0.2418
# Train Dice: 0.7789 | Val Dice: 0.6813
# Train IoU : 0.6841 | Val IoU : 0.5495
# Epoch 62/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 62/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.48it/s]
# Epoch 62/100
# Train Loss: 0.1622 | Val Loss: 0.2606
# Train Dice: 0.7871 | Val Dice: 0.6671
# Train IoU : 0.6926 | Val IoU : 0.5307
# Epoch 63/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 63/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.56it/s]
# Epoch 63/100
# Train Loss: 0.1605 | Val Loss: 0.2602
# Train Dice: 0.7926 | Val Dice: 0.6597
# Train IoU : 0.6996 | Val IoU : 0.5253
# Epoch 64/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 64/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 64/100
# Train Loss: 0.1587 | Val Loss: 0.2645
# Train Dice: 0.7932 | Val Dice: 0.6609
# Train IoU : 0.7003 | Val IoU : 0.5228
# Epoch 65/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 65/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 65/100
# Train Loss: 0.1595 | Val Loss: 0.2274
# Train Dice: 0.7900 | Val Dice: 0.6890
# Train IoU : 0.6985 | Val IoU : 0.5604
# ✓ Best model saved (Epoch 65, Val Loss 0.2274)
# Epoch 66/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 66/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 66/100
# Train Loss: 0.1599 | Val Loss: 0.2323
# Train Dice: 0.7901 | Val Dice: 0.6930
# Train IoU : 0.6969 | Val IoU : 0.5604
# Epoch 67/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 67/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.53it/s]
# Epoch 67/100
# Train Loss: 0.1569 | Val Loss: 0.2608
# Train Dice: 0.7937 | Val Dice: 0.6649
# Train IoU : 0.7022 | Val IoU : 0.5290
# Epoch 68/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 68/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 68/100
# Train Loss: 0.1477 | Val Loss: 0.2492
# Train Dice: 0.8086 | Val Dice: 0.6774
# Train IoU : 0.7184 | Val IoU : 0.5429
# Epoch 69/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 69/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 69/100
# Train Loss: 0.1466 | Val Loss: 0.2378
# Train Dice: 0.8082 | Val Dice: 0.6851
# Train IoU : 0.7206 | Val IoU : 0.5628
# Epoch 70/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 70/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.54it/s]
# Epoch 70/100
# Train Loss: 0.1495 | Val Loss: 0.2615
# Train Dice: 0.8059 | Val Dice: 0.6674
# Train IoU : 0.7163 | Val IoU : 0.5383
# Epoch 71/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 71/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 71/100
# Train Loss: 0.1437 | Val Loss: 0.2463
# Train Dice: 0.8150 | Val Dice: 0.6798
# Train IoU : 0.7269 | Val IoU : 0.5497
# Epoch 72/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 72/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.63it/s]
# Epoch 72/100
# Train Loss: 0.1521 | Val Loss: 0.2715
# Train Dice: 0.8007 | Val Dice: 0.6514
# Train IoU : 0.7095 | Val IoU : 0.5205
# Epoch 73/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 73/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 73/100
# Train Loss: 0.1485 | Val Loss: 0.2711
# Train Dice: 0.8059 | Val Dice: 0.6446
# Train IoU : 0.7165 | Val IoU : 0.5122
# Epoch 74/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 74/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.63it/s]
# Epoch 74/100
# Train Loss: 0.1417 | Val Loss: 0.2513
# Train Dice: 0.8161 | Val Dice: 0.6723
# Train IoU : 0.7310 | Val IoU : 0.5382
# Epoch 75/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 75/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.56it/s]
# Epoch 75/100
# Train Loss: 0.1560 | Val Loss: 0.2730
# Train Dice: 0.7969 | Val Dice: 0.6525
# Train IoU : 0.7051 | Val IoU : 0.5111
# Epoch 76/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 76/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.49it/s]
# Epoch 76/100
# Train Loss: 0.1464 | Val Loss: 0.2904
# Train Dice: 0.8095 | Val Dice: 0.6412
# Train IoU : 0.7228 | Val IoU : 0.4978
# Epoch 77/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 77/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 77/100
# Train Loss: 0.1344 | Val Loss: 0.2567
# Train Dice: 0.8230 | Val Dice: 0.6677
# Train IoU : 0.7409 | Val IoU : 0.5312
# Epoch 78/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 78/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 78/100
# Train Loss: 0.1179 | Val Loss: 0.2279
# Train Dice: 0.8450 | Val Dice: 0.6985
# Train IoU : 0.7688 | Val IoU : 0.5677
# Epoch 79/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 79/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 79/100
# Train Loss: 0.1236 | Val Loss: 0.2385
# Train Dice: 0.8386 | Val Dice: 0.6897
# Train IoU : 0.7595 | Val IoU : 0.5502
# Epoch 80/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 80/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.63it/s]
# Epoch 80/100
# Train Loss: 0.1193 | Val Loss: 0.2575
# Train Dice: 0.8440 | Val Dice: 0.6666
# Train IoU : 0.7658 | Val IoU : 0.5250
# Epoch 81/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 81/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.58it/s]
# Epoch 81/100
# Train Loss: 0.1284 | Val Loss: 0.2587
# Train Dice: 0.8355 | Val Dice: 0.6706
# Train IoU : 0.7569 | Val IoU : 0.5274
# Epoch 82/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.85it/s]
# Epoch 82/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 82/100
# Train Loss: 0.1130 | Val Loss: 0.2446
# Train Dice: 0.8528 | Val Dice: 0.6831
# Train IoU : 0.7767 | Val IoU : 0.5434
# Epoch 83/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 83/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 83/100
# Train Loss: 0.1182 | Val Loss: 0.2269
# Train Dice: 0.8482 | Val Dice: 0.7001
# Train IoU : 0.7722 | Val IoU : 0.5715
# ✓ Best model saved (Epoch 83, Val Loss 0.2269)
# Epoch 84/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 84/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.58it/s]
# Epoch 84/100
# Train Loss: 0.1124 | Val Loss: 0.2394
# Train Dice: 0.8525 | Val Dice: 0.6941
# Train IoU : 0.7792 | Val IoU : 0.5553
# Epoch 85/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 85/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 85/100
# Train Loss: 0.1031 | Val Loss: 0.2657
# Train Dice: 0.8636 | Val Dice: 0.6601
# Train IoU : 0.7945 | Val IoU : 0.5230
# Epoch 86/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 86/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 86/100
# Train Loss: 0.1196 | Val Loss: 0.2437
# Train Dice: 0.8427 | Val Dice: 0.6855
# Train IoU : 0.7652 | Val IoU : 0.5465
# Epoch 87/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 87/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 87/100
# Train Loss: 0.1197 | Val Loss: 0.2577
# Train Dice: 0.8396 | Val Dice: 0.6695
# Train IoU : 0.7613 | Val IoU : 0.5249
# Epoch 88/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 88/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.56it/s]
# Epoch 88/100
# Train Loss: 0.1063 | Val Loss: 0.2867
# Train Dice: 0.8611 | Val Dice: 0.6503
# Train IoU : 0.7902 | Val IoU : 0.5053
# Epoch 89/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 89/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 89/100
# Train Loss: 0.1099 | Val Loss: 0.2488
# Train Dice: 0.8584 | Val Dice: 0.6877
# Train IoU : 0.7833 | Val IoU : 0.5476
# Epoch 90/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 90/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 90/100
# Train Loss: 0.1103 | Val Loss: 0.2532
# Train Dice: 0.8549 | Val Dice: 0.6796
# Train IoU : 0.7789 | Val IoU : 0.5394
# Epoch 91/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 91/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.46it/s]
# Epoch 91/100
# Train Loss: 0.1068 | Val Loss: 0.2595
# Train Dice: 0.8610 | Val Dice: 0.6678
# Train IoU : 0.7899 | Val IoU : 0.5268
# Epoch 92/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 92/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 92/100
# Train Loss: 0.1091 | Val Loss: 0.2371
# Train Dice: 0.8579 | Val Dice: 0.6945
# Train IoU : 0.7834 | Val IoU : 0.5616
# Epoch 93/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 93/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.60it/s]
# Epoch 93/100
# Train Loss: 0.1151 | Val Loss: 0.2372
# Train Dice: 0.8498 | Val Dice: 0.6958
# Train IoU : 0.7759 | Val IoU : 0.5623
# Epoch 94/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 94/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.59it/s]
# Epoch 94/100
# Train Loss: 0.1171 | Val Loss: 0.2599
# Train Dice: 0.8475 | Val Dice: 0.6702
# Train IoU : 0.7714 | Val IoU : 0.5282
# Epoch 95/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 95/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.61it/s]
# Epoch 95/100
# Train Loss: 0.0993 | Val Loss: 0.2468
# Train Dice: 0.8683 | Val Dice: 0.6931
# Train IoU : 0.7994 | Val IoU : 0.5504
# Epoch 96/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 96/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 96/100
# Train Loss: 0.0988 | Val Loss: 0.2456
# Train Dice: 0.8730 | Val Dice: 0.6862
# Train IoU : 0.8040 | Val IoU : 0.5449
# Epoch 97/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 97/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.57it/s]
# Epoch 97/100
# Train Loss: 0.0970 | Val Loss: 0.2512
# Train Dice: 0.8726 | Val Dice: 0.6849
# Train IoU : 0.8045 | Val IoU : 0.5418
# Epoch 98/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.83it/s]
# Epoch 98/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.58it/s]
# Epoch 98/100
# Train Loss: 0.1083 | Val Loss: 0.2299
# Train Dice: 0.8602 | Val Dice: 0.7111
# Train IoU : 0.7870 | Val IoU : 0.5728
# Epoch 99/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 99/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.55it/s]
# Epoch 99/100
# Train Loss: 0.0968 | Val Loss: 0.2443
# Train Dice: 0.8712 | Val Dice: 0.6954
# Train IoU : 0.8044 | Val IoU : 0.5552
# Epoch 100/100 [Train]: 100%|██████████| 65/65 [00:35<00:00,  1.84it/s]
# Epoch 100/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  4.54it/s]
# Epoch 100/100
# Train Loss: 0.0948 | Val Loss: 0.2562
# Train Dice: 0.8765 | Val Dice: 0.6842
# Train IoU : 0.8086 | Val IoU : 0.5435
#
# ============================================================
# Training Completed!
# Best Epoch: 83
# Best Val Loss: 0.2269
# ============================================================
# Loading best model...
# Evaluating on test set...
# Evaluating Test Set: 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# ========================================
# TEST SET EVALUATION
# ========================================
# Dice Coefficient: 0.7122
# IoU (Jaccard):    0.5772
# ========================================
#
# Generating visualizations...
# Evaluation completed successfully!
