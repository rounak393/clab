# %% [markdown]
# <a href="https://colab.research.google.com/github/rounak393/clab/blob/main/samres4555.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install albumentations scikit-learn timm torchinfo ultralytics -q

import os
import math
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import random
import copy

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import albumentations as A
import cv2
import warnings
import torch.nn.functional as F
from torchinfo import summary
from torchvision.models import resnet34, ResNet34_Weights

warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

BASE_DIR = "/kaggle/input/datasets/britikak/busi-dataset/Dataset_BUSI_with_GT"
CLASSES = ["benign", "malignant"]
IMG_SIZE = 256
BATCH_SIZE = 8
SEED = 42

torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = True

class BUSISegmentationDataset(Dataset):
    def __init__(self, base_dir, classes, transform=None):
        self.samples = []
        self.transform = transform

        for cls in classes:
            cls_dir = os.path.join(base_dir, cls)
            if not os.path.exists(cls_dir):
                continue

            images = [
                f for f in os.listdir(cls_dir)
                if f.endswith(".png") and "_mask" not in f
            ]

            for img_name in images:
                img_path = os.path.join(cls_dir, img_name)
                base_name = img_name.replace(".png", "")

                mask_files = [
                    f for f in os.listdir(cls_dir)
                    if f.startswith(base_name + "_mask") and f.endswith(".png")
                ]

                if len(mask_files) == 0:
                    continue

                mask_paths = [os.path.join(cls_dir, f) for f in mask_files]
                self.samples.append((img_path, mask_paths))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, mask_paths = self.samples[idx]

        image = np.array(Image.open(img_path).convert("RGB"))

        combined_mask = np.zeros(image.shape[:2], dtype=np.uint8)
        for mpath in mask_paths:
            mask = np.array(Image.open(mpath).convert("L"))
            mask = (mask > 0).astype(np.uint8)
            combined_mask = np.logical_or(combined_mask, mask)

        combined_mask = combined_mask.astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=combined_mask)
            image = augmented["image"]
            combined_mask = augmented["mask"]

        combined_mask = (combined_mask > 0.5).astype(np.float32)
        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(combined_mask).unsqueeze(0).float()

        return image, mask

# ==========================================
# AUGMENTATIONS (ADDED ELASTIC DEFORMATIONS)
# ==========================================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03, p=0.5),
    A.GridDistortion(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

test_transform = val_transform

# ===================------------------------==================
full_dataset = BUSISegmentationDataset(BASE_DIR, classes=CLASSES, transform=None)
total_size = len(full_dataset)
indices = list(range(total_size))
np.random.seed(SEED)
np.random.shuffle(indices)

train_size = int(0.8 * total_size)
val_size   = int(0.1 * total_size)

val_indices = indices[:val_size]
train_indices   = indices[val_size:train_size + val_size]
test_indices  = indices[train_size + val_size:]

train_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=train_transform),
    train_indices)

val_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=val_transform),
    val_indices)

test_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=test_transform),
    test_indices)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

# ==========================================
# PATH 2: PRE-TRAINED FASTSAM GLOBAL ENCODER
# ==========================================
class FastSAMEncoder(nn.Module):
    _IN_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1)
    _IN_STD = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1)

    def __init__(self, checkpoint='FastSAM-s.pt', out_channels=512,
                 fine_tune_last=2, feature_size=4, image_size=256):
        super().__init__()
        self.out_ch = out_channels
        self.feature_size = feature_size
        self.fine_tune_last = fine_tune_last

        from ultralytics import FastSAM as _FastSAM
        print(f"[FastSAMEncoder] Loading {checkpoint} ...")
        fs = _FastSAM(checkpoint)
        all_layers = list(fs.model.model)
        del fs

        target_h = image_size // 8
        selected = []
        backbone_out_ch = None

        probe = torch.zeros(1, 3, image_size, image_size)
        with torch.no_grad():
            x = probe
            for layer in all_layers:
                x = layer(x)
                selected.append(layer)
                if x.shape[-2] == target_h:
                    backbone_out_ch = x.shape[1]
                    break

        assert backbone_out_ch is not None

        self.backbone = nn.ModuleList(selected)
        n = len(self.backbone)

        for p in self.backbone.parameters():
            p.requires_grad = False
        for layer in self.backbone[-fine_tune_last:]:
            for p in layer.parameters():
                p.requires_grad = True

        self.proj = nn.Sequential(
            nn.Conv2d(backbone_out_ch, out_channels, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

        self.register_buffer('in_mean', self._IN_MEAN)
        self.register_buffer('in_std', self._IN_STD)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x * self.in_std + self.in_mean
        frozen_end = len(self.backbone) - self.fine_tune_last
        with torch.no_grad():
            for layer in self.backbone[:frozen_end]:
                x = layer(x)
        for layer in self.backbone[frozen_end:]:
            x = layer(x)

        x = self.proj(x)
        if x.shape[-1] != self.feature_size:
            x = F.interpolate(x, size=(self.feature_size, self.feature_size),
                               mode='bilinear', align_corners=False)
        return x

# ==========================================
# CUSTOM MODULES
# ==========================================
class RobertsEdgeOperator(nn.Module):
    def __init__(self):
        super().__init__()
        kx = torch.tensor([[[[1.0, 0.0], [0.0, -1.0]]]])
        ky = torch.tensor([[[[0.0, 1.0], [-1.0, 0.0]]]])
        self.register_buffer("kx", kx)
        self.register_buffer("ky", ky)

    def forward(self, x):
        gray = (0.2989 * x[:, 0:1] + 0.5870 * x[:, 1:2] + 0.1140 * x[:, 2:3])
        gray_padded = F.pad(gray, (0, 1, 0, 1), mode="replicate")
        gx   = F.conv2d(gray_padded, self.kx)
        gy   = F.conv2d(gray_padded, self.ky)
        edge = torch.sqrt(gx ** 2 + gy ** 2 + 1e-8)
        return edge

class PCBAM_Filter(nn.Module):
    def __init__(self, in_channels, reduction=8):
        super().__init__()
        self.cam = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels)
        )
        self.sam = nn.Conv2d(2, 1, kernel_size=7, padding=3, bias=False)

    def forward(self, x):
        b, c, _, _ = x.size()
        avg = self.cam(F.adaptive_avg_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        mxp = self.cam(F.adaptive_max_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        x_c = x * torch.sigmoid(avg + mxp)

        sp  = torch.cat([
            torch.mean(x_c, dim=1, keepdim=True),
            torch.max(x_c,  dim=1, keepdim=True)[0]
        ], dim=1)
        x_s = x_c * torch.sigmoid(self.sam(sp))
        return x_s

class SpatialGateAttention(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        mid = in_channels // 8
        self.q_conv   = nn.Conv2d(in_channels, mid, 1)
        self.k_conv   = nn.Conv2d(in_channels, mid, 1)
        self.v_conv   = nn.Conv2d(in_channels, in_channels, 1)
        self.gate     = nn.Conv2d(mid * 2 + in_channels, in_channels, 1)

    def forward(self, x):
        q = self.q_conv(x)
        k = self.k_conv(x)
        v = self.v_conv(x)
        A = torch.sigmoid(self.gate(torch.cat([q, k, v], dim=1)))
        return x + v * A

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

# ADDED: Attention Gate for Decoder
class AttentionGate(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super().__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        if g1.shape[-2:] != x1.shape[-2:]:
            g1 = F.interpolate(g1, size=x1.shape[-2:], mode='bilinear', align_corners=False)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi

# ==========================================
# DUAL-PATH U-NET
# ==========================================
class PreTrainedDualPathUNet(nn.Module):
    def __init__(self, fastsam_checkpoint='FastSAM-s.pt',
                 fastsam_out_channels=512, fastsam_fine_tune_last=2):
        super().__init__()

        self.global_encoder = FastSAMEncoder(
            checkpoint=fastsam_checkpoint,
            out_channels=fastsam_out_channels,
            fine_tune_last=fastsam_fine_tune_last,
            feature_size=IMG_SIZE // 64,
            image_size=IMG_SIZE,
        )

        self.roberts = RobertsEdgeOperator()
        resnet = resnet34(weights=ResNet34_Weights.IMAGENET1K_V1)
        old_conv = resnet.conv1
        self.conv1 = nn.Conv2d(4, 64, kernel_size=7, stride=2, padding=3, bias=False)
        with torch.no_grad():
            self.conv1.weight[:, :3] = old_conv.weight
            self.conv1.weight[:, 3]  = old_conv.weight.mean(dim=1)

        self.bn1     = resnet.bn1
        self.relu    = resnet.relu
        self.maxpool = resnet.maxpool

        self.layer1 = resnet.layer1
        self.layer2 = resnet.layer2
        self.layer3 = resnet.layer3
        self.layer4 = resnet.layer4

        self.pcbam1 = PCBAM_Filter(64)
        self.pcbam2 = PCBAM_Filter(128)
        self.pcbam3 = PCBAM_Filter(256)
        self.pcbam4 = PCBAM_Filter(512)

        self.pool       = nn.MaxPool2d(2)
        self.bottleneck = DoubleConv(512, 1024)

        self.fusion = DoubleConv(1024 + fastsam_out_channels, 1024)
        self.sga    = SpatialGateAttention(1024)

        #  Attention Gates for Skip Connections
        self.ag4 = AttentionGate(F_g=512, F_l=512, F_int=256)
        self.ag3 = AttentionGate(F_g=256, F_l=256, F_int=128)
        self.ag2 = AttentionGate(F_g=128, F_l=128, F_int=64)
        self.ag1 = AttentionGate(F_g=64, F_l=64, F_int=32)

        self.up4  = nn.ConvTranspose2d(1024, 512, 2, stride=2)
        self.dec4 = DoubleConv(1024, 512)
        self.up3  = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec3 = DoubleConv(512, 256)
        self.up2  = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec2 = DoubleConv(256, 128)
        self.up1  = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec1 = DoubleConv(128, 64)
        self.up0  = nn.ConvTranspose2d(64, 64, 2, stride=2)
        self.dec0 = DoubleConv(128, 64)
        self.up_out  = nn.ConvTranspose2d(64, 32, 2, stride=2)
        self.dec_out = DoubleConv(32, 32)
        self.final   = nn.Conv2d(32, 1, 1)

        #  Auxiliary Outputs for Deep Supervision
        self.out_ds2 = nn.Conv2d(128, 1, kernel_size=1) # 1/4 Scale Output
        self.out_ds1 = nn.Conv2d(64, 1, kernel_size=1)  # 1/2 Scale Output

    def forward(self, x):
        global_feat = self.global_encoder(x)
        x_edge  = self.roberts(x)
        x_fused = torch.cat([x, x_edge], dim=1)

        x0 = self.relu(self.bn1(self.conv1(x_fused)))
        x1 = self.maxpool(x0)

        e1 = self.layer1(x1)
        e2 = self.layer2(e1)
        e3 = self.layer3(e2)
        e4 = self.layer4(e3)

        s1 = self.pcbam1(e1)
        s2 = self.pcbam2(e2)
        s3 = self.pcbam3(e3)
        s4 = self.pcbam4(e4)

        b = self.bottleneck(self.pool(e4))

        if global_feat.shape[-2:] != b.shape[-2:]:
            global_feat = F.interpolate(global_feat, size=b.shape[-2:], mode='bilinear', align_corners=False)

        b = self.fusion(torch.cat([b, global_feat], dim=1))
        b = self.sga(b)

        #  Decoder with Attention Gates
        g4 = self.up4(b)
        x4 = self.ag4(g=g4, x=s4)
        d4 = self.dec4(torch.cat([g4, x4], dim=1))

        g3 = self.up3(d4)
        x3 = self.ag3(g=g3, x=s3)
        d3 = self.dec3(torch.cat([g3, x3], dim=1))

        g2 = self.up2(d3)
        x2 = self.ag2(g=g2, x=s2)
        d2 = self.dec2(torch.cat([g2, x2], dim=1))

        # Deep Supervision Extraction
        out_ds2 = self.out_ds2(d2)

        g1 = self.up1(d2)
        x1 = self.ag1(g=g1, x=s1)
        d1 = self.dec1(torch.cat([g1, x1], dim=1))

        # Deep Supervision Extraction
        out_ds1 = self.out_ds1(d1)

        d0  = self.dec0(torch.cat([self.up0(d1), x0], dim=1))
        out = self.dec_out(self.up_out(d0))

        out_main = self.final(out)
        if self.training:
            return out_main, out_ds1, out_ds2
        else:
            return out_main

# ==========================================
# TVERSKY LOSS & METRICS
# ==========================================
class HybridLoss(nn.Module):
    # CHANGED: alpha=0.45, beta=0.55
    def __init__(self, smooth=1.0, focal_gamma=2.0, alpha=0.45, beta=0.55):
        super().__init__()
        self.smooth = smooth
        self.focal_gamma = focal_gamma
        self.alpha = alpha  # Penalty for False Positives
        self.beta = beta    # Penalty for False Negatives

    def forward(self, logits, targets):
        bce = F.binary_cross_entropy_with_logits(logits, targets)
        probs = torch.sigmoid(logits).view(-1)
        tgt = targets.view(-1)

        # Tversky implementation
        tp = (probs * tgt).sum()
        fp = (probs * (1.0 - tgt)).sum()
        fn = ((1.0 - probs) * tgt).sum()
        tversky = (tp + self.smooth) / (tp + self.alpha * fp + self.beta * fn + self.smooth)
        tversky_loss = 1.0 - tversky

        pt = torch.where(tgt == 1, probs, 1.0 - probs)
        focal = (-(1.0 - pt) ** self.focal_gamma * torch.log(pt + 1e-8)).mean()

        return 0.4 * bce + 0.4 * tversky_loss + 0.2 * focal

def dice_coef(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    inter = (y_true_f * y_pred_f).sum()
    return (2. * inter + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

def iou_score(preds, masks, threshold=0.5, eps=1e-6):
    preds_bin = (preds > threshold).float()
    masks_bin = (masks > threshold).float()
    inter = (preds_bin * masks_bin).sum().item()
    union = preds_bin.sum().item() + masks_bin.sum().item() - inter
    return inter / (union + eps)

# ==========================================
# TRAINING FUNCTION
# ==========================================
def train_model(model, train_loader, val_loader, epochs=50):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)

    criterion = HybridLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=10, min_lr=1e-6
    )

    train_losses, val_losses = [], []
    train_dice_scores, val_dice_scores = [], []
    train_iou_scores, val_iou_scores = [], []

    best_val_loss = float("inf")
    best_epoch = 0
    best_model_weights = None

    for epoch in range(epochs):
        model.train()
        train_loss = train_dice = train_iou = 0
        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs} [Train]"):
            images, masks = images.to(device), masks.to(device)

            # ADDED: Deep Supervision Return
            preds_logits, logits_ds1, logits_ds2 = model(images)

            # Rescale targets to match the deep supervision auxiliary output sizes
            mask_ds1 = F.interpolate(masks, size=logits_ds1.shape[-2:], mode='nearest-exact')
            mask_ds2 = F.interpolate(masks, size=logits_ds2.shape[-2:], mode='nearest-exact')

            loss_main = criterion(preds_logits, masks)
            loss_ds1 = criterion(logits_ds1, mask_ds1)
            loss_ds2 = criterion(logits_ds2, mask_ds2)

            # Combine losses
            loss = loss_main + 0.3 * loss_ds1 + 0.1 * loss_ds2

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            preds_probs = torch.sigmoid(preds_logits)

            # Only track main loss for metrics
            train_loss += loss_main.item()
            train_dice += dice_coef(masks, preds_probs).item()
            train_iou += iou_score(preds_probs, masks)

        model.eval()
        val_loss = val_dice = val_iou = 0

        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc=f"Epoch {epoch+1}/{epochs} [Val]"):
                images, masks = images.to(device), masks.to(device)

                preds_logits = model(images)
                loss = criterion(preds_logits, masks)

                preds_probs = torch.sigmoid(preds_logits)

                val_loss += loss.item()
                val_dice += dice_coef(masks, preds_probs).item()
                val_iou += iou_score(preds_probs, masks)

        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        avg_train_dice = train_dice / len(train_loader)
        avg_val_dice   = val_dice / len(val_loader)
        avg_train_iou  = train_iou / len(train_loader)
        avg_val_iou    = val_iou / len(val_loader)

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_dice_scores.append(avg_train_dice)
        val_dice_scores.append(avg_val_dice)
        train_iou_scores.append(avg_train_iou)
        val_iou_scores.append(avg_val_iou)

        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
        print(f"Train Dice: {avg_train_dice:.4f} | Val Dice: {avg_val_dice:.4f}")
        print(f"Train IoU : {avg_train_iou:.4f} | Val IoU : {avg_val_iou:.4f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch + 1
            best_model_weights = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), "best_fastsam_dualpath_unet.pth")
            print(f"✓ Best model saved (Epoch {epoch+1}, Val Loss {best_val_loss:.4f})")

        scheduler.step(avg_val_loss)

    model.load_state_dict(best_model_weights)

    print("\n" + "="*60)
    print("Training Completed!")
    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val Loss: {best_val_loss:.4f}")
    print("="*60)

    return {
        "train_losses": train_losses, "val_losses": val_losses,
        "train_dice": train_dice_scores, "val_dice": val_dice_scores,
        "train_iou": train_iou_scores, "val_iou": val_iou_scores,
    }

def plot_training(history):
    plt.figure(figsize=(17, 4))
    plt.subplot(1, 3, 1)
    plt.plot(history["train_losses"], label="Train Loss", linewidth=2)
    plt.plot(history["val_losses"], label="Val Loss", linewidth=2)
    plt.title("Loss Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 2)
    plt.plot(history["train_dice"], label="Train Dice", linewidth=2)
    plt.plot(history["val_dice"], label="Val Dice", linewidth=2)
    plt.title("Dice Coefficient Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 3)
    plt.plot(history["train_iou"], label="Train IoU", linewidth=2)
    plt.plot(history["val_iou"], label="Val IoU", linewidth=2)
    plt.title("IoU Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("IoU Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=300, bbox_inches='tight')
    plt.show()

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    model = PreTrainedDualPathUNet(fastsam_checkpoint='FastSAM-s.pt')
    model = model.to(device)

    print("\n================= MODEL SUMMARY =================\n")
    # Tell Torchinfo to evaluate using the eval() output structure to prevent crashes
    print(summary(model, input_size=(BATCH_SIZE, 3, IMG_SIZE, IMG_SIZE), mode='eval'))

    history = train_model(model, train_loader, val_loader, epochs=100)
    plot_training(history)

    print("Loading best model...")
    model.load_state_dict(torch.load("best_fastsam_dualpath_unet.pth", map_location=device))
    model.eval()

    test_dice, test_iou = 0, 0
    print("Evaluating on test set...")
    with torch.no_grad():
        for images, masks in tqdm(test_loader, desc="Evaluating Test Set"):
            images, masks = images.to(device), masks.to(device)
            preds_probs = torch.sigmoid(model(images))
            preds_bin = (preds_probs > 0.4).float()
            test_dice += dice_coef(masks, preds_bin).item()
            test_iou += iou_score(preds_probs, masks)

    num_batches = len(test_loader)
    avg_test_dice = test_dice / num_batches
    avg_test_iou = test_iou / num_batches

    print("\n" + "="*40)
    print("TEST SET EVALUATION")
    print("="*40)
    print(f"Dice Coefficient: {avg_test_dice:.4f}")
    print(f"IoU (Jaccard):    {avg_test_iou:.4f}")
    print("="*40)
# Out:
# Using device: cuda
# [FastSAMEncoder] Loading FastSAM-s.pt ...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/FastSAM-s.pt to 'FastSAM-s.pt': 100% ━━━━━━━━━━━━ 22.7MB 156.4MB/s 0.1s1s<0.1s
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 207MB/s]
# ================= MODEL SUMMARY =================
#
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# PreTrainedDualPathUNet                                  [8, 1, 256, 256]          --
# ├─FastSAMEncoder: 1-1                                   [8, 512, 4, 4]            --
# │    └─ModuleList: 2-1                                  --                        --
# │    │    └─Conv: 3-1                                   [8, 32, 128, 128]         (928)
# │    │    └─Conv: 3-12                                  --                        (recursive)
# │    │    └─Conv: 3-3                                   [8, 64, 64, 64]           (18,560)
# │    │    └─Conv: 3-12                                  --                        (recursive)
# │    │    └─C2f: 3-5                                    [8, 64, 64, 64]           29,056
# │    │    └─Conv: 3-12                                  --                        (recursive)
# │    │    └─C2f: 3-11                                   --                        (recursive)
# │    │    └─Conv: 3-12                                  --                        (recursive)
# │    │    └─C2f: 3-11                                   --                        (recursive)
# │    │    └─Conv: 3-12                                  --                        (recursive)
# │    │    └─C2f: 3-11                                   --                        (recursive)
# │    │    └─Conv: 3-12                                  --                        (recursive)
# │    │    └─Conv: 3-13                                  [8, 128, 32, 32]          73,984
# │    └─Sequential: 2-2                                  [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-14                                [8, 512, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-15                           [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-16                                  [8, 512, 32, 32]          --
# ├─RobertsEdgeOperator: 1-2                              [8, 1, 256, 256]          --
# ├─Conv2d: 1-3                                           [8, 64, 128, 128]         12,544
# ├─BatchNorm2d: 1-4                                      [8, 64, 128, 128]         128
# ├─ReLU: 1-5                                             [8, 64, 128, 128]         --
# ├─MaxPool2d: 1-6                                        [8, 64, 64, 64]           --
# ├─Sequential: 1-7                                       [8, 64, 64, 64]           --
# │    └─BasicBlock: 2-3                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-17                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-18                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-19                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-20                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-21                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-22                                  [8, 64, 64, 64]           --
# │    └─BasicBlock: 2-4                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-23                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-24                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-25                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-26                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-27                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-28                                  [8, 64, 64, 64]           --
# │    └─BasicBlock: 2-5                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-29                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-30                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-31                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-32                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-33                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-34                                  [8, 64, 64, 64]           --
# ├─Sequential: 1-8                                       [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-6                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-35                                [8, 128, 32, 32]          73,728
# │    │    └─BatchNorm2d: 3-36                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-37                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-38                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-39                           [8, 128, 32, 32]          256
# │    │    └─Sequential: 3-40                            [8, 128, 32, 32]          8,448
# │    │    └─ReLU: 3-41                                  [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-7                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-42                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-43                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-44                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-45                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-46                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-47                                  [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-8                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-48                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-49                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-50                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-51                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-52                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-53                                  [8, 128, 32, 32]          --
# │    └─BasicBlock: 2-9                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-54                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-55                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-56                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-57                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-58                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-59                                  [8, 128, 32, 32]          --
# ├─Sequential: 1-9                                       [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-10                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-60                                [8, 256, 16, 16]          294,912
# │    │    └─BatchNorm2d: 3-61                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-62                                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-63                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-64                           [8, 256, 16, 16]          512
# │    │    └─Sequential: 3-65                            [8, 256, 16, 16]          33,280
# │    │    └─ReLU: 3-66                                  [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-11                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-67                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-68                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-69                                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-70                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-71                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-72                                  [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-12                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-73                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-74                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-75                                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-76                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-77                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-78                                  [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-13                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-79                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-80                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-81                                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-82                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-83                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-84                                  [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-14                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-85                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-86                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-87                                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-88                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-89                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-90                                  [8, 256, 16, 16]          --
# │    └─BasicBlock: 2-15                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-91                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-92                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-93                                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-94                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-95                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-96                                  [8, 256, 16, 16]          --
# ├─Sequential: 1-10                                      [8, 512, 8, 8]            --
# │    └─BasicBlock: 2-16                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-97                                [8, 512, 8, 8]            1,179,648
# │    │    └─BatchNorm2d: 3-98                           [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-99                                  [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-100                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-101                          [8, 512, 8, 8]            1,024
# │    │    └─Sequential: 3-102                           [8, 512, 8, 8]            132,096
# │    │    └─ReLU: 3-103                                 [8, 512, 8, 8]            --
# │    └─BasicBlock: 2-17                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-104                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-105                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-106                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-107                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-108                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-109                                 [8, 512, 8, 8]            --
# │    └─BasicBlock: 2-18                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-110                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-111                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-112                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-113                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-114                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-115                                 [8, 512, 8, 8]            --
# ├─PCBAM_Filter: 1-11                                    [8, 64, 64, 64]           --
# │    └─Sequential: 2-19                                 [8, 64]                   --
# │    │    └─Linear: 3-116                               [8, 8]                    520
# │    │    └─ReLU: 3-117                                 [8, 8]                    --
# │    │    └─Linear: 3-118                               [8, 64]                   576
# │    └─Sequential: 2-20                                 [8, 64]                   (recursive)
# │    │    └─Linear: 3-119                               [8, 8]                    (recursive)
# │    │    └─ReLU: 3-120                                 [8, 8]                    --
# │    │    └─Linear: 3-121                               [8, 64]                   (recursive)
# │    └─Conv2d: 2-21                                     [8, 1, 64, 64]            98
# ├─PCBAM_Filter: 1-12                                    [8, 128, 32, 32]          --
# │    └─Sequential: 2-22                                 [8, 128]                  --
# │    │    └─Linear: 3-122                               [8, 16]                   2,064
# │    │    └─ReLU: 3-123                                 [8, 16]                   --
# │    │    └─Linear: 3-124                               [8, 128]                  2,176
# │    └─Sequential: 2-23                                 [8, 128]                  (recursive)
# │    │    └─Linear: 3-125                               [8, 16]                   (recursive)
# │    │    └─ReLU: 3-126                                 [8, 16]                   --
# │    │    └─Linear: 3-127                               [8, 128]                  (recursive)
# │    └─Conv2d: 2-24                                     [8, 1, 32, 32]            98
# ├─PCBAM_Filter: 1-13                                    [8, 256, 16, 16]          --
# │    └─Sequential: 2-25                                 [8, 256]                  --
# │    │    └─Linear: 3-128                               [8, 32]                   8,224
# │    │    └─ReLU: 3-129                                 [8, 32]                   --
# │    │    └─Linear: 3-130                               [8, 256]                  8,448
# │    └─Sequential: 2-26                                 [8, 256]                  (recursive)
# │    │    └─Linear: 3-131                               [8, 32]                   (recursive)
# │    │    └─ReLU: 3-132                                 [8, 32]                   --
# │    │    └─Linear: 3-133                               [8, 256]                  (recursive)
# │    └─Conv2d: 2-27                                     [8, 1, 16, 16]            98
# ├─PCBAM_Filter: 1-14                                    [8, 512, 8, 8]            --
# │    └─Sequential: 2-28                                 [8, 512]                  --
# │    │    └─Linear: 3-134                               [8, 64]                   32,832
# │    │    └─ReLU: 3-135                                 [8, 64]                   --
# │    │    └─Linear: 3-136                               [8, 512]                  33,280
# │    └─Sequential: 2-29                                 [8, 512]                  (recursive)
# │    │    └─Linear: 3-137                               [8, 64]                   (recursive)
# │    │    └─ReLU: 3-138                                 [8, 64]                   --
# │    │    └─Linear: 3-139                               [8, 512]                  (recursive)
# │    └─Conv2d: 2-30                                     [8, 1, 8, 8]              98
# ├─MaxPool2d: 1-15                                       [8, 512, 4, 4]            --
# ├─DoubleConv: 1-16                                      [8, 1024, 4, 4]           --
# │    └─Sequential: 2-31                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-140                               [8, 1024, 4, 4]           4,718,592
# │    │    └─BatchNorm2d: 3-141                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-142                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-143                               [8, 1024, 4, 4]           9,437,184
# │    │    └─BatchNorm2d: 3-144                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-145                                 [8, 1024, 4, 4]           --
# ├─DoubleConv: 1-17                                      [8, 1024, 4, 4]           --
# │    └─Sequential: 2-32                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-146                               [8, 1024, 4, 4]           14,155,776
# │    │    └─BatchNorm2d: 3-147                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-148                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-149                               [8, 1024, 4, 4]           9,437,184
# │    │    └─BatchNorm2d: 3-150                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-151                                 [8, 1024, 4, 4]           --
# ├─SpatialGateAttention: 1-18                            [8, 1024, 4, 4]           --
# │    └─Conv2d: 2-33                                     [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-34                                     [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-35                                     [8, 1024, 4, 4]           1,049,600
# │    └─Conv2d: 2-36                                     [8, 1024, 4, 4]           1,311,744
# ├─ConvTranspose2d: 1-19                                 [8, 512, 8, 8]            2,097,664
# ├─AttentionGate: 1-20                                   [8, 512, 8, 8]            --
# │    └─Sequential: 2-37                                 [8, 256, 8, 8]            --
# │    │    └─Conv2d: 3-152                               [8, 256, 8, 8]            131,328
# │    │    └─BatchNorm2d: 3-153                          [8, 256, 8, 8]            512
# │    └─Sequential: 2-38                                 [8, 256, 8, 8]            --
# │    │    └─Conv2d: 3-154                               [8, 256, 8, 8]            131,328
# │    │    └─BatchNorm2d: 3-155                          [8, 256, 8, 8]            512
# │    └─ReLU: 2-39                                       [8, 256, 8, 8]            --
# │    └─Sequential: 2-40                                 [8, 1, 8, 8]              --
# │    │    └─Conv2d: 3-156                               [8, 1, 8, 8]              257
# │    │    └─BatchNorm2d: 3-157                          [8, 1, 8, 8]              2
# │    │    └─Sigmoid: 3-158                              [8, 1, 8, 8]              --
# ├─DoubleConv: 1-21                                      [8, 512, 8, 8]            --
# │    └─Sequential: 2-41                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-159                               [8, 512, 8, 8]            4,718,592
# │    │    └─BatchNorm2d: 3-160                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-161                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-162                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-163                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-164                                 [8, 512, 8, 8]            --
# ├─ConvTranspose2d: 1-22                                 [8, 256, 16, 16]          524,544
# ├─AttentionGate: 1-23                                   [8, 256, 16, 16]          --
# │    └─Sequential: 2-42                                 [8, 128, 16, 16]          --
# │    │    └─Conv2d: 3-165                               [8, 128, 16, 16]          32,896
# │    │    └─BatchNorm2d: 3-166                          [8, 128, 16, 16]          256
# │    └─Sequential: 2-43                                 [8, 128, 16, 16]          --
# │    │    └─Conv2d: 3-167                               [8, 128, 16, 16]          32,896
# │    │    └─BatchNorm2d: 3-168                          [8, 128, 16, 16]          256
# │    └─ReLU: 2-44                                       [8, 128, 16, 16]          --
# │    └─Sequential: 2-45                                 [8, 1, 16, 16]            --
# │    │    └─Conv2d: 3-169                               [8, 1, 16, 16]            129
# │    │    └─BatchNorm2d: 3-170                          [8, 1, 16, 16]            2
# │    │    └─Sigmoid: 3-171                              [8, 1, 16, 16]            --
# ├─DoubleConv: 1-24                                      [8, 256, 16, 16]          --
# │    └─Sequential: 2-46                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-172                               [8, 256, 16, 16]          1,179,648
# │    │    └─BatchNorm2d: 3-173                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-174                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-175                               [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-176                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-177                                 [8, 256, 16, 16]          --
# ├─ConvTranspose2d: 1-25                                 [8, 128, 32, 32]          131,200
# ├─AttentionGate: 1-26                                   [8, 128, 32, 32]          --
# │    └─Sequential: 2-47                                 [8, 64, 32, 32]           --
# │    │    └─Conv2d: 3-178                               [8, 64, 32, 32]           8,256
# │    │    └─BatchNorm2d: 3-179                          [8, 64, 32, 32]           128
# │    └─Sequential: 2-48                                 [8, 64, 32, 32]           --
# │    │    └─Conv2d: 3-180                               [8, 64, 32, 32]           8,256
# │    │    └─BatchNorm2d: 3-181                          [8, 64, 32, 32]           128
# │    └─ReLU: 2-49                                       [8, 64, 32, 32]           --
# │    └─Sequential: 2-50                                 [8, 1, 32, 32]            --
# │    │    └─Conv2d: 3-182                               [8, 1, 32, 32]            65
# │    │    └─BatchNorm2d: 3-183                          [8, 1, 32, 32]            2
# │    │    └─Sigmoid: 3-184                              [8, 1, 32, 32]            --
# ├─DoubleConv: 1-27                                      [8, 128, 32, 32]          --
# │    └─Sequential: 2-51                                 [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-185                               [8, 128, 32, 32]          294,912
# │    │    └─BatchNorm2d: 3-186                          [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-187                                 [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-188                               [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-189                          [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-190                                 [8, 128, 32, 32]          --
# ├─Conv2d: 1-28                                          [8, 1, 32, 32]            129
# ├─ConvTranspose2d: 1-29                                 [8, 64, 64, 64]           32,832
# ├─AttentionGate: 1-30                                   [8, 64, 64, 64]           --
# │    └─Sequential: 2-52                                 [8, 32, 64, 64]           --
# │    │    └─Conv2d: 3-191                               [8, 32, 64, 64]           2,080
# │    │    └─BatchNorm2d: 3-192                          [8, 32, 64, 64]           64
# │    └─Sequential: 2-53                                 [8, 32, 64, 64]           --
# │    │    └─Conv2d: 3-193                               [8, 32, 64, 64]           2,080
# │    │    └─BatchNorm2d: 3-194                          [8, 32, 64, 64]           64
# │    └─ReLU: 2-54                                       [8, 32, 64, 64]           --
# │    └─Sequential: 2-55                                 [8, 1, 64, 64]            --
# │    │    └─Conv2d: 3-195                               [8, 1, 64, 64]            33
# │    │    └─BatchNorm2d: 3-196                          [8, 1, 64, 64]            2
# │    │    └─Sigmoid: 3-197                              [8, 1, 64, 64]            --
# ├─DoubleConv: 1-31                                      [8, 64, 64, 64]           --
# │    └─Sequential: 2-56                                 [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-198                               [8, 64, 64, 64]           73,728
# │    │    └─BatchNorm2d: 3-199                          [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-200                                 [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-201                               [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-202                          [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-203                                 [8, 64, 64, 64]           --
# ├─Conv2d: 1-32                                          [8, 1, 64, 64]            65
# ├─ConvTranspose2d: 1-33                                 [8, 64, 128, 128]         16,448
# ├─DoubleConv: 1-34                                      [8, 64, 128, 128]         --
# │    └─Sequential: 2-57                                 [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-204                               [8, 64, 128, 128]         73,728
# │    │    └─BatchNorm2d: 3-205                          [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-206                                 [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-207                               [8, 64, 128, 128]         36,864
# │    │    └─BatchNorm2d: 3-208                          [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-209                                 [8, 64, 128, 128]         --
# ├─ConvTranspose2d: 1-35                                 [8, 32, 256, 256]         8,224
# ├─DoubleConv: 1-36                                      [8, 32, 256, 256]         --
# │    └─Sequential: 2-58                                 [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-210                               [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-211                          [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-212                                 [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-213                               [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-214                          [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-215                                 [8, 32, 256, 256]         --
# ├─Conv2d: 1-37                                          [8, 1, 256, 256]          33
# =========================================================================================================
# Total params: 74,676,431
# Trainable params: 74,656,943
# Non-trainable params: 19,488
# Total mult-adds (Units.GIGABYTES): 96.64
# =========================================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 2153.45
# Params size (MB): 298.57
# Estimated Total Size (MB): 2458.31
# =========================================================================================================
# Epoch 1/100 [Train]: 100%|██████████| 65/65 [00:31<00:00,  2.06it/s]
# Epoch 1/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.18it/s]
# Epoch 1/100
# Train Loss: 0.5224 | Val Loss: 0.5126
# Train Dice: 0.2272 | Val Dice: 0.2870
# Train IoU : 0.3188 | Val IoU : 0.4088
# ✓ Best model saved (Epoch 1, Val Loss 0.5126)
# Epoch 2/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 2/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.44it/s]
# Epoch 2/100
# Train Loss: 0.4460 | Val Loss: 0.4678
# Train Dice: 0.2892 | Val Dice: 0.3240
# Train IoU : 0.4667 | Val IoU : 0.4616
# ✓ Best model saved (Epoch 2, Val Loss 0.4678)
# Epoch 3/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.57it/s]
# Epoch 3/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.48it/s]
# Epoch 3/100
# Train Loss: 0.4089 | Val Loss: 0.3925
# Train Dice: 0.3290 | Val Dice: 0.3401
# Train IoU : 0.5403 | Val IoU : 0.5482
# ✓ Best model saved (Epoch 3, Val Loss 0.3925)
# Epoch 4/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.57it/s]
# Epoch 4/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.68it/s]
# Epoch 4/100
# Train Loss: 0.3923 | Val Loss: 0.3944
# Train Dice: 0.3471 | Val Dice: 0.3487
# Train IoU : 0.5432 | Val IoU : 0.5415
# Epoch 5/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 5/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.20it/s]
# Epoch 5/100
# Train Loss: 0.3673 | Val Loss: 0.4080
# Train Dice: 0.3739 | Val Dice: 0.3483
# Train IoU : 0.6017 | Val IoU : 0.5065
# Epoch 6/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.49it/s]
# Epoch 6/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.26it/s]
# Epoch 6/100
# Train Loss: 0.3535 | Val Loss: 0.4252
# Train Dice: 0.3951 | Val Dice: 0.3653
# Train IoU : 0.6058 | Val IoU : 0.5059
# Epoch 7/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 7/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.53it/s]
# Epoch 7/100
# Train Loss: 0.3343 | Val Loss: 0.3329
# Train Dice: 0.4159 | Val Dice: 0.4034
# Train IoU : 0.6364 | Val IoU : 0.6227
# ✓ Best model saved (Epoch 7, Val Loss 0.3329)
# Epoch 8/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 8/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.58it/s]
# Epoch 8/100
# Train Loss: 0.3267 | Val Loss: 0.3409
# Train Dice: 0.4270 | Val Dice: 0.4000
# Train IoU : 0.6419 | Val IoU : 0.5813
# Epoch 9/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 9/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.67it/s]
# Epoch 9/100
# Train Loss: 0.3170 | Val Loss: 0.3106
# Train Dice: 0.4412 | Val Dice: 0.4387
# Train IoU : 0.6347 | Val IoU : 0.6252
# ✓ Best model saved (Epoch 9, Val Loss 0.3106)
# Epoch 10/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 10/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.55it/s]
# Epoch 10/100
# Train Loss: 0.3133 | Val Loss: 0.3427
# Train Dice: 0.4420 | Val Dice: 0.4044
# Train IoU : 0.6209 | Val IoU : 0.5675
# Epoch 11/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 11/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.39it/s]
# Epoch 11/100
# Train Loss: 0.2965 | Val Loss: 0.3001
# Train Dice: 0.4669 | Val Dice: 0.4499
# Train IoU : 0.6513 | Val IoU : 0.6203
# ✓ Best model saved (Epoch 11, Val Loss 0.3001)
# Epoch 12/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 12/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.48it/s]
# Epoch 12/100
# Train Loss: 0.2758 | Val Loss: 0.2953
# Train Dice: 0.4986 | Val Dice: 0.4686
# Train IoU : 0.6851 | Val IoU : 0.5957
# ✓ Best model saved (Epoch 12, Val Loss 0.2953)
# Epoch 13/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 13/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.80it/s]
# Epoch 13/100
# Train Loss: 0.2698 | Val Loss: 0.3226
# Train Dice: 0.5102 | Val Dice: 0.4568
# Train IoU : 0.6877 | Val IoU : 0.5873
# Epoch 14/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 14/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.42it/s]
# Epoch 14/100
# Train Loss: 0.2556 | Val Loss: 0.2743
# Train Dice: 0.5337 | Val Dice: 0.4965
# Train IoU : 0.7022 | Val IoU : 0.6458
# ✓ Best model saved (Epoch 14, Val Loss 0.2743)
# Epoch 15/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 15/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.54it/s]
# Epoch 15/100
# Train Loss: 0.2477 | Val Loss: 0.2704
# Train Dice: 0.5436 | Val Dice: 0.5058
# Train IoU : 0.6992 | Val IoU : 0.5915
# ✓ Best model saved (Epoch 15, Val Loss 0.2704)
# Epoch 16/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 16/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.00it/s]
# Epoch 16/100
# Train Loss: 0.2458 | Val Loss: 0.2745
# Train Dice: 0.5512 | Val Dice: 0.5033
# Train IoU : 0.6908 | Val IoU : 0.5991
# Epoch 17/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 17/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.41it/s]
# Epoch 17/100
# Train Loss: 0.2286 | Val Loss: 0.2736
# Train Dice: 0.5768 | Val Dice: 0.5247
# Train IoU : 0.7128 | Val IoU : 0.5737
# Epoch 18/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 18/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.03it/s]
# Epoch 18/100
# Train Loss: 0.2233 | Val Loss: 0.2400
# Train Dice: 0.5860 | Val Dice: 0.5521
# Train IoU : 0.7168 | Val IoU : 0.6286
# ✓ Best model saved (Epoch 18, Val Loss 0.2400)
# Epoch 19/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 19/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.83it/s]
# Epoch 19/100
# Train Loss: 0.2190 | Val Loss: 0.2435
# Train Dice: 0.5928 | Val Dice: 0.5566
# Train IoU : 0.7104 | Val IoU : 0.6192
# Epoch 20/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 20/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.93it/s]
# Epoch 20/100
# Train Loss: 0.2062 | Val Loss: 0.2519
# Train Dice: 0.6175 | Val Dice: 0.5595
# Train IoU : 0.7278 | Val IoU : 0.5933
# Epoch 21/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 21/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.41it/s]
# Epoch 21/100
# Train Loss: 0.1959 | Val Loss: 0.2219
# Train Dice: 0.6357 | Val Dice: 0.5779
# Train IoU : 0.7399 | Val IoU : 0.6687
# ✓ Best model saved (Epoch 21, Val Loss 0.2219)
# Epoch 22/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 22/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.44it/s]
# Epoch 22/100
# Train Loss: 0.1938 | Val Loss: 0.2336
# Train Dice: 0.6424 | Val Dice: 0.5961
# Train IoU : 0.7244 | Val IoU : 0.6074
# Epoch 23/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 23/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.30it/s]
# Epoch 23/100
# Train Loss: 0.1934 | Val Loss: 0.2124
# Train Dice: 0.6423 | Val Dice: 0.6154
# Train IoU : 0.7191 | Val IoU : 0.6598
# ✓ Best model saved (Epoch 23, Val Loss 0.2124)
# Epoch 24/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 24/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.96it/s]
# Epoch 24/100
# Train Loss: 0.1739 | Val Loss: 0.2229
# Train Dice: 0.6772 | Val Dice: 0.5941
# Train IoU : 0.7536 | Val IoU : 0.6390
# Epoch 25/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 25/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.08it/s]
# Epoch 25/100
# Train Loss: 0.1732 | Val Loss: 0.1944
# Train Dice: 0.6804 | Val Dice: 0.6410
# Train IoU : 0.7444 | Val IoU : 0.7091
# ✓ Best model saved (Epoch 25, Val Loss 0.1944)
# Epoch 26/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 26/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.39it/s]
# Epoch 26/100
# Train Loss: 0.1751 | Val Loss: 0.1868
# Train Dice: 0.6810 | Val Dice: 0.6570
# Train IoU : 0.7365 | Val IoU : 0.6802
# ✓ Best model saved (Epoch 26, Val Loss 0.1868)
# Epoch 27/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 27/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.53it/s]
# Epoch 27/100
# Train Loss: 0.1692 | Val Loss: 0.2093
# Train Dice: 0.6888 | Val Dice: 0.6351
# Train IoU : 0.7325 | Val IoU : 0.6304
# Epoch 28/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 28/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.14it/s]
# Epoch 28/100
# Train Loss: 0.1602 | Val Loss: 0.1690
# Train Dice: 0.7074 | Val Dice: 0.6876
# Train IoU : 0.7517 | Val IoU : 0.7229
# ✓ Best model saved (Epoch 28, Val Loss 0.1690)
# Epoch 29/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 29/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.19it/s]
# Epoch 29/100
# Train Loss: 0.1571 | Val Loss: 0.2247
# Train Dice: 0.7109 | Val Dice: 0.6356
# Train IoU : 0.7529 | Val IoU : 0.6181
# Epoch 30/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 30/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.38it/s]
# Epoch 30/100
# Train Loss: 0.1550 | Val Loss: 0.1879
# Train Dice: 0.7156 | Val Dice: 0.6783
# Train IoU : 0.7510 | Val IoU : 0.6498
# Epoch 31/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 31/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.45it/s]
# Epoch 31/100
# Train Loss: 0.1467 | Val Loss: 0.1866
# Train Dice: 0.7299 | Val Dice: 0.6763
# Train IoU : 0.7557 | Val IoU : 0.6551
# Epoch 32/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 32/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.24it/s]
# Epoch 32/100
# Train Loss: 0.1496 | Val Loss: 0.2322
# Train Dice: 0.7291 | Val Dice: 0.6293
# Train IoU : 0.7537 | Val IoU : 0.5823
# Epoch 33/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 33/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.24it/s]
# Epoch 33/100
# Train Loss: 0.1408 | Val Loss: 0.1990
# Train Dice: 0.7446 | Val Dice: 0.6710
# Train IoU : 0.7621 | Val IoU : 0.6581
# Epoch 34/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 34/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.26it/s]
# Epoch 34/100
# Train Loss: 0.1407 | Val Loss: 0.2005
# Train Dice: 0.7441 | Val Dice: 0.6746
# Train IoU : 0.7601 | Val IoU : 0.6223
# Epoch 35/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 35/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.45it/s]
# Epoch 35/100
# Train Loss: 0.1286 | Val Loss: 0.1803
# Train Dice: 0.7680 | Val Dice: 0.7035
# Train IoU : 0.7776 | Val IoU : 0.6550
# Epoch 36/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 36/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.18it/s]
# Epoch 36/100
# Train Loss: 0.1261 | Val Loss: 0.2025
# Train Dice: 0.7745 | Val Dice: 0.6775
# Train IoU : 0.7869 | Val IoU : 0.6091
# Epoch 37/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 37/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.47it/s]
# Epoch 37/100
# Train Loss: 0.1234 | Val Loss: 0.2359
# Train Dice: 0.7791 | Val Dice: 0.6617
# Train IoU : 0.7825 | Val IoU : 0.5853
# Epoch 38/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 38/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.44it/s]
# Epoch 38/100
# Train Loss: 0.1223 | Val Loss: 0.2194
# Train Dice: 0.7832 | Val Dice: 0.6608
# Train IoU : 0.7790 | Val IoU : 0.5843
# Epoch 39/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 39/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.54it/s]
# Epoch 39/100
# Train Loss: 0.1318 | Val Loss: 0.1656
# Train Dice: 0.7721 | Val Dice: 0.7137
# Train IoU : 0.7643 | Val IoU : 0.6559
# ✓ Best model saved (Epoch 39, Val Loss 0.1656)
# Epoch 40/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 40/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.43it/s]
# Epoch 40/100
# Train Loss: 0.1195 | Val Loss: 0.1975
# Train Dice: 0.7905 | Val Dice: 0.6870
# Train IoU : 0.7822 | Val IoU : 0.6119
# Epoch 41/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 41/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.29it/s]
# Epoch 41/100
# Train Loss: 0.1218 | Val Loss: 0.1743
# Train Dice: 0.7876 | Val Dice: 0.7151
# Train IoU : 0.7727 | Val IoU : 0.6343
# Epoch 42/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 42/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.11it/s]
# Epoch 42/100
# Train Loss: 0.1233 | Val Loss: 0.1674
# Train Dice: 0.7864 | Val Dice: 0.7179
# Train IoU : 0.7670 | Val IoU : 0.6520
# Epoch 43/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 43/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.29it/s]
# Epoch 43/100
# Train Loss: 0.1088 | Val Loss: 0.1794
# Train Dice: 0.8099 | Val Dice: 0.7133
# Train IoU : 0.7943 | Val IoU : 0.6302
# Epoch 44/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 44/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.30it/s]
# Epoch 44/100
# Train Loss: 0.1129 | Val Loss: 0.2037
# Train Dice: 0.8021 | Val Dice: 0.6937
# Train IoU : 0.7854 | Val IoU : 0.6047
# Epoch 45/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 45/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.55it/s]
# Epoch 45/100
# Train Loss: 0.1140 | Val Loss: 0.1933
# Train Dice: 0.8070 | Val Dice: 0.6951
# Train IoU : 0.7777 | Val IoU : 0.6196
# Epoch 46/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 46/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.45it/s]
# Epoch 46/100
# Train Loss: 0.1161 | Val Loss: 0.1970
# Train Dice: 0.8008 | Val Dice: 0.6979
# Train IoU : 0.7763 | Val IoU : 0.6251
# Epoch 47/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 47/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.52it/s]
# Epoch 47/100
# Train Loss: 0.1143 | Val Loss: 0.1379
# Train Dice: 0.8044 | Val Dice: 0.7727
# Train IoU : 0.7756 | Val IoU : 0.7158
# ✓ Best model saved (Epoch 47, Val Loss 0.1379)
# Epoch 48/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 48/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.18it/s]
# Epoch 48/100
# Train Loss: 0.1100 | Val Loss: 0.1671
# Train Dice: 0.8116 | Val Dice: 0.7380
# Train IoU : 0.7800 | Val IoU : 0.6495
# Epoch 49/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 49/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.50it/s]
# Epoch 49/100
# Train Loss: 0.1077 | Val Loss: 0.1746
# Train Dice: 0.8216 | Val Dice: 0.7287
# Train IoU : 0.7874 | Val IoU : 0.6447
# Epoch 50/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 50/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.19it/s]
# Epoch 50/100
# Train Loss: 0.1050 | Val Loss: 0.1983
# Train Dice: 0.8177 | Val Dice: 0.7170
# Train IoU : 0.7834 | Val IoU : 0.6220
# Epoch 51/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 51/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.23it/s]
# Epoch 51/100
# Train Loss: 0.0956 | Val Loss: 0.1711
# Train Dice: 0.8339 | Val Dice: 0.7314
# Train IoU : 0.8105 | Val IoU : 0.6537
# Epoch 52/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 52/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.20it/s]
# Epoch 52/100
# Train Loss: 0.1008 | Val Loss: 0.1846
# Train Dice: 0.8297 | Val Dice: 0.7157
# Train IoU : 0.7929 | Val IoU : 0.6299
# Epoch 53/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 53/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.06it/s]
# Epoch 53/100
# Train Loss: 0.0968 | Val Loss: 0.1768
# Train Dice: 0.8351 | Val Dice: 0.7230
# Train IoU : 0.7986 | Val IoU : 0.6334
# Epoch 54/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 54/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.53it/s]
# Epoch 54/100
# Train Loss: 0.0960 | Val Loss: 0.1781
# Train Dice: 0.8395 | Val Dice: 0.7298
# Train IoU : 0.8043 | Val IoU : 0.6318
# Epoch 55/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 55/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.36it/s]
# Epoch 55/100
# Train Loss: 0.0964 | Val Loss: 0.1803
# Train Dice: 0.8391 | Val Dice: 0.7301
# Train IoU : 0.7995 | Val IoU : 0.6386
# Epoch 56/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 56/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.23it/s]
# Epoch 56/100
# Train Loss: 0.0921 | Val Loss: 0.1814
# Train Dice: 0.8464 | Val Dice: 0.7415
# Train IoU : 0.8081 | Val IoU : 0.6457
# Epoch 57/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 57/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.30it/s]
# Epoch 57/100
# Train Loss: 0.1012 | Val Loss: 0.2024
# Train Dice: 0.8310 | Val Dice: 0.7099
# Train IoU : 0.7904 | Val IoU : 0.6134
# Epoch 58/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 58/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.35it/s]
# Epoch 58/100
# Train Loss: 0.0954 | Val Loss: 0.1880
# Train Dice: 0.8443 | Val Dice: 0.7298
# Train IoU : 0.8045 | Val IoU : 0.6312
# Epoch 59/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 59/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.11it/s]
# Epoch 59/100
# Train Loss: 0.0890 | Val Loss: 0.2116
# Train Dice: 0.8515 | Val Dice: 0.7021
# Train IoU : 0.8133 | Val IoU : 0.5937
# Epoch 60/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 60/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.73it/s]
# Epoch 60/100
# Train Loss: 0.0828 | Val Loss: 0.1869
# Train Dice: 0.8600 | Val Dice: 0.7244
# Train IoU : 0.8249 | Val IoU : 0.6227
# Epoch 61/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 61/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.45it/s]
# Epoch 61/100
# Train Loss: 0.0847 | Val Loss: 0.1824
# Train Dice: 0.8587 | Val Dice: 0.7283
# Train IoU : 0.8210 | Val IoU : 0.6256
# Epoch 62/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 62/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.52it/s]
# Epoch 62/100
# Train Loss: 0.0758 | Val Loss: 0.1813
# Train Dice: 0.8707 | Val Dice: 0.7311
# Train IoU : 0.8371 | Val IoU : 0.6268
# Epoch 63/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 63/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.78it/s]
# Epoch 63/100
# Train Loss: 0.0807 | Val Loss: 0.1664
# Train Dice: 0.8641 | Val Dice: 0.7516
# Train IoU : 0.8282 | Val IoU : 0.6548
# Epoch 64/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 64/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.26it/s]
# Epoch 64/100
# Train Loss: 0.0757 | Val Loss: 0.1859
# Train Dice: 0.8717 | Val Dice: 0.7371
# Train IoU : 0.8389 | Val IoU : 0.6324
# Epoch 65/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 65/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.28it/s]
# Epoch 65/100
# Train Loss: 0.0791 | Val Loss: 0.2019
# Train Dice: 0.8671 | Val Dice: 0.7153
# Train IoU : 0.8265 | Val IoU : 0.6066
# Epoch 66/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 66/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.39it/s]
# Epoch 66/100
# Train Loss: 0.0756 | Val Loss: 0.1896
# Train Dice: 0.8725 | Val Dice: 0.7256
# Train IoU : 0.8374 | Val IoU : 0.6188
# Epoch 67/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 67/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.37it/s]
# Epoch 67/100
# Train Loss: 0.0768 | Val Loss: 0.1847
# Train Dice: 0.8714 | Val Dice: 0.7346
# Train IoU : 0.8356 | Val IoU : 0.6285
# Epoch 68/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 68/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.48it/s]
# Epoch 68/100
# Train Loss: 0.0734 | Val Loss: 0.1719
# Train Dice: 0.8737 | Val Dice: 0.7416
# Train IoU : 0.8409 | Val IoU : 0.6359
# Epoch 69/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 69/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.33it/s]
# Epoch 69/100
# Train Loss: 0.0761 | Val Loss: 0.1949
# Train Dice: 0.8747 | Val Dice: 0.7258
# Train IoU : 0.8372 | Val IoU : 0.6137
# Epoch 70/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 70/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.21it/s]
# Epoch 70/100
# Train Loss: 0.0787 | Val Loss: 0.1789
# Train Dice: 0.8710 | Val Dice: 0.7392
# Train IoU : 0.8307 | Val IoU : 0.6295
# Epoch 71/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 71/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  8.66it/s]
# Epoch 71/100
# Train Loss: 0.0699 | Val Loss: 0.1809
# Train Dice: 0.8828 | Val Dice: 0.7414
# Train IoU : 0.8469 | Val IoU : 0.6336
# Epoch 72/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 72/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.61it/s]
# Epoch 72/100
# Train Loss: 0.0727 | Val Loss: 0.1835
# Train Dice: 0.8791 | Val Dice: 0.7396
# Train IoU : 0.8426 | Val IoU : 0.6331
# Epoch 73/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 73/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.43it/s]
# Epoch 73/100
# Train Loss: 0.0719 | Val Loss: 0.1864
# Train Dice: 0.8784 | Val Dice: 0.7368
# Train IoU : 0.8419 | Val IoU : 0.6303
# Epoch 74/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 74/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.07it/s]
# Epoch 74/100
# Train Loss: 0.0669 | Val Loss: 0.1967
# Train Dice: 0.8869 | Val Dice: 0.7312
# Train IoU : 0.8523 | Val IoU : 0.6211
# Epoch 75/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 75/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.50it/s]
# Epoch 75/100
# Train Loss: 0.0733 | Val Loss: 0.1838
# Train Dice: 0.8766 | Val Dice: 0.7348
# Train IoU : 0.8390 | Val IoU : 0.6245
# Epoch 76/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 76/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.39it/s]
# Epoch 76/100
# Train Loss: 0.0696 | Val Loss: 0.1783
# Train Dice: 0.8835 | Val Dice: 0.7473
# Train IoU : 0.8487 | Val IoU : 0.6411
# Epoch 77/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 77/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.21it/s]
# Epoch 77/100
# Train Loss: 0.0682 | Val Loss: 0.1860
# Train Dice: 0.8855 | Val Dice: 0.7390
# Train IoU : 0.8501 | Val IoU : 0.6274
# Epoch 78/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 78/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.55it/s]
# Epoch 78/100
# Train Loss: 0.0677 | Val Loss: 0.2011
# Train Dice: 0.8854 | Val Dice: 0.7229
# Train IoU : 0.8492 | Val IoU : 0.6086
# Epoch 79/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 79/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.00it/s]
# Epoch 79/100
# Train Loss: 0.0686 | Val Loss: 0.2006
# Train Dice: 0.8844 | Val Dice: 0.7230
# Train IoU : 0.8473 | Val IoU : 0.6110
# Epoch 80/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 80/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.14it/s]
# Epoch 80/100
# Train Loss: 0.0660 | Val Loss: 0.1997
# Train Dice: 0.8888 | Val Dice: 0.7260
# Train IoU : 0.8530 | Val IoU : 0.6110
# Epoch 81/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 81/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.63it/s]
# Epoch 81/100
# Train Loss: 0.0651 | Val Loss: 0.2017
# Train Dice: 0.8892 | Val Dice: 0.7287
# Train IoU : 0.8548 | Val IoU : 0.6164
# Epoch 82/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 82/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  8.77it/s]
# Epoch 82/100
# Train Loss: 0.0626 | Val Loss: 0.1957
# Train Dice: 0.8967 | Val Dice: 0.7307
# Train IoU : 0.8620 | Val IoU : 0.6151
# Epoch 83/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 83/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.17it/s]
# Epoch 83/100
# Train Loss: 0.0678 | Val Loss: 0.1911
# Train Dice: 0.8879 | Val Dice: 0.7373
# Train IoU : 0.8515 | Val IoU : 0.6270
# Epoch 84/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 84/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  8.38it/s]
# Epoch 84/100
# Train Loss: 0.0637 | Val Loss: 0.1918
# Train Dice: 0.8917 | Val Dice: 0.7347
# Train IoU : 0.8577 | Val IoU : 0.6226
# Epoch 85/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 85/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.17it/s]
# Epoch 85/100
# Train Loss: 0.0638 | Val Loss: 0.1914
# Train Dice: 0.8919 | Val Dice: 0.7356
# Train IoU : 0.8578 | Val IoU : 0.6248
# Epoch 86/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 86/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.14it/s]
# Epoch 86/100
# Train Loss: 0.0666 | Val Loss: 0.1827
# Train Dice: 0.8886 | Val Dice: 0.7415
# Train IoU : 0.8509 | Val IoU : 0.6298
# Epoch 87/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 87/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.03it/s]
# Epoch 87/100
# Train Loss: 0.0612 | Val Loss: 0.1871
# Train Dice: 0.8958 | Val Dice: 0.7346
# Train IoU : 0.8645 | Val IoU : 0.6206
# Epoch 88/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 88/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.39it/s]
# Epoch 88/100
# Train Loss: 0.0618 | Val Loss: 0.1936
# Train Dice: 0.8966 | Val Dice: 0.7347
# Train IoU : 0.8637 | Val IoU : 0.6224
# Epoch 89/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.54it/s]
# Epoch 89/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.04it/s]
# Epoch 89/100
# Train Loss: 0.0675 | Val Loss: 0.1925
# Train Dice: 0.8889 | Val Dice: 0.7342
# Train IoU : 0.8496 | Val IoU : 0.6191
# Epoch 90/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 90/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.70it/s]
# Epoch 90/100
# Train Loss: 0.0619 | Val Loss: 0.1929
# Train Dice: 0.8947 | Val Dice: 0.7318
# Train IoU : 0.8606 | Val IoU : 0.6186
# Epoch 91/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 91/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.22it/s]
# Epoch 91/100
# Train Loss: 0.0627 | Val Loss: 0.2051
# Train Dice: 0.8939 | Val Dice: 0.7212
# Train IoU : 0.8590 | Val IoU : 0.6057
# Epoch 92/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.51it/s]
# Epoch 92/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  8.00it/s]
# Epoch 92/100
# Train Loss: 0.0649 | Val Loss: 0.2094
# Train Dice: 0.8903 | Val Dice: 0.7205
# Train IoU : 0.8533 | Val IoU : 0.6069
# Epoch 93/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 93/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  8.90it/s]
# Epoch 93/100
# Train Loss: 0.0633 | Val Loss: 0.2160
# Train Dice: 0.8940 | Val Dice: 0.7188
# Train IoU : 0.8602 | Val IoU : 0.6035
# Epoch 94/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 94/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  8.89it/s]
# Epoch 94/100
# Train Loss: 0.0588 | Val Loss: 0.2137
# Train Dice: 0.8989 | Val Dice: 0.7183
# Train IoU : 0.8658 | Val IoU : 0.6015
# Epoch 95/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 95/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  8.44it/s]
# Epoch 95/100
# Train Loss: 0.0617 | Val Loss: 0.2112
# Train Dice: 0.8940 | Val Dice: 0.7204
# Train IoU : 0.8598 | Val IoU : 0.6042
# Epoch 96/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.52it/s]
# Epoch 96/100 [Val]: 100%|██████████| 8/8 [00:00<00:00,  9.41it/s]
# Epoch 96/100
# Train Loss: 0.0634 | Val Loss: 0.2138
# Train Dice: 0.8947 | Val Dice: 0.7217
# Train IoU : 0.8594 | Val IoU : 0.6080
# Epoch 97/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 97/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.35it/s]
# Epoch 97/100
# Train Loss: 0.0596 | Val Loss: 0.2090
# Train Dice: 0.8988 | Val Dice: 0.7229
# Train IoU : 0.8655 | Val IoU : 0.6074
# Epoch 98/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 98/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.52it/s]
# Epoch 98/100
# Train Loss: 0.0558 | Val Loss: 0.2081
# Train Dice: 0.9041 | Val Dice: 0.7255
# Train IoU : 0.8728 | Val IoU : 0.6115
# Epoch 99/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 99/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.63it/s]
# Epoch 99/100
# Train Loss: 0.0621 | Val Loss: 0.2093
# Train Dice: 0.8942 | Val Dice: 0.7220
# Train IoU : 0.8588 | Val IoU : 0.6046
# Epoch 100/100 [Train]: 100%|██████████| 65/65 [00:14<00:00,  4.53it/s]
# Epoch 100/100 [Val]: 100%|██████████| 8/8 [00:00<00:00, 10.39it/s]
# Epoch 100/100
# Train Loss: 0.0605 | Val Loss: 0.2115
# Train Dice: 0.8964 | Val Dice: 0.7196
# Train IoU : 0.8599 | Val IoU : 0.6033
#
# ============================================================
# Training Completed!
# Best Epoch: 47
# Best Val Loss: 0.1379
# ============================================================
# Loading best model...
# Evaluating on test set...
# Evaluating Test Set: 100%|██████████| 9/9 [00:03<00:00,  2.92it/s]
# ========================================
# TEST SET EVALUATION
# ========================================
# Dice Coefficient: 0.8091
# IoU (Jaccard):    0.6984
# ========================================
