# %% [markdown]
# <a href="https://colab.research.google.com/github/rounak393/clab/blob/main/samxres50_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install albumentations scikit-learn timm torchinfo ultralytics -q

import os
import math
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import random
import copy

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import albumentations as A
import cv2
import warnings
import torch.nn.functional as F
from torchinfo import summary
# CHANGED: Imported resnet50 and its weights
from torchvision.models import resnet50, ResNet50_Weights

warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

BASE_DIR = "/kaggle/input/datasets/britikak/busi-dataset/Dataset_BUSI_with_GT"
CLASSES = ["benign", "malignant"]
IMG_SIZE = 256
BATCH_SIZE = 8
SEED = 42

torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = True

class BUSISegmentationDataset(Dataset):
    def __init__(self, base_dir, classes, transform=None):
        self.samples = []
        self.transform = transform

        for cls in classes:
            cls_dir = os.path.join(base_dir, cls)
            if not os.path.exists(cls_dir):
                continue

            images = [
                f for f in os.listdir(cls_dir)
                if f.endswith(".png") and "_mask" not in f
            ]

            for img_name in images:
                img_path = os.path.join(cls_dir, img_name)
                base_name = img_name.replace(".png", "")

                mask_files = [
                    f for f in os.listdir(cls_dir)
                    if f.startswith(base_name + "_mask") and f.endswith(".png")
                ]

                if len(mask_files) == 0:
                    continue

                mask_paths = [os.path.join(cls_dir, f) for f in mask_files]
                self.samples.append((img_path, mask_paths))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, mask_paths = self.samples[idx]

        image = np.array(Image.open(img_path).convert("RGB"))

        combined_mask = np.zeros(image.shape[:2], dtype=np.uint8)
        for mpath in mask_paths:
            mask = np.array(Image.open(mpath).convert("L"))
            mask = (mask > 0).astype(np.uint8)
            combined_mask = np.logical_or(combined_mask, mask)

        combined_mask = combined_mask.astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=combined_mask)
            image = augmented["image"]
            combined_mask = augmented["mask"]

        combined_mask = (combined_mask > 0.5).astype(np.float32)
        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(combined_mask).unsqueeze(0).float()

        return image, mask

# ==========================================
# AUGMENTATIONS (ADDED ELASTIC DEFORMATIONS)
# ==========================================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03, p=0.5),
    A.GridDistortion(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

test_transform = val_transform

# ===================------------------------==================
full_dataset = BUSISegmentationDataset(BASE_DIR, classes=CLASSES, transform=None)
total_size = len(full_dataset)
indices = list(range(total_size))
np.random.seed(SEED)
np.random.shuffle(indices)

train_size = int(0.8 * total_size)
val_size   = int(0.1 * total_size)

val_indices = indices[:val_size]
train_indices   = indices[val_size:train_size + val_size]
test_indices  = indices[train_size + val_size:]

train_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=train_transform),
    train_indices)

val_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=val_transform),
    val_indices)

test_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=test_transform),
    test_indices)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

# ==========================================
# PATH 2: PRE-TRAINED FASTSAM GLOBAL ENCODER
# ==========================================
class FastSAMEncoder(nn.Module):
    _IN_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1)
    _IN_STD = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1)

    def __init__(self, checkpoint='FastSAM-x.pt', out_channels=512,
                 fine_tune_last=2, feature_size=4, image_size=256):
        super().__init__()
        self.out_ch = out_channels
        self.feature_size = feature_size
        self.fine_tune_last = fine_tune_last

        from ultralytics import FastSAM as _FastSAM
        print(f"[FastSAMEncoder] Loading {checkpoint} ...")
        fs = _FastSAM(checkpoint)
        all_layers = list(fs.model.model)
        del fs

        target_h = image_size // 8
        selected = []
        backbone_out_ch = None

        probe = torch.zeros(1, 3, image_size, image_size)
        with torch.no_grad():
            x = probe
            for layer in all_layers:
                x = layer(x)
                selected.append(layer)
                if x.shape[-2] == target_h:
                    backbone_out_ch = x.shape[1]
                    break

        assert backbone_out_ch is not None

        self.backbone = nn.ModuleList(selected)
        n = len(self.backbone)

        for p in self.backbone.parameters():
            p.requires_grad = False
        for layer in self.backbone[-fine_tune_last:]:
            for p in layer.parameters():
                p.requires_grad = True

        self.proj = nn.Sequential(
            nn.Conv2d(backbone_out_ch, out_channels, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

        self.register_buffer('in_mean', self._IN_MEAN)
        self.register_buffer('in_std', self._IN_STD)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x * self.in_std + self.in_mean
        frozen_end = len(self.backbone) - self.fine_tune_last
        with torch.no_grad():
            for layer in self.backbone[:frozen_end]:
                x = layer(x)
        for layer in self.backbone[frozen_end:]:
            x = layer(x)

        x = self.proj(x)
        if x.shape[-1] != self.feature_size:
            x = F.interpolate(x, size=(self.feature_size, self.feature_size),
                               mode='bilinear', align_corners=False)
        return x

# ==========================================
# CUSTOM MODULES
# ==========================================
class RobertsEdgeOperator(nn.Module):
    def __init__(self):
        super().__init__()
        kx = torch.tensor([[[[1.0, 0.0], [0.0, -1.0]]]])
        ky = torch.tensor([[[[0.0, 1.0], [-1.0, 0.0]]]])
        self.register_buffer("kx", kx)
        self.register_buffer("ky", ky)

    def forward(self, x):
        gray = (0.2989 * x[:, 0:1] + 0.5870 * x[:, 1:2] + 0.1140 * x[:, 2:3])
        gray_padded = F.pad(gray, (0, 1, 0, 1), mode="replicate")
        gx   = F.conv2d(gray_padded, self.kx)
        gy   = F.conv2d(gray_padded, self.ky)
        edge = torch.sqrt(gx ** 2 + gy ** 2 + 1e-8)
        return edge

class PCBAM_Filter(nn.Module):
    def __init__(self, in_channels, reduction=8):
        super().__init__()
        self.cam = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels)
        )
        self.sam = nn.Conv2d(2, 1, kernel_size=7, padding=3, bias=False)

    def forward(self, x):
        b, c, _, _ = x.size()
        avg = self.cam(F.adaptive_avg_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        mxp = self.cam(F.adaptive_max_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        x_c = x * torch.sigmoid(avg + mxp)

        sp  = torch.cat([
            torch.mean(x_c, dim=1, keepdim=True),
            torch.max(x_c,  dim=1, keepdim=True)[0]
        ], dim=1)
        x_s = x_c * torch.sigmoid(self.sam(sp))
        return x_s

class SpatialGateAttention(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        mid = in_channels // 8
        self.q_conv   = nn.Conv2d(in_channels, mid, 1)
        self.k_conv   = nn.Conv2d(in_channels, mid, 1)
        self.v_conv   = nn.Conv2d(in_channels, in_channels, 1)
        self.gate     = nn.Conv2d(mid * 2 + in_channels, in_channels, 1)

    def forward(self, x):
        q = self.q_conv(x)
        k = self.k_conv(x)
        v = self.v_conv(x)
        A = torch.sigmoid(self.gate(torch.cat([q, k, v], dim=1)))
        return x + v * A

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

# ADDED: Attention Gate for Decoder
class AttentionGate(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super().__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        if g1.shape[-2:] != x1.shape[-2:]:
            g1 = F.interpolate(g1, size=x1.shape[-2:], mode='bilinear', align_corners=False)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi

# ==========================================
# DUAL-PATH U-NET
# ==========================================
class PreTrainedDualPathUNet(nn.Module):
    def __init__(self, fastsam_checkpoint='FastSAM-x.pt', # CHANGED TO FastSAM-x
                 fastsam_out_channels=512, fastsam_fine_tune_last=2):
        super().__init__()

        self.global_encoder = FastSAMEncoder(
            checkpoint=fastsam_checkpoint,
            out_channels=fastsam_out_channels,
            fine_tune_last=fastsam_fine_tune_last,
            feature_size=IMG_SIZE // 64,
            image_size=IMG_SIZE,
        )

        self.roberts = RobertsEdgeOperator()

        # CHANGED: ResNet34 to ResNet50
        resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
        old_conv = resnet.conv1
        self.conv1 = nn.Conv2d(4, 64, kernel_size=7, stride=2, padding=3, bias=False)
        with torch.no_grad():
            self.conv1.weight[:, :3] = old_conv.weight
            self.conv1.weight[:, 3]  = old_conv.weight.mean(dim=1)

        self.bn1     = resnet.bn1
        self.relu    = resnet.relu
        self.maxpool = resnet.maxpool

        self.layer1 = resnet.layer1
        self.layer2 = resnet.layer2
        self.layer3 = resnet.layer3
        self.layer4 = resnet.layer4

        # CHANGED: Adjusted PCBAM channels to match ResNet50 output features
        self.pcbam1 = PCBAM_Filter(256)
        self.pcbam2 = PCBAM_Filter(512)
        self.pcbam3 = PCBAM_Filter(1024)
        self.pcbam4 = PCBAM_Filter(2048)

        self.pool       = nn.MaxPool2d(2)
        # CHANGED: Adjusted Bottleneck to match ResNet50 e4 output (2048)
        self.bottleneck = DoubleConv(2048, 1024)

        self.fusion = DoubleConv(1024 + fastsam_out_channels, 1024)
        self.sga    = SpatialGateAttention(1024)

        # CHANGED: Adjusted Attention Gates for ResNet50 Skip Connections
        self.ag4 = AttentionGate(F_g=512, F_l=2048, F_int=512)
        self.ag3 = AttentionGate(F_g=256, F_l=1024, F_int=256)
        self.ag2 = AttentionGate(F_g=128, F_l=512,  F_int=128)
        self.ag1 = AttentionGate(F_g=64,  F_l=256,  F_int=64)

        # CHANGED: Adjusted Decoder Channels for ResNet50 Skip Connections
        self.up4  = nn.ConvTranspose2d(1024, 512, 2, stride=2)
        self.dec4 = DoubleConv(512 + 2048, 512)

        self.up3  = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec3 = DoubleConv(256 + 1024, 256)

        self.up2  = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec2 = DoubleConv(128 + 512, 128)

        self.up1  = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec1 = DoubleConv(64 + 256, 64)

        self.up0  = nn.ConvTranspose2d(64, 64, 2, stride=2)
        self.dec0 = DoubleConv(64 + 64, 64) # x0 remains 64 channels

        self.up_out  = nn.ConvTranspose2d(64, 32, 2, stride=2)
        self.dec_out = DoubleConv(32, 32)
        self.final   = nn.Conv2d(32, 1, 1)

        #  Auxiliary Outputs for Deep Supervision
        self.out_ds2 = nn.Conv2d(128, 1, kernel_size=1)
        self.out_ds1 = nn.Conv2d(64,  1, kernel_size=1)

    def forward(self, x):
        global_feat = self.global_encoder(x)
        x_edge  = self.roberts(x)
        x_fused = torch.cat([x, x_edge], dim=1)

        x0 = self.relu(self.bn1(self.conv1(x_fused)))
        x1 = self.maxpool(x0)

        e1 = self.layer1(x1)
        e2 = self.layer2(e1)
        e3 = self.layer3(e2)
        e4 = self.layer4(e3)

        s1 = self.pcbam1(e1)
        s2 = self.pcbam2(e2)
        s3 = self.pcbam3(e3)
        s4 = self.pcbam4(e4)

        b = self.bottleneck(self.pool(e4))

        if global_feat.shape[-2:] != b.shape[-2:]:
            global_feat = F.interpolate(global_feat, size=b.shape[-2:], mode='bilinear', align_corners=False)

        b = self.fusion(torch.cat([b, global_feat], dim=1))
        b = self.sga(b)

        #  Decoder with Attention Gates
        g4 = self.up4(b)
        x4 = self.ag4(g=g4, x=s4)
        d4 = self.dec4(torch.cat([g4, x4], dim=1))

        g3 = self.up3(d4)
        x3 = self.ag3(g=g3, x=s3)
        d3 = self.dec3(torch.cat([g3, x3], dim=1))

        g2 = self.up2(d3)
        x2 = self.ag2(g=g2, x=s2)
        d2 = self.dec2(torch.cat([g2, x2], dim=1))

        # Deep Supervision Extraction
        out_ds2 = self.out_ds2(d2)

        g1 = self.up1(d2)
        x1 = self.ag1(g=g1, x=s1)
        d1 = self.dec1(torch.cat([g1, x1], dim=1))

        # Deep Supervision Extraction
        out_ds1 = self.out_ds1(d1)

        d0  = self.dec0(torch.cat([self.up0(d1), x0], dim=1))
        out = self.dec_out(self.up_out(d0))

        out_main = self.final(out)
        if self.training:
            return out_main, out_ds1, out_ds2
        else:
            return out_main

# ==========================================
# TVERSKY LOSS & METRICS
# ==========================================
class HybridLoss(nn.Module):
    def __init__(self, smooth=1.0, focal_gamma=2.0, alpha=0.3, beta=0.7):
        super().__init__()
        self.smooth = smooth
        self.focal_gamma = focal_gamma
        self.alpha = alpha
        self.beta = beta

    def forward(self, logits, targets):
        bce = F.binary_cross_entropy_with_logits(logits, targets)
        probs = torch.sigmoid(logits).view(-1)
        tgt = targets.view(-1)

        # Tversky implementation
        tp = (probs * tgt).sum()
        fp = (probs * (1.0 - tgt)).sum()
        fn = ((1.0 - probs) * tgt).sum()
        tversky = (tp + self.smooth) / (tp + self.alpha * fp + self.beta * fn + self.smooth)
        tversky_loss = 1.0 - tversky

        pt = torch.where(tgt == 1, probs, 1.0 - probs)
        focal = (-(1.0 - pt) ** self.focal_gamma * torch.log(pt + 1e-8)).mean()

        return 0.4 * bce + 0.4 * tversky_loss + 0.2 * focal

def dice_coef(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    inter = (y_true_f * y_pred_f).sum()
    return (2. * inter + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

def iou_score(preds, masks, threshold=0.5, eps=1e-6):
    preds_bin = (preds > threshold).float()
    masks_bin = (masks > threshold).float()
    inter = (preds_bin * masks_bin).sum().item()
    union = preds_bin.sum().item() + masks_bin.sum().item() - inter
    return inter / (union + eps)

# ==========================================
# TRAINING FUNCTION
# ==========================================
def train_model(model, train_loader, val_loader, epochs=50):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)

    criterion = HybridLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=10, min_lr=1e-6
    )

    train_losses, val_losses = [], []
    train_dice_scores, val_dice_scores = [], []
    train_iou_scores, val_iou_scores = [], []

    best_val_loss = float("inf")
    best_epoch = 0
    best_model_weights = None

    for epoch in range(epochs):
        model.train()
        train_loss = train_dice = train_iou = 0
        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs} [Train]"):
            images, masks = images.to(device), masks.to(device)

            # ADDED: Deep Supervision Return
            preds_logits, logits_ds1, logits_ds2 = model(images)

            # Rescale targets to match the deep supervision auxiliary output sizes
            mask_ds1 = F.interpolate(masks, size=logits_ds1.shape[-2:], mode='nearest-exact')
            mask_ds2 = F.interpolate(masks, size=logits_ds2.shape[-2:], mode='nearest-exact')

            loss_main = criterion(preds_logits, masks)
            loss_ds1 = criterion(logits_ds1, mask_ds1)
            loss_ds2 = criterion(logits_ds2, mask_ds2)

            # Combine losses
            loss = loss_main + 0.3 * loss_ds1 + 0.1 * loss_ds2

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            preds_probs = torch.sigmoid(preds_logits)

            # Only track main loss for metrics
            train_loss += loss_main.item()
            train_dice += dice_coef(masks, preds_probs).item()
            train_iou += iou_score(preds_probs, masks)

        model.eval()
        val_loss = val_dice = val_iou = 0

        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc=f"Epoch {epoch+1}/{epochs} [Val]"):
                images, masks = images.to(device), masks.to(device)

                preds_logits = model(images)
                loss = criterion(preds_logits, masks)

                preds_probs = torch.sigmoid(preds_logits)

                val_loss += loss.item()
                val_dice += dice_coef(masks, preds_probs).item()
                val_iou += iou_score(preds_probs, masks)

        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        avg_train_dice = train_dice / len(train_loader)
        avg_val_dice   = val_dice / len(val_loader)
        avg_train_iou  = train_iou / len(train_loader)
        avg_val_iou    = val_iou / len(val_loader)

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_dice_scores.append(avg_train_dice)
        val_dice_scores.append(avg_val_dice)
        train_iou_scores.append(avg_train_iou)
        val_iou_scores.append(avg_val_iou)

        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
        print(f"Train Dice: {avg_train_dice:.4f} | Val Dice: {avg_val_dice:.4f}")
        print(f"Train IoU : {avg_train_iou:.4f} | Val IoU : {avg_val_iou:.4f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch + 1
            best_model_weights = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), "best_fastsam_dualpath_unet.pth")
            print(f"✓ Best model saved (Epoch {epoch+1}, Val Loss {best_val_loss:.4f})")

        scheduler.step(avg_val_loss)

    model.load_state_dict(best_model_weights)

    print("\n" + "="*60)
    print("Training Completed!")
    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val Loss: {best_val_loss:.4f}")
    print("="*60)

    return {
        "train_losses": train_losses, "val_losses": val_losses,
        "train_dice": train_dice_scores, "val_dice": val_dice_scores,
        "train_iou": train_iou_scores, "val_iou": val_iou_scores,
    }

def plot_training(history):
    plt.figure(figsize=(17, 4))
    plt.subplot(1, 3, 1)
    plt.plot(history["train_losses"], label="Train Loss", linewidth=2)
    plt.plot(history["val_losses"], label="Val Loss", linewidth=2)
    plt.title("Loss Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 2)
    plt.plot(history["train_dice"], label="Train Dice", linewidth=2)
    plt.plot(history["val_dice"], label="Val Dice", linewidth=2)
    plt.title("Dice Coefficient Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 3)
    plt.plot(history["train_iou"], label="Train IoU", linewidth=2)
    plt.plot(history["val_iou"], label="Val IoU", linewidth=2)
    plt.title("IoU Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("IoU Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=300, bbox_inches='tight')
    plt.show()

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    # CHANGED: Checkpoint to FastSAM-x.pt
    model = PreTrainedDualPathUNet(fastsam_checkpoint='FastSAM-x.pt')
    model = model.to(device)

    print("\n================= MODEL SUMMARY =================\n")
    print(summary(model, input_size=(BATCH_SIZE, 3, IMG_SIZE, IMG_SIZE), mode='eval'))

    history = train_model(model, train_loader, val_loader, epochs=100)
    plot_training(history)

    print("Loading best model...")
    model.load_state_dict(torch.load("best_fastsam_dualpath_unet.pth", map_location=device))
    model.eval()

    test_dice, test_iou = 0, 0
    print("Evaluating on test set...")
    with torch.no_grad():
        for images, masks in tqdm(test_loader, desc="Evaluating Test Set"):
            images, masks = images.to(device), masks.to(device)
            preds_probs = torch.sigmoid(model(images))
            preds_bin = (preds_probs > 0.4).float()
            test_dice += dice_coef(masks, preds_bin).item()
            test_iou += iou_score(preds_probs, masks)

    num_batches = len(test_loader)
    avg_test_dice = test_dice / num_batches
    avg_test_iou = test_iou / num_batches

    print("\n" + "="*40)
    print("TEST SET EVALUATION")
    print("="*40)
    print(f"Dice Coefficient: {avg_test_dice:.4f}")
    print(f"IoU (Jaccard):    {avg_test_iou:.4f}")
    print("="*40)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 100.1 MB/s eta 0:00:0000:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Using device: cuda
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# [FastSAMEncoder] Loading FastSAM-x.pt ...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/FastSAM-x.pt to 'FastSAM-x.pt': 100% ━━━━━━━━━━━━ 138.3MB 76.6MB/s 1.8s 1.7s<0.1s
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 217MB/s]
# ================= MODEL SUMMARY =================
#
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# PreTrainedDualPathUNet                                  [8, 1, 256, 256]          --
# ├─FastSAMEncoder: 1-1                                   [8, 512, 4, 4]            --
# │    └─ModuleList: 2-1                                  --                        --
# │    │    └─Conv: 3-1                                   [8, 80, 128, 128]         (2,320)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─Conv: 3-3                                   [8, 160, 64, 64]          (115,520)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-5                                    [8, 160, 64, 64]          436,800
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-19                                   --                        (recursive)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-19                                   --                        (recursive)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-19                                   --                        (recursive)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-19                                   --                        (recursive)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-19                                   --                        (recursive)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-19                                   --                        (recursive)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─C2f: 3-19                                   --                        (recursive)
# │    │    └─Conv: 3-20                                  --                        (recursive)
# │    │    └─Conv: 3-21                                  [8, 320, 32, 32]          461,440
# │    └─Sequential: 2-2                                  [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-22                                [8, 512, 32, 32]          163,840
# │    │    └─BatchNorm2d: 3-23                           [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-24                                  [8, 512, 32, 32]          --
# ├─RobertsEdgeOperator: 1-2                              [8, 1, 256, 256]          --
# ├─Conv2d: 1-3                                           [8, 64, 128, 128]         12,544
# ├─BatchNorm2d: 1-4                                      [8, 64, 128, 128]         128
# ├─ReLU: 1-5                                             [8, 64, 128, 128]         --
# ├─MaxPool2d: 1-6                                        [8, 64, 64, 64]           --
# ├─Sequential: 1-7                                       [8, 256, 64, 64]          --
# │    └─Bottleneck: 2-3                                  [8, 256, 64, 64]          --
# │    │    └─Conv2d: 3-25                                [8, 64, 64, 64]           4,096
# │    │    └─BatchNorm2d: 3-26                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-27                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-28                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-29                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-30                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-31                                [8, 256, 64, 64]          16,384
# │    │    └─BatchNorm2d: 3-32                           [8, 256, 64, 64]          512
# │    │    └─Sequential: 3-33                            [8, 256, 64, 64]          16,896
# │    │    └─ReLU: 3-34                                  [8, 256, 64, 64]          --
# │    └─Bottleneck: 2-4                                  [8, 256, 64, 64]          --
# │    │    └─Conv2d: 3-35                                [8, 64, 64, 64]           16,384
# │    │    └─BatchNorm2d: 3-36                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-37                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-38                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-39                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-40                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-41                                [8, 256, 64, 64]          16,384
# │    │    └─BatchNorm2d: 3-42                           [8, 256, 64, 64]          512
# │    │    └─ReLU: 3-43                                  [8, 256, 64, 64]          --
# │    └─Bottleneck: 2-5                                  [8, 256, 64, 64]          --
# │    │    └─Conv2d: 3-44                                [8, 64, 64, 64]           16,384
# │    │    └─BatchNorm2d: 3-45                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-46                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-47                                [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-48                           [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-49                                  [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-50                                [8, 256, 64, 64]          16,384
# │    │    └─BatchNorm2d: 3-51                           [8, 256, 64, 64]          512
# │    │    └─ReLU: 3-52                                  [8, 256, 64, 64]          --
# ├─Sequential: 1-8                                       [8, 512, 32, 32]          --
# │    └─Bottleneck: 2-6                                  [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-53                                [8, 128, 64, 64]          32,768
# │    │    └─BatchNorm2d: 3-54                           [8, 128, 64, 64]          256
# │    │    └─ReLU: 3-55                                  [8, 128, 64, 64]          --
# │    │    └─Conv2d: 3-56                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-57                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-58                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-59                                [8, 512, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-60                           [8, 512, 32, 32]          1,024
# │    │    └─Sequential: 3-61                            [8, 512, 32, 32]          132,096
# │    │    └─ReLU: 3-62                                  [8, 512, 32, 32]          --
# │    └─Bottleneck: 2-7                                  [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-63                                [8, 128, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-64                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-65                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-66                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-67                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-68                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-69                                [8, 512, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-70                           [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-71                                  [8, 512, 32, 32]          --
# │    └─Bottleneck: 2-8                                  [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-72                                [8, 128, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-73                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-74                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-75                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-76                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-77                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-78                                [8, 512, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-79                           [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-80                                  [8, 512, 32, 32]          --
# │    └─Bottleneck: 2-9                                  [8, 512, 32, 32]          --
# │    │    └─Conv2d: 3-81                                [8, 128, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-82                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-83                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-84                                [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-85                           [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-86                                  [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-87                                [8, 512, 32, 32]          65,536
# │    │    └─BatchNorm2d: 3-88                           [8, 512, 32, 32]          1,024
# │    │    └─ReLU: 3-89                                  [8, 512, 32, 32]          --
# ├─Sequential: 1-9                                       [8, 1024, 16, 16]         --
# │    └─Bottleneck: 2-10                                 [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-90                                [8, 256, 32, 32]          131,072
# │    │    └─BatchNorm2d: 3-91                           [8, 256, 32, 32]          512
# │    │    └─ReLU: 3-92                                  [8, 256, 32, 32]          --
# │    │    └─Conv2d: 3-93                                [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-94                           [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-95                                  [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-96                                [8, 1024, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-97                           [8, 1024, 16, 16]         2,048
# │    │    └─Sequential: 3-98                            [8, 1024, 16, 16]         526,336
# │    │    └─ReLU: 3-99                                  [8, 1024, 16, 16]         --
# │    └─Bottleneck: 2-11                                 [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-100                               [8, 256, 16, 16]          262,144
# │    │    └─BatchNorm2d: 3-101                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-102                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-103                               [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-104                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-105                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-106                               [8, 1024, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-107                          [8, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-108                                 [8, 1024, 16, 16]         --
# │    └─Bottleneck: 2-12                                 [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-109                               [8, 256, 16, 16]          262,144
# │    │    └─BatchNorm2d: 3-110                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-111                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-112                               [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-113                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-114                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-115                               [8, 1024, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-116                          [8, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-117                                 [8, 1024, 16, 16]         --
# │    └─Bottleneck: 2-13                                 [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-118                               [8, 256, 16, 16]          262,144
# │    │    └─BatchNorm2d: 3-119                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-120                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-121                               [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-122                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-123                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-124                               [8, 1024, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-125                          [8, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-126                                 [8, 1024, 16, 16]         --
# │    └─Bottleneck: 2-14                                 [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-127                               [8, 256, 16, 16]          262,144
# │    │    └─BatchNorm2d: 3-128                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-129                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-130                               [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-131                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-132                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-133                               [8, 1024, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-134                          [8, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-135                                 [8, 1024, 16, 16]         --
# │    └─Bottleneck: 2-15                                 [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-136                               [8, 256, 16, 16]          262,144
# │    │    └─BatchNorm2d: 3-137                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-138                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-139                               [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-140                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-141                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-142                               [8, 1024, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-143                          [8, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-144                                 [8, 1024, 16, 16]         --
# ├─Sequential: 1-10                                      [8, 2048, 8, 8]           --
# │    └─Bottleneck: 2-16                                 [8, 2048, 8, 8]           --
# │    │    └─Conv2d: 3-145                               [8, 512, 16, 16]          524,288
# │    │    └─BatchNorm2d: 3-146                          [8, 512, 16, 16]          1,024
# │    │    └─ReLU: 3-147                                 [8, 512, 16, 16]          --
# │    │    └─Conv2d: 3-148                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-149                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-150                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-151                               [8, 2048, 8, 8]           1,048,576
# │    │    └─BatchNorm2d: 3-152                          [8, 2048, 8, 8]           4,096
# │    │    └─Sequential: 3-153                           [8, 2048, 8, 8]           2,101,248
# │    │    └─ReLU: 3-154                                 [8, 2048, 8, 8]           --
# │    └─Bottleneck: 2-17                                 [8, 2048, 8, 8]           --
# │    │    └─Conv2d: 3-155                               [8, 512, 8, 8]            1,048,576
# │    │    └─BatchNorm2d: 3-156                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-157                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-158                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-159                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-160                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-161                               [8, 2048, 8, 8]           1,048,576
# │    │    └─BatchNorm2d: 3-162                          [8, 2048, 8, 8]           4,096
# │    │    └─ReLU: 3-163                                 [8, 2048, 8, 8]           --
# │    └─Bottleneck: 2-18                                 [8, 2048, 8, 8]           --
# │    │    └─Conv2d: 3-164                               [8, 512, 8, 8]            1,048,576
# │    │    └─BatchNorm2d: 3-165                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-166                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-167                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-168                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-169                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-170                               [8, 2048, 8, 8]           1,048,576
# │    │    └─BatchNorm2d: 3-171                          [8, 2048, 8, 8]           4,096
# │    │    └─ReLU: 3-172                                 [8, 2048, 8, 8]           --
# ├─PCBAM_Filter: 1-11                                    [8, 256, 64, 64]          --
# │    └─Sequential: 2-19                                 [8, 256]                  --
# │    │    └─Linear: 3-173                               [8, 32]                   8,224
# │    │    └─ReLU: 3-174                                 [8, 32]                   --
# │    │    └─Linear: 3-175                               [8, 256]                  8,448
# │    └─Sequential: 2-20                                 [8, 256]                  (recursive)
# │    │    └─Linear: 3-176                               [8, 32]                   (recursive)
# │    │    └─ReLU: 3-177                                 [8, 32]                   --
# │    │    └─Linear: 3-178                               [8, 256]                  (recursive)
# │    └─Conv2d: 2-21                                     [8, 1, 64, 64]            98
# ├─PCBAM_Filter: 1-12                                    [8, 512, 32, 32]          --
# │    └─Sequential: 2-22                                 [8, 512]                  --
# │    │    └─Linear: 3-179                               [8, 64]                   32,832
# │    │    └─ReLU: 3-180                                 [8, 64]                   --
# │    │    └─Linear: 3-181                               [8, 512]                  33,280
# │    └─Sequential: 2-23                                 [8, 512]                  (recursive)
# │    │    └─Linear: 3-182                               [8, 64]                   (recursive)
# │    │    └─ReLU: 3-183                                 [8, 64]                   --
# │    │    └─Linear: 3-184                               [8, 512]                  (recursive)
# │    └─Conv2d: 2-24                                     [8, 1, 32, 32]            98
# ├─PCBAM_Filter: 1-13                                    [8, 1024, 16, 16]         --
# │    └─Sequential: 2-25                                 [8, 1024]                 --
# │    │    └─Linear: 3-185                               [8, 128]                  131,200
# │    │    └─ReLU: 3-186                                 [8, 128]                  --
# │    │    └─Linear: 3-187                               [8, 1024]                 132,096
# │    └─Sequential: 2-26                                 [8, 1024]                 (recursive)
# │    │    └─Linear: 3-188                               [8, 128]                  (recursive)
# │    │    └─ReLU: 3-189                                 [8, 128]                  --
# │    │    └─Linear: 3-190                               [8, 1024]                 (recursive)
# │    └─Conv2d: 2-27                                     [8, 1, 16, 16]            98
# ├─PCBAM_Filter: 1-14                                    [8, 2048, 8, 8]           --
# │    └─Sequential: 2-28                                 [8, 2048]                 --
# │    │    └─Linear: 3-191                               [8, 256]                  524,544
# │    │    └─ReLU: 3-192                                 [8, 256]                  --
# │    │    └─Linear: 3-193                               [8, 2048]                 526,336
# │    └─Sequential: 2-29                                 [8, 2048]                 (recursive)
# │    │    └─Linear: 3-194                               [8, 256]                  (recursive)
# │    │    └─ReLU: 3-195                                 [8, 256]                  --
# │    │    └─Linear: 3-196                               [8, 2048]                 (recursive)
# │    └─Conv2d: 2-30                                     [8, 1, 8, 8]              98
# ├─MaxPool2d: 1-15                                       [8, 2048, 4, 4]           --
# ├─DoubleConv: 1-16                                      [8, 1024, 4, 4]           --
# │    └─Sequential: 2-31                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-197                               [8, 1024, 4, 4]           18,874,368
# │    │    └─BatchNorm2d: 3-198                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-199                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-200                               [8, 1024, 4, 4]           9,437,184
# │    │    └─BatchNorm2d: 3-201                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-202                                 [8, 1024, 4, 4]           --
# ├─DoubleConv: 1-17                                      [8, 1024, 4, 4]           --
# │    └─Sequential: 2-32                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-203                               [8, 1024, 4, 4]           14,155,776
# │    │    └─BatchNorm2d: 3-204                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-205                                 [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-206                               [8, 1024, 4, 4]           9,437,184
# │    │    └─BatchNorm2d: 3-207                          [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-208                                 [8, 1024, 4, 4]           --
# ├─SpatialGateAttention: 1-18                            [8, 1024, 4, 4]           --
# │    └─Conv2d: 2-33                                     [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-34                                     [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-35                                     [8, 1024, 4, 4]           1,049,600
# │    └─Conv2d: 2-36                                     [8, 1024, 4, 4]           1,311,744
# ├─ConvTranspose2d: 1-19                                 [8, 512, 8, 8]            2,097,664
# ├─AttentionGate: 1-20                                   [8, 2048, 8, 8]           --
# │    └─Sequential: 2-37                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-209                               [8, 512, 8, 8]            262,656
# │    │    └─BatchNorm2d: 3-210                          [8, 512, 8, 8]            1,024
# │    └─Sequential: 2-38                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-211                               [8, 512, 8, 8]            1,049,088
# │    │    └─BatchNorm2d: 3-212                          [8, 512, 8, 8]            1,024
# │    └─ReLU: 2-39                                       [8, 512, 8, 8]            --
# │    └─Sequential: 2-40                                 [8, 1, 8, 8]              --
# │    │    └─Conv2d: 3-213                               [8, 1, 8, 8]              513
# │    │    └─BatchNorm2d: 3-214                          [8, 1, 8, 8]              2
# │    │    └─Sigmoid: 3-215                              [8, 1, 8, 8]              --
# ├─DoubleConv: 1-21                                      [8, 512, 8, 8]            --
# │    └─Sequential: 2-41                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-216                               [8, 512, 8, 8]            11,796,480
# │    │    └─BatchNorm2d: 3-217                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-218                                 [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-219                               [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-220                          [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-221                                 [8, 512, 8, 8]            --
# ├─ConvTranspose2d: 1-22                                 [8, 256, 16, 16]          524,544
# ├─AttentionGate: 1-23                                   [8, 1024, 16, 16]         --
# │    └─Sequential: 2-42                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-222                               [8, 256, 16, 16]          65,792
# │    │    └─BatchNorm2d: 3-223                          [8, 256, 16, 16]          512
# │    └─Sequential: 2-43                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-224                               [8, 256, 16, 16]          262,400
# │    │    └─BatchNorm2d: 3-225                          [8, 256, 16, 16]          512
# │    └─ReLU: 2-44                                       [8, 256, 16, 16]          --
# │    └─Sequential: 2-45                                 [8, 1, 16, 16]            --
# │    │    └─Conv2d: 3-226                               [8, 1, 16, 16]            257
# │    │    └─BatchNorm2d: 3-227                          [8, 1, 16, 16]            2
# │    │    └─Sigmoid: 3-228                              [8, 1, 16, 16]            --
# ├─DoubleConv: 1-24                                      [8, 256, 16, 16]          --
# │    └─Sequential: 2-46                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-229                               [8, 256, 16, 16]          2,949,120
# │    │    └─BatchNorm2d: 3-230                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-231                                 [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-232                               [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-233                          [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-234                                 [8, 256, 16, 16]          --
# ├─ConvTranspose2d: 1-25                                 [8, 128, 32, 32]          131,200
# ├─AttentionGate: 1-26                                   [8, 512, 32, 32]          --
# │    └─Sequential: 2-47                                 [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-235                               [8, 128, 32, 32]          16,512
# │    │    └─BatchNorm2d: 3-236                          [8, 128, 32, 32]          256
# │    └─Sequential: 2-48                                 [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-237                               [8, 128, 32, 32]          65,664
# │    │    └─BatchNorm2d: 3-238                          [8, 128, 32, 32]          256
# │    └─ReLU: 2-49                                       [8, 128, 32, 32]          --
# │    └─Sequential: 2-50                                 [8, 1, 32, 32]            --
# │    │    └─Conv2d: 3-239                               [8, 1, 32, 32]            129
# │    │    └─BatchNorm2d: 3-240                          [8, 1, 32, 32]            2
# │    │    └─Sigmoid: 3-241                              [8, 1, 32, 32]            --
# ├─DoubleConv: 1-27                                      [8, 128, 32, 32]          --
# │    └─Sequential: 2-51                                 [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-242                               [8, 128, 32, 32]          737,280
# │    │    └─BatchNorm2d: 3-243                          [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-244                                 [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-245                               [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-246                          [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-247                                 [8, 128, 32, 32]          --
# ├─Conv2d: 1-28                                          [8, 1, 32, 32]            129
# ├─ConvTranspose2d: 1-29                                 [8, 64, 64, 64]           32,832
# ├─AttentionGate: 1-30                                   [8, 256, 64, 64]          --
# │    └─Sequential: 2-52                                 [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-248                               [8, 64, 64, 64]           4,160
# │    │    └─BatchNorm2d: 3-249                          [8, 64, 64, 64]           128
# │    └─Sequential: 2-53                                 [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-250                               [8, 64, 64, 64]           16,448
# │    │    └─BatchNorm2d: 3-251                          [8, 64, 64, 64]           128
# │    └─ReLU: 2-54                                       [8, 64, 64, 64]           --
# │    └─Sequential: 2-55                                 [8, 1, 64, 64]            --
# │    │    └─Conv2d: 3-252                               [8, 1, 64, 64]            65
# │    │    └─BatchNorm2d: 3-253                          [8, 1, 64, 64]            2
# │    │    └─Sigmoid: 3-254                              [8, 1, 64, 64]            --
# ├─DoubleConv: 1-31                                      [8, 64, 64, 64]           --
# │    └─Sequential: 2-56                                 [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-255                               [8, 64, 64, 64]           184,320
# │    │    └─BatchNorm2d: 3-256                          [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-257                                 [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-258                               [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-259                          [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-260                                 [8, 64, 64, 64]           --
# ├─Conv2d: 1-32                                          [8, 1, 64, 64]            65
# ├─ConvTranspose2d: 1-33                                 [8, 64, 128, 128]         16,448
# ├─DoubleConv: 1-34                                      [8, 64, 128, 128]         --
# │    └─Sequential: 2-57                                 [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-261                               [8, 64, 128, 128]         73,728
# │    │    └─BatchNorm2d: 3-262                          [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-263                                 [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-264                               [8, 64, 128, 128]         36,864
# │    │    └─BatchNorm2d: 3-265                          [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-266                                 [8, 64, 128, 128]         --
# ├─ConvTranspose2d: 1-35                                 [8, 32, 256, 256]         8,224
# ├─DoubleConv: 1-36                                      [8, 32, 256, 256]         --
# │    └─Sequential: 2-58                                 [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-267                               [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-268                          [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-269                                 [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-270                               [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-271                          [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-272                                 [8, 32, 256, 256]         --
# ├─Conv2d: 1-37                                          [8, 1, 256, 256]          33
# =========================================================================================================
# Total params: 104,702,631
# Trainable params: 104,584,791
# Non-trainable params: 117,840
# Total mult-adds (Units.GIGABYTES): 140.19
# =========================================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 3944.83
# Params size (MB): 416.47
# Estimated Total Size (MB): 4367.60
# =========================================================================================================
# Epoch 1/100 [Train]: 100%|██████████| 65/65 [00:50<00:00,  1.30it/s]
# Epoch 1/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  6.02it/s]
# Epoch 1/100
# Train Loss: 0.5617 | Val Loss: 0.4994
# Train Dice: 0.2068 | Val Dice: 0.2391
# Train IoU : 0.2833 | Val IoU : 0.4758
# ✓ Best model saved (Epoch 1, Val Loss 0.4994)
# Epoch 2/100 [Train]: 100%|██████████| 65/65 [00:22<00:00,  2.93it/s]
# Epoch 2/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.64it/s]
# Epoch 2/100
# Train Loss: 0.4618 | Val Loss: 0.4671
# Train Dice: 0.2737 | Val Dice: 0.2794
# Train IoU : 0.4861 | Val IoU : 0.4980
# ✓ Best model saved (Epoch 2, Val Loss 0.4671)
# Epoch 3/100 [Train]: 100%|██████████| 65/65 [00:22<00:00,  2.86it/s]
# Epoch 3/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.72it/s]
# Epoch 3/100
# Train Loss: 0.4350 | Val Loss: 0.4086
# Train Dice: 0.2895 | Val Dice: 0.2969
# Train IoU : 0.4951 | Val IoU : 0.5308
# ✓ Best model saved (Epoch 3, Val Loss 0.4086)
# Epoch 4/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.78it/s]
# Epoch 4/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.40it/s]
# Epoch 4/100
# Train Loss: 0.4104 | Val Loss: 0.4030
# Train Dice: 0.3111 | Val Dice: 0.3166
# Train IoU : 0.5238 | Val IoU : 0.5349
# ✓ Best model saved (Epoch 4, Val Loss 0.4030)
# Epoch 5/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.73it/s]
# Epoch 5/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 5/100
# Train Loss: 0.3875 | Val Loss: 0.3930
# Train Dice: 0.3297 | Val Dice: 0.3080
# Train IoU : 0.5737 | Val IoU : 0.5519
# ✓ Best model saved (Epoch 5, Val Loss 0.3930)
# Epoch 6/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 6/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.41it/s]
# Epoch 6/100
# Train Loss: 0.3762 | Val Loss: 0.4013
# Train Dice: 0.3431 | Val Dice: 0.3383
# Train IoU : 0.5706 | Val IoU : 0.5068
# Epoch 7/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.77it/s]
# Epoch 7/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.29it/s]
# Epoch 7/100
# Train Loss: 0.3639 | Val Loss: 0.3674
# Train Dice: 0.3551 | Val Dice: 0.3191
# Train IoU : 0.5831 | Val IoU : 0.5932
# ✓ Best model saved (Epoch 7, Val Loss 0.3674)
# Epoch 8/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 8/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.27it/s]
# Epoch 8/100
# Train Loss: 0.3508 | Val Loss: 0.3839
# Train Dice: 0.3681 | Val Dice: 0.3424
# Train IoU : 0.6012 | Val IoU : 0.5538
# Epoch 9/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 9/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.42it/s]
# Epoch 9/100
# Train Loss: 0.3414 | Val Loss: 0.3397
# Train Dice: 0.3775 | Val Dice: 0.3755
# Train IoU : 0.5934 | Val IoU : 0.6080
# ✓ Best model saved (Epoch 9, Val Loss 0.3397)
# Epoch 10/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 10/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.31it/s]
# Epoch 10/100
# Train Loss: 0.3159 | Val Loss: 0.3376
# Train Dice: 0.4073 | Val Dice: 0.3808
# Train IoU : 0.6450 | Val IoU : 0.5905
# ✓ Best model saved (Epoch 10, Val Loss 0.3376)
# Epoch 11/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 11/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.43it/s]
# Epoch 11/100
# Train Loss: 0.3072 | Val Loss: 0.3320
# Train Dice: 0.4179 | Val Dice: 0.3920
# Train IoU : 0.6431 | Val IoU : 0.5836
# ✓ Best model saved (Epoch 11, Val Loss 0.3320)
# Epoch 12/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 12/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.47it/s]
# Epoch 12/100
# Train Loss: 0.2986 | Val Loss: 0.3091
# Train Dice: 0.4274 | Val Dice: 0.4026
# Train IoU : 0.6537 | Val IoU : 0.6101
# ✓ Best model saved (Epoch 12, Val Loss 0.3091)
# Epoch 13/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.77it/s]
# Epoch 13/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.45it/s]
# Epoch 13/100
# Train Loss: 0.2833 | Val Loss: 0.3120
# Train Dice: 0.4494 | Val Dice: 0.4201
# Train IoU : 0.6711 | Val IoU : 0.6061
# Epoch 14/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 14/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 14/100
# Train Loss: 0.2744 | Val Loss: 0.3055
# Train Dice: 0.4619 | Val Dice: 0.4246
# Train IoU : 0.6640 | Val IoU : 0.5863
# ✓ Best model saved (Epoch 14, Val Loss 0.3055)
# Epoch 15/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 15/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.28it/s]
# Epoch 15/100
# Train Loss: 0.2687 | Val Loss: 0.2675
# Train Dice: 0.4711 | Val Dice: 0.4603
# Train IoU : 0.6570 | Val IoU : 0.6183
# ✓ Best model saved (Epoch 15, Val Loss 0.2675)
# Epoch 16/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 16/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.39it/s]
# Epoch 16/100
# Train Loss: 0.2596 | Val Loss: 0.2862
# Train Dice: 0.4856 | Val Dice: 0.4433
# Train IoU : 0.6710 | Val IoU : 0.5873
# Epoch 17/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 17/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.41it/s]
# Epoch 17/100
# Train Loss: 0.2507 | Val Loss: 0.2868
# Train Dice: 0.4991 | Val Dice: 0.4517
# Train IoU : 0.6772 | Val IoU : 0.6004
# Epoch 18/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 18/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 18/100
# Train Loss: 0.2462 | Val Loss: 0.2613
# Train Dice: 0.5052 | Val Dice: 0.4840
# Train IoU : 0.6710 | Val IoU : 0.6211
# ✓ Best model saved (Epoch 18, Val Loss 0.2613)
# Epoch 19/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 19/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 19/100
# Train Loss: 0.2312 | Val Loss: 0.3059
# Train Dice: 0.5288 | Val Dice: 0.4569
# Train IoU : 0.6958 | Val IoU : 0.5420
# Epoch 20/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 20/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.42it/s]
# Epoch 20/100
# Train Loss: 0.2230 | Val Loss: 0.2674
# Train Dice: 0.5411 | Val Dice: 0.4751
# Train IoU : 0.6989 | Val IoU : 0.5827
# Epoch 21/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 21/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.29it/s]
# Epoch 21/100
# Train Loss: 0.2114 | Val Loss: 0.2670
# Train Dice: 0.5599 | Val Dice: 0.4975
# Train IoU : 0.7194 | Val IoU : 0.5769
# Epoch 22/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 22/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.42it/s]
# Epoch 22/100
# Train Loss: 0.2034 | Val Loss: 0.2421
# Train Dice: 0.5794 | Val Dice: 0.5428
# Train IoU : 0.7271 | Val IoU : 0.6343
# ✓ Best model saved (Epoch 22, Val Loss 0.2421)
# Epoch 23/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 23/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 23/100
# Train Loss: 0.2055 | Val Loss: 0.2399
# Train Dice: 0.5743 | Val Dice: 0.5259
# Train IoU : 0.7158 | Val IoU : 0.6376
# ✓ Best model saved (Epoch 23, Val Loss 0.2399)
# Epoch 24/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 24/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.35it/s]
# Epoch 24/100
# Train Loss: 0.1993 | Val Loss: 0.2374
# Train Dice: 0.5896 | Val Dice: 0.5477
# Train IoU : 0.7065 | Val IoU : 0.6270
# ✓ Best model saved (Epoch 24, Val Loss 0.2374)
# Epoch 25/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 25/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.41it/s]
# Epoch 25/100
# Train Loss: 0.1891 | Val Loss: 0.2319
# Train Dice: 0.6066 | Val Dice: 0.5341
# Train IoU : 0.7239 | Val IoU : 0.6290
# ✓ Best model saved (Epoch 25, Val Loss 0.2319)
# Epoch 26/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.77it/s]
# Epoch 26/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.35it/s]
# Epoch 26/100
# Train Loss: 0.1857 | Val Loss: 0.2325
# Train Dice: 0.6154 | Val Dice: 0.5464
# Train IoU : 0.7228 | Val IoU : 0.6140
# Epoch 27/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 27/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.41it/s]
# Epoch 27/100
# Train Loss: 0.1856 | Val Loss: 0.2427
# Train Dice: 0.6188 | Val Dice: 0.5485
# Train IoU : 0.7203 | Val IoU : 0.5634
# Epoch 28/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 28/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.38it/s]
# Epoch 28/100
# Train Loss: 0.1744 | Val Loss: 0.2130
# Train Dice: 0.6386 | Val Dice: 0.5762
# Train IoU : 0.7303 | Val IoU : 0.6404
# ✓ Best model saved (Epoch 28, Val Loss 0.2130)
# Epoch 29/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 29/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.37it/s]
# Epoch 29/100
# Train Loss: 0.1706 | Val Loss: 0.1943
# Train Dice: 0.6476 | Val Dice: 0.6183
# Train IoU : 0.7324 | Val IoU : 0.6410
# ✓ Best model saved (Epoch 29, Val Loss 0.1943)
# Epoch 30/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 30/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.40it/s]
# Epoch 30/100
# Train Loss: 0.1633 | Val Loss: 0.1903
# Train Dice: 0.6618 | Val Dice: 0.6265
# Train IoU : 0.7358 | Val IoU : 0.6425
# ✓ Best model saved (Epoch 30, Val Loss 0.1903)
# Epoch 31/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 31/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.45it/s]
# Epoch 31/100
# Train Loss: 0.1608 | Val Loss: 0.2169
# Train Dice: 0.6701 | Val Dice: 0.5860
# Train IoU : 0.7342 | Val IoU : 0.5857
# Epoch 32/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 32/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.33it/s]
# Epoch 32/100
# Train Loss: 0.1513 | Val Loss: 0.2086
# Train Dice: 0.6856 | Val Dice: 0.6138
# Train IoU : 0.7550 | Val IoU : 0.6133
# Epoch 33/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 33/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.22it/s]
# Epoch 33/100
# Train Loss: 0.1491 | Val Loss: 0.2084
# Train Dice: 0.6858 | Val Dice: 0.6214
# Train IoU : 0.7538 | Val IoU : 0.6035
# Epoch 34/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 34/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.37it/s]
# Epoch 34/100
# Train Loss: 0.1471 | Val Loss: 0.2063
# Train Dice: 0.6989 | Val Dice: 0.6107
# Train IoU : 0.7493 | Val IoU : 0.6080
# Epoch 35/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 35/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.30it/s]
# Epoch 35/100
# Train Loss: 0.1524 | Val Loss: 0.2037
# Train Dice: 0.6913 | Val Dice: 0.6161
# Train IoU : 0.7293 | Val IoU : 0.6276
# Epoch 36/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 36/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 36/100
# Train Loss: 0.1432 | Val Loss: 0.2070
# Train Dice: 0.7057 | Val Dice: 0.6361
# Train IoU : 0.7454 | Val IoU : 0.6249
# Epoch 37/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 37/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.32it/s]
# Epoch 37/100
# Train Loss: 0.1390 | Val Loss: 0.1808
# Train Dice: 0.7165 | Val Dice: 0.6587
# Train IoU : 0.7513 | Val IoU : 0.6352
# ✓ Best model saved (Epoch 37, Val Loss 0.1808)
# Epoch 38/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 38/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.33it/s]
# Epoch 38/100
# Train Loss: 0.1236 | Val Loss: 0.1973
# Train Dice: 0.7431 | Val Dice: 0.6334
# Train IoU : 0.7802 | Val IoU : 0.6162
# Epoch 39/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 39/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.46it/s]
# Epoch 39/100
# Train Loss: 0.1288 | Val Loss: 0.2012
# Train Dice: 0.7367 | Val Dice: 0.6541
# Train IoU : 0.7640 | Val IoU : 0.6281
# Epoch 40/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 40/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.37it/s]
# Epoch 40/100
# Train Loss: 0.1340 | Val Loss: 0.1762
# Train Dice: 0.7359 | Val Dice: 0.6773
# Train IoU : 0.7452 | Val IoU : 0.6292
# ✓ Best model saved (Epoch 40, Val Loss 0.1762)
# Epoch 41/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 41/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.38it/s]
# Epoch 41/100
# Train Loss: 0.1302 | Val Loss: 0.1803
# Train Dice: 0.7438 | Val Dice: 0.6797
# Train IoU : 0.7568 | Val IoU : 0.6365
# Epoch 42/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 42/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.38it/s]
# Epoch 42/100
# Train Loss: 0.1187 | Val Loss: 0.1801
# Train Dice: 0.7586 | Val Dice: 0.6709
# Train IoU : 0.7826 | Val IoU : 0.6500
# Epoch 43/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 43/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.31it/s]
# Epoch 43/100
# Train Loss: 0.1242 | Val Loss: 0.1979
# Train Dice: 0.7562 | Val Dice: 0.6567
# Train IoU : 0.7631 | Val IoU : 0.6119
# Epoch 44/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 44/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.10it/s]
# Epoch 44/100
# Train Loss: 0.1234 | Val Loss: 0.2034
# Train Dice: 0.7565 | Val Dice: 0.6599
# Train IoU : 0.7631 | Val IoU : 0.5950
# Epoch 45/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 45/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 45/100
# Train Loss: 0.1145 | Val Loss: 0.1660
# Train Dice: 0.7704 | Val Dice: 0.6868
# Train IoU : 0.7710 | Val IoU : 0.6488
# ✓ Best model saved (Epoch 45, Val Loss 0.1660)
# Epoch 46/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 46/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.24it/s]
# Epoch 46/100
# Train Loss: 0.1076 | Val Loss: 0.1951
# Train Dice: 0.7869 | Val Dice: 0.6635
# Train IoU : 0.7855 | Val IoU : 0.5830
# Epoch 47/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 47/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.41it/s]
# Epoch 47/100
# Train Loss: 0.1139 | Val Loss: 0.1971
# Train Dice: 0.7744 | Val Dice: 0.6613
# Train IoU : 0.7692 | Val IoU : 0.5980
# Epoch 48/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 48/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.33it/s]
# Epoch 48/100
# Train Loss: 0.1035 | Val Loss: 0.2046
# Train Dice: 0.7949 | Val Dice: 0.6814
# Train IoU : 0.7939 | Val IoU : 0.6033
# Epoch 49/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 49/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.18it/s]
# Epoch 49/100
# Train Loss: 0.1023 | Val Loss: 0.1862
# Train Dice: 0.8003 | Val Dice: 0.6795
# Train IoU : 0.7927 | Val IoU : 0.6083
# Epoch 50/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 50/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.25it/s]
# Epoch 50/100
# Train Loss: 0.1059 | Val Loss: 0.1854
# Train Dice: 0.7939 | Val Dice: 0.6977
# Train IoU : 0.7901 | Val IoU : 0.6066
# Epoch 51/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 51/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.31it/s]
# Epoch 51/100
# Train Loss: 0.1048 | Val Loss: 0.1947
# Train Dice: 0.7981 | Val Dice: 0.6749
# Train IoU : 0.7861 | Val IoU : 0.5955
# Epoch 52/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 52/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.37it/s]
# Epoch 52/100
# Train Loss: 0.1090 | Val Loss: 0.2210
# Train Dice: 0.7959 | Val Dice: 0.6679
# Train IoU : 0.7771 | Val IoU : 0.5799
# Epoch 53/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 53/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.19it/s]
# Epoch 53/100
# Train Loss: 0.1085 | Val Loss: 0.2020
# Train Dice: 0.7976 | Val Dice: 0.6749
# Train IoU : 0.7761 | Val IoU : 0.5837
# Epoch 54/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 54/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.35it/s]
# Epoch 54/100
# Train Loss: 0.1046 | Val Loss: 0.1819
# Train Dice: 0.8026 | Val Dice: 0.7008
# Train IoU : 0.7773 | Val IoU : 0.6226
# Epoch 55/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 55/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.39it/s]
# Epoch 55/100
# Train Loss: 0.1082 | Val Loss: 0.2085
# Train Dice: 0.7974 | Val Dice: 0.6742
# Train IoU : 0.7718 | Val IoU : 0.5713
# Epoch 56/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 56/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.29it/s]
# Epoch 56/100
# Train Loss: 0.0971 | Val Loss: 0.1920
# Train Dice: 0.8177 | Val Dice: 0.6971
# Train IoU : 0.7963 | Val IoU : 0.6109
# Epoch 57/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 57/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.33it/s]
# Epoch 57/100
# Train Loss: 0.0982 | Val Loss: 0.1921
# Train Dice: 0.8197 | Val Dice: 0.6959
# Train IoU : 0.7950 | Val IoU : 0.5990
# Epoch 58/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 58/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.37it/s]
# Epoch 58/100
# Train Loss: 0.0912 | Val Loss: 0.1778
# Train Dice: 0.8273 | Val Dice: 0.7086
# Train IoU : 0.8053 | Val IoU : 0.6117
# Epoch 59/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 59/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.31it/s]
# Epoch 59/100
# Train Loss: 0.0903 | Val Loss: 0.1815
# Train Dice: 0.8245 | Val Dice: 0.7046
# Train IoU : 0.8079 | Val IoU : 0.6146
# Epoch 60/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 60/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 60/100
# Train Loss: 0.0857 | Val Loss: 0.1840
# Train Dice: 0.8358 | Val Dice: 0.7077
# Train IoU : 0.8109 | Val IoU : 0.6136
# Epoch 61/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 61/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 61/100
# Train Loss: 0.0832 | Val Loss: 0.1989
# Train Dice: 0.8401 | Val Dice: 0.6993
# Train IoU : 0.8154 | Val IoU : 0.5922
# Epoch 62/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 62/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.37it/s]
# Epoch 62/100
# Train Loss: 0.0885 | Val Loss: 0.1798
# Train Dice: 0.8317 | Val Dice: 0.7147
# Train IoU : 0.8100 | Val IoU : 0.6188
# Epoch 63/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.77it/s]
# Epoch 63/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 63/100
# Train Loss: 0.0914 | Val Loss: 0.1994
# Train Dice: 0.8262 | Val Dice: 0.7044
# Train IoU : 0.7994 | Val IoU : 0.6070
# Epoch 64/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 64/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.29it/s]
# Epoch 64/100
# Train Loss: 0.0808 | Val Loss: 0.1984
# Train Dice: 0.8464 | Val Dice: 0.7071
# Train IoU : 0.8222 | Val IoU : 0.6060
# Epoch 65/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 65/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.42it/s]
# Epoch 65/100
# Train Loss: 0.0858 | Val Loss: 0.1929
# Train Dice: 0.8408 | Val Dice: 0.7119
# Train IoU : 0.8145 | Val IoU : 0.6118
# Epoch 66/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 66/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.29it/s]
# Epoch 66/100
# Train Loss: 0.0764 | Val Loss: 0.1993
# Train Dice: 0.8497 | Val Dice: 0.7047
# Train IoU : 0.8279 | Val IoU : 0.6094
# Epoch 67/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 67/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.30it/s]
# Epoch 67/100
# Train Loss: 0.0807 | Val Loss: 0.2055
# Train Dice: 0.8488 | Val Dice: 0.6989
# Train IoU : 0.8216 | Val IoU : 0.5956
# Epoch 68/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 68/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.22it/s]
# Epoch 68/100
# Train Loss: 0.0739 | Val Loss: 0.1976
# Train Dice: 0.8549 | Val Dice: 0.7075
# Train IoU : 0.8325 | Val IoU : 0.6072
# Epoch 69/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 69/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 69/100
# Train Loss: 0.0753 | Val Loss: 0.1942
# Train Dice: 0.8555 | Val Dice: 0.7103
# Train IoU : 0.8305 | Val IoU : 0.6041
# Epoch 70/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 70/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.29it/s]
# Epoch 70/100
# Train Loss: 0.0710 | Val Loss: 0.1992
# Train Dice: 0.8623 | Val Dice: 0.7099
# Train IoU : 0.8393 | Val IoU : 0.6092
# Epoch 71/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 71/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.20it/s]
# Epoch 71/100
# Train Loss: 0.0717 | Val Loss: 0.1926
# Train Dice: 0.8653 | Val Dice: 0.7112
# Train IoU : 0.8400 | Val IoU : 0.6111
# Epoch 72/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 72/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 72/100
# Train Loss: 0.0726 | Val Loss: 0.2016
# Train Dice: 0.8585 | Val Dice: 0.7087
# Train IoU : 0.8359 | Val IoU : 0.6076
# Epoch 73/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 73/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.35it/s]
# Epoch 73/100
# Train Loss: 0.0698 | Val Loss: 0.1948
# Train Dice: 0.8675 | Val Dice: 0.7138
# Train IoU : 0.8448 | Val IoU : 0.6108
# Epoch 74/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 74/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 74/100
# Train Loss: 0.0755 | Val Loss: 0.1933
# Train Dice: 0.8590 | Val Dice: 0.7103
# Train IoU : 0.8313 | Val IoU : 0.6109
# Epoch 75/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 75/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.32it/s]
# Epoch 75/100
# Train Loss: 0.0729 | Val Loss: 0.1881
# Train Dice: 0.8621 | Val Dice: 0.7165
# Train IoU : 0.8359 | Val IoU : 0.6173
# Epoch 76/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 76/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.39it/s]
# Epoch 76/100
# Train Loss: 0.0642 | Val Loss: 0.1942
# Train Dice: 0.8730 | Val Dice: 0.7151
# Train IoU : 0.8525 | Val IoU : 0.6107
# Epoch 77/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 77/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.40it/s]
# Epoch 77/100
# Train Loss: 0.0676 | Val Loss: 0.1941
# Train Dice: 0.8708 | Val Dice: 0.7147
# Train IoU : 0.8461 | Val IoU : 0.6117
# Epoch 78/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.77it/s]
# Epoch 78/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.43it/s]
# Epoch 78/100
# Train Loss: 0.0691 | Val Loss: 0.1916
# Train Dice: 0.8688 | Val Dice: 0.7156
# Train IoU : 0.8410 | Val IoU : 0.6137
# Epoch 79/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 79/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.43it/s]
# Epoch 79/100
# Train Loss: 0.0655 | Val Loss: 0.2014
# Train Dice: 0.8712 | Val Dice: 0.7125
# Train IoU : 0.8495 | Val IoU : 0.6083
# Epoch 80/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 80/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.42it/s]
# Epoch 80/100
# Train Loss: 0.0662 | Val Loss: 0.1944
# Train Dice: 0.8719 | Val Dice: 0.7154
# Train IoU : 0.8485 | Val IoU : 0.6091
# Epoch 81/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 81/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.43it/s]
# Epoch 81/100
# Train Loss: 0.0697 | Val Loss: 0.1884
# Train Dice: 0.8660 | Val Dice: 0.7202
# Train IoU : 0.8434 | Val IoU : 0.6127
# Epoch 82/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 82/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.32it/s]
# Epoch 82/100
# Train Loss: 0.0676 | Val Loss: 0.1977
# Train Dice: 0.8685 | Val Dice: 0.7192
# Train IoU : 0.8434 | Val IoU : 0.6135
# Epoch 83/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 83/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.19it/s]
# Epoch 83/100
# Train Loss: 0.0653 | Val Loss: 0.1924
# Train Dice: 0.8757 | Val Dice: 0.7198
# Train IoU : 0.8515 | Val IoU : 0.6148
# Epoch 84/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 84/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.42it/s]
# Epoch 84/100
# Train Loss: 0.0669 | Val Loss: 0.1888
# Train Dice: 0.8728 | Val Dice: 0.7251
# Train IoU : 0.8450 | Val IoU : 0.6202
# Epoch 85/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 85/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 85/100
# Train Loss: 0.0644 | Val Loss: 0.1894
# Train Dice: 0.8748 | Val Dice: 0.7218
# Train IoU : 0.8512 | Val IoU : 0.6171
# Epoch 86/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 86/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]
# Epoch 86/100
# Train Loss: 0.0680 | Val Loss: 0.1910
# Train Dice: 0.8685 | Val Dice: 0.7216
# Train IoU : 0.8390 | Val IoU : 0.6207
# Epoch 87/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 87/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.50it/s]
# Epoch 87/100
# Train Loss: 0.0656 | Val Loss: 0.1897
# Train Dice: 0.8766 | Val Dice: 0.7233
# Train IoU : 0.8526 | Val IoU : 0.6200
# Epoch 88/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 88/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 88/100
# Train Loss: 0.0648 | Val Loss: 0.1933
# Train Dice: 0.8746 | Val Dice: 0.7207
# Train IoU : 0.8505 | Val IoU : 0.6166
# Epoch 89/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 89/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.35it/s]
# Epoch 89/100
# Train Loss: 0.0650 | Val Loss: 0.1896
# Train Dice: 0.8757 | Val Dice: 0.7226
# Train IoU : 0.8488 | Val IoU : 0.6204
# Epoch 90/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 90/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.34it/s]
# Epoch 90/100
# Train Loss: 0.0652 | Val Loss: 0.1881
# Train Dice: 0.8753 | Val Dice: 0.7243
# Train IoU : 0.8489 | Val IoU : 0.6202
# Epoch 91/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 91/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.30it/s]
# Epoch 91/100
# Train Loss: 0.0629 | Val Loss: 0.1982
# Train Dice: 0.8787 | Val Dice: 0.7126
# Train IoU : 0.8534 | Val IoU : 0.6089
# Epoch 92/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 92/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.25it/s]
# Epoch 92/100
# Train Loss: 0.0601 | Val Loss: 0.1879
# Train Dice: 0.8829 | Val Dice: 0.7246
# Train IoU : 0.8601 | Val IoU : 0.6213
# Epoch 93/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 93/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.33it/s]
# Epoch 93/100
# Train Loss: 0.0639 | Val Loss: 0.1878
# Train Dice: 0.8768 | Val Dice: 0.7250
# Train IoU : 0.8520 | Val IoU : 0.6207
# Epoch 94/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 94/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.33it/s]
# Epoch 94/100
# Train Loss: 0.0607 | Val Loss: 0.1905
# Train Dice: 0.8821 | Val Dice: 0.7239
# Train IoU : 0.8572 | Val IoU : 0.6201
# Epoch 95/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 95/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.30it/s]
# Epoch 95/100
# Train Loss: 0.0613 | Val Loss: 0.1923
# Train Dice: 0.8820 | Val Dice: 0.7264
# Train IoU : 0.8577 | Val IoU : 0.6223
# Epoch 96/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 96/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.38it/s]
# Epoch 96/100
# Train Loss: 0.0628 | Val Loss: 0.1898
# Train Dice: 0.8783 | Val Dice: 0.7250
# Train IoU : 0.8533 | Val IoU : 0.6196
# Epoch 97/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.74it/s]
# Epoch 97/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.22it/s]
# Epoch 97/100
# Train Loss: 0.0694 | Val Loss: 0.1920
# Train Dice: 0.8709 | Val Dice: 0.7256
# Train IoU : 0.8395 | Val IoU : 0.6209
# Epoch 98/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.75it/s]
# Epoch 98/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.39it/s]
# Epoch 98/100
# Train Loss: 0.0634 | Val Loss: 0.1887
# Train Dice: 0.8784 | Val Dice: 0.7288
# Train IoU : 0.8544 | Val IoU : 0.6235
# Epoch 99/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 99/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.37it/s]
# Epoch 99/100
# Train Loss: 0.0597 | Val Loss: 0.1866
# Train Dice: 0.8847 | Val Dice: 0.7313
# Train IoU : 0.8605 | Val IoU : 0.6244
# Epoch 100/100 [Train]: 100%|██████████| 65/65 [00:23<00:00,  2.76it/s]
# Epoch 100/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.41it/s]
# Epoch 100/100
# Train Loss: 0.0591 | Val Loss: 0.1846
# Train Dice: 0.8870 | Val Dice: 0.7321
# Train IoU : 0.8615 | Val IoU : 0.6271
#
# ============================================================
# Training Completed!
# Best Epoch: 45
# Best Val Loss: 0.1660
# ============================================================
# Loading best model...
# Evaluating on test set...
# Evaluating Test Set: 100%|██████████| 9/9 [00:03<00:00,  2.28it/s]
# ========================================
# TEST SET EVALUATION
# ========================================
# Dice Coefficient: 0.8239
# IoU (Jaccard):    0.7145
# ========================================
