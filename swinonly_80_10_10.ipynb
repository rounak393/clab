# %% [markdown]
# <a href="https://colab.research.google.com/github/rounak393/clab/blob/main/swinonly_80_10_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install albumentations scikit-learn timm torchinfo -q

import os
import math
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import random
import copy

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import albumentations as A
import cv2
import warnings
import torch.nn.functional as F
from torchinfo import summary
import timm

warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

BASE_DIR = "/kaggle/input/datasets/britikak/busi-dataset/Dataset_BUSI_with_GT"
CLASSES = ["benign", "malignant"]
IMG_SIZE = 256
BATCH_SIZE = 8
SEED = 42

torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = True

class BUSISegmentationDataset(Dataset):
    def __init__(self, base_dir, classes, transform=None):
        self.samples = []
        self.transform = transform

        for cls in classes:
            cls_dir = os.path.join(base_dir, cls)
            if not os.path.exists(cls_dir):
                continue

            images = [
                f for f in os.listdir(cls_dir)
                if f.endswith(".png") and "_mask" not in f
            ]

            for img_name in images:
                img_path = os.path.join(cls_dir, img_name)
                base_name = img_name.replace(".png", "")

                mask_files = [
                    f for f in os.listdir(cls_dir)
                    if f.startswith(base_name + "_mask") and f.endswith(".png")
                ]

                if len(mask_files) == 0:
                    continue

                mask_paths = [os.path.join(cls_dir, f) for f in mask_files]
                self.samples.append((img_path, mask_paths))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, mask_paths = self.samples[idx]

        image = np.array(Image.open(img_path).convert("RGB"))

        combined_mask = np.zeros(image.shape[:2], dtype=np.uint8)
        for mpath in mask_paths:
            mask = np.array(Image.open(mpath).convert("L"))
            mask = (mask > 0).astype(np.uint8)
            combined_mask = np.logical_or(combined_mask, mask)

        combined_mask = combined_mask.astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=combined_mask)
            image = augmented["image"]
            combined_mask = augmented["mask"]

        combined_mask = (combined_mask > 0.5).astype(np.float32)
        image = torch.from_numpy(image).permute(2, 0, 1).float()
        mask = torch.from_numpy(combined_mask).unsqueeze(0).float()

        return image, mask

# ===================---------------------=======================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0)
])

test_transform = val_transform

# ===================------------------------==================
full_dataset = BUSISegmentationDataset(BASE_DIR, classes=CLASSES, transform=None)
total_size = len(full_dataset)
indices = list(range(total_size))
np.random.seed(SEED)
np.random.shuffle(indices)

train_size = int(0.8 * total_size)
val_size   = int(0.1 * total_size)

val_indices = indices[:val_size]
train_indices   = indices[val_size:train_size + val_size]
test_indices  = indices[train_size + val_size:]

train_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=train_transform),
    train_indices)

val_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=val_transform),
    val_indices)

test_dataset = torch.utils.data.Subset(
    BUSISegmentationDataset(BASE_DIR, CLASSES, transform=test_transform),
    test_indices)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

# ==========================================
# CUSTOM MODULES
# ==========================================
class PCBAM_Filter(nn.Module):
    def __init__(self, in_channels, reduction=8):
        super().__init__()
        self.cam = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels)
        )
        self.sam = nn.Conv2d(2, 1, kernel_size=7, padding=3, bias=False)

    def forward(self, x):
        b, c, _, _ = x.size()
        avg = self.cam(F.adaptive_avg_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        mxp = self.cam(F.adaptive_max_pool2d(x, 1).view(b, c)).view(b, c, 1, 1)
        x_c = x * torch.sigmoid(avg + mxp)

        sp  = torch.cat([
            torch.mean(x_c, dim=1, keepdim=True),
            torch.max(x_c,  dim=1, keepdim=True)[0]
        ], dim=1)
        x_s = x_c * torch.sigmoid(self.sam(sp))
        return x_s

class SpatialGateAttention(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        mid = in_channels // 8
        self.q_conv   = nn.Conv2d(in_channels, mid, 1)
        self.k_conv   = nn.Conv2d(in_channels, mid, 1)
        self.v_conv   = nn.Conv2d(in_channels, in_channels, 1)
        self.gate     = nn.Conv2d(mid * 2 + in_channels, in_channels, 1)

    def forward(self, x):
        q = self.q_conv(x)
        k = self.k_conv(x)
        v = self.v_conv(x)
        A = torch.sigmoid(self.gate(torch.cat([q, k, v], dim=1)))
        return x + v * A

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

# ==========================================
# PURE ViT U-NET ARCHITECTURE (FIXED)
# ==========================================
class PureViTUNet(nn.Module):
    def __init__(self, n_classes=1):
        super().__init__()

        # 1. Pure Transformer Encoder (Hierarchical Swin ViT)
        self.encoder = timm.create_model('swinv2_tiny_window8_256', pretrained=True, features_only=True)

        # Swin-Tiny outputs channels: 96, 192, 384, 768
        self.pcbam1 = PCBAM_Filter(96)
        self.pcbam2 = PCBAM_Filter(192)
        self.pcbam3 = PCBAM_Filter(384)
        self.pcbam4 = PCBAM_Filter(768)

        self.pool       = nn.MaxPool2d(2) # 8x8 -> 4x4
        self.bottleneck = DoubleConv(768, 1024)
        self.sga        = SpatialGateAttention(1024)

        # 2. Decoder
        self.up4  = nn.ConvTranspose2d(1024, 512, 2, stride=2) # 4x4 -> 8x8
        self.dec4 = DoubleConv(512 + 768, 512) # Concat up4(512) + s4(768) = 1280 -> 512

        self.up3  = nn.ConvTranspose2d(512, 256, 2, stride=2) # 8x8 -> 16x16
        self.dec3 = DoubleConv(256 + 384, 256) # Concat up3(256) + s3(384) = 640 -> 256

        self.up2  = nn.ConvTranspose2d(256, 128, 2, stride=2) # 16x16 -> 32x32
        self.dec2 = DoubleConv(128 + 192, 128) # Concat up2(128) + s2(192) = 320 -> 128

        self.up1  = nn.ConvTranspose2d(128, 64, 2, stride=2) # 32x32 -> 64x64
        self.dec1 = DoubleConv(64 + 96, 64) # Concat up1(64) + s1(96) = 160 -> 64

        self.up0  = nn.ConvTranspose2d(64, 64, 2, stride=2) # 64x64 -> 128x128
        self.dec0 = DoubleConv(64, 64)

        self.up_out  = nn.ConvTranspose2d(64, 32, 2, stride=2) # 128x128 -> 256x256
        self.dec_out = DoubleConv(32, 32)

        self.final   = nn.Conv2d(32, n_classes, 1)

    def forward(self, x):
        # 1. Pure Transformer Encoder
        features = self.encoder(x)

        # FIX: Permute from [B, H, W, C] to [B, C, H, W]
        e1 = features[0].permute(0, 3, 1, 2)
        e2 = features[1].permute(0, 3, 1, 2)
        e3 = features[2].permute(0, 3, 1, 2)
        e4 = features[3].permute(0, 3, 1, 2)

        # 2. Skip connections through PCBAM
        s1 = self.pcbam1(e1)
        s2 = self.pcbam2(e2)
        s3 = self.pcbam3(e3)
        s4 = self.pcbam4(e4)

        # 3. Bottleneck with SGA
        b = self.sga(self.bottleneck(self.pool(e4)))

        # 4. Decoder
        d4 = self.dec4(torch.cat([self.up4(b),  s4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), s3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), s2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), s1], dim=1))

        d0  = self.dec0(self.up0(d1))
        out = self.dec_out(self.up_out(d0))

        # RETURNS RAW LOGITS (Required for HybridLoss)
        return self.final(out)

# ==========================================
# HYBRID LOSS & METRICS
# ==========================================
class HybridLoss(nn.Module):
    def __init__(self, smooth=1.0, focal_gamma=2.0):
        super().__init__()
        self.smooth      = smooth
        self.focal_gamma = focal_gamma

    def forward(self, logits, targets):
        bce   = F.binary_cross_entropy_with_logits(logits, targets)
        probs = torch.sigmoid(logits).view(-1)
        tgt   = targets.view(-1)
        inter = (probs * tgt).sum()
        dice  = 1.0 - (2.0 * inter + self.smooth) / (probs.sum() + tgt.sum() + self.smooth)
        pt    = torch.where(tgt == 1, probs, 1.0 - probs)
        focal = (-(1.0 - pt) ** self.focal_gamma * torch.log(pt + 1e-8)).mean()
        return 0.4 * bce + 0.4 * dice + 0.2 * focal

# Dice Metric
def dice_coef(y_true, y_pred, smooth=1e-5):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    inter = (y_true_f * y_pred_f).sum()
    return (2. * inter + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

# IoU Metric
def iou_score(preds, masks, threshold=0.5, eps=1e-6):
    preds_bin = (preds > threshold).float()
    masks_bin = (masks > threshold).float()

    inter = (preds_bin * masks_bin).sum().item()
    union = preds_bin.sum().item() + masks_bin.sum().item() - inter

    return inter / (union + eps)

# ==========================================
# TRAINING FUNCTION
# ==========================================
def train_model(model, train_loader, val_loader, epochs=50):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)

    criterion = HybridLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',          # because we monitor val_loss
        factor=0.5,          # reduce LR by half
        patience=10,         # wait 10 epochs before reducing,
        min_lr=1e-6
    )

    train_losses, val_losses = [], []
    train_dice_scores, val_dice_scores = [], []
    train_iou_scores, val_iou_scores = [], []

    best_val_loss = float("inf")
    best_epoch = 0
    best_model_weights = None

    for epoch in range(epochs):
        model.train()
        train_loss = train_dice = train_iou = 0
        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs} [Train]"):
            images, masks = images.to(device), masks.to(device)

            # Outputs Logits
            preds_logits = model(images)
            loss = criterion(preds_logits, masks)

            optimizer.zero_grad()
            loss.backward()

            # Gradient clipping to prevent inf loss
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

            # Convert logits to probabilities for metric calculation
            preds_probs = torch.sigmoid(preds_logits)

            train_loss += loss.item()
            train_dice += dice_coef(masks, preds_probs).item()
            train_iou += iou_score(preds_probs, masks)

        # ------------------ VALIDATION ------------------
        model.eval()
        val_loss = val_dice = val_iou = 0

        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc=f"Epoch {epoch+1}/{epochs} [Val]"):
                images, masks = images.to(device), masks.to(device)

                preds_logits = model(images)
                loss = criterion(preds_logits, masks)

                preds_probs = torch.sigmoid(preds_logits)

                val_loss += loss.item()
                val_dice += dice_coef(masks, preds_probs).item()
                val_iou += iou_score(preds_probs, masks)

        # ------------------ AVERAGES ------------------
        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        avg_train_dice = train_dice / len(train_loader)
        avg_val_dice   = val_dice / len(val_loader)
        avg_train_iou  = train_iou / len(train_loader)
        avg_val_iou    = val_iou / len(val_loader)

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_dice_scores.append(avg_train_dice)
        val_dice_scores.append(avg_val_dice)
        train_iou_scores.append(avg_train_iou)
        val_iou_scores.append(avg_val_iou)

        # ------------------ PRINT ------------------
        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
        print(f"Train Dice: {avg_train_dice:.4f} | Val Dice: {avg_val_dice:.4f}")
        print(f"Train IoU : {avg_train_iou:.4f} | Val IoU : {avg_val_iou:.4f}")

        # ------------------ SAVE BEST ------------------
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch + 1
            best_model_weights = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), "best_pure_vit_unet.pth")
            print(f"✓ Best model saved (Epoch {epoch+1}, Val Loss {best_val_loss:.4f})")

        scheduler.step(avg_val_loss)

    # ------------------ LOAD BEST MODEL ------------------
    model.load_state_dict(best_model_weights)

    print("\n" + "="*60)
    print("Training Completed!")
    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val Loss: {best_val_loss:.4f}")
    print("="*60)

    return {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "train_dice": train_dice_scores,
        "val_dice": val_dice_scores,
        "train_iou": train_iou_scores,
        "val_iou": val_iou_scores,
    }

def plot_training(history):
    plt.figure(figsize=(17, 4))

    # Loss
    plt.subplot(1, 3, 1)
    plt.plot(history["train_losses"], label="Train Loss", linewidth=2)
    plt.plot(history["val_losses"], label="Val Loss", linewidth=2)
    plt.title("Loss Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Dice
    plt.subplot(1, 3, 2)
    plt.plot(history["train_dice"], label="Train Dice", linewidth=2)
    plt.plot(history["val_dice"], label="Val Dice", linewidth=2)
    plt.title("Dice Coefficient Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(history["train_iou"], label="Train IoU", linewidth=2)
    plt.plot(history["val_iou"], label="Val IoU", linewidth=2)
    plt.title("IoU Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch")
    plt.ylabel("IoU Score")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=300, bbox_inches='tight')
    plt.show()

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    model = PureViTUNet()
    model = model.to(device)

    print("\n================= MODEL SUMMARY =================\n")
    print(summary(model, input_size=(BATCH_SIZE, 3, IMG_SIZE, IMG_SIZE)))

    history = train_model(model, train_loader, val_loader, epochs=100)
    plot_training(history)

    def iou_coef(y_true, y_pred, smooth=1e-5):
        y_true_f = y_true.view(-1)
        y_pred_f = y_pred.view(-1)
        intersection = (y_true_f * y_pred_f).sum()
        union = y_true_f.sum() + y_pred_f.sum() - intersection
        return (intersection + smooth) / (union + smooth)

    print("Loading best model...")
    model.load_state_dict(torch.load("best_pure_vit_unet.pth", map_location=device))
    model.eval()

    test_dice, test_iou = 0, 0
    print("Evaluating on test set...")
    with torch.no_grad():
        for images, masks in tqdm(test_loader, desc="Evaluating Test Set"):
            images, masks = images.to(device), masks.to(device)

            # Use SIGMOID for raw logits output
            preds_probs = torch.sigmoid(model(images))
            preds_bin = (preds_probs > 0.4).float()

            test_dice += dice_coef(masks, preds_bin).item()
            test_iou += iou_coef(masks, preds_bin).item()

    num_batches = len(test_loader)
    avg_test_dice = test_dice / num_batches
    avg_test_iou = test_iou / num_batches

    print("\n" + "="*40)
    print("TEST SET EVALUATION")
    print("="*40)
    print(f"Dice Coefficient: {avg_test_dice:.4f}")
    print(f"IoU (Jaccard):    {avg_test_iou:.4f}")
    print("="*40)

    def dice_coef_single(y_true, y_pred, smooth=1e-5):
        y_true_f = y_true.flatten()
        y_pred_f = y_pred.flatten()
        intersection = np.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

    def iou_coef_single(y_true, y_pred, smooth=1e-5):
        intersection = np.sum(y_true * y_pred)
        union = np.sum(y_true) + np.sum(y_pred) - intersection
        return intersection / (union + smooth)

    def visualize_predictions_simple(model, dataset, num_samples=5, threshold=0.5):
        indices = random.sample(range(len(dataset)), num_samples)
        fig, axes = plt.subplots(num_samples, 4, figsize=(16, num_samples * 4))

        if num_samples == 1:
            axes = axes.reshape(1, -1)

        for i, idx in enumerate(indices):
            image, mask = dataset[idx]

            with torch.no_grad():
                pred_prob = torch.sigmoid(model(image.unsqueeze(0).to(device))).cpu().squeeze().numpy()

            pred_mask = (pred_prob > threshold).astype(np.uint8)
            true_mask = mask.squeeze().numpy().astype(np.uint8)

            dice_score = dice_coef_single(true_mask, pred_mask) * 100
            iou_score = iou_coef_single(true_mask, pred_mask) * 100

            error_map = np.zeros((*true_mask.shape, 3), dtype=np.uint8)
            true_positive = (true_mask == 1) & (pred_mask == 1)
            false_positive = (true_mask == 0) & (pred_mask == 1)
            false_negative = (true_mask == 1) & (pred_mask == 0)

            error_map[true_positive] = [255, 255, 255]
            error_map[false_positive] = [255, 0, 0]
            error_map[false_negative] = [0, 0, 255]

            axes[i, 0].imshow(image.permute(1, 2, 0) if image.shape[0] == 3 else image.squeeze(), cmap='gray')
            axes[i, 0].set_title(f"Input Image {idx}")
            axes[i, 0].axis("off")

            axes[i, 1].imshow(true_mask, cmap="gray")
            axes[i, 1].set_title("Ground Truth")
            axes[i, 1].axis("off")

            axes[i, 2].imshow(pred_mask, cmap="gray")
            axes[i, 2].set_title(f"Prediction\nDice: {dice_score:.1f}% | IoU: {iou_score:.1f}%")
            axes[i, 2].axis("off")

            axes[i, 3].imshow(error_map)
            axes[i, 3].set_title("Error Analysis\n(Red: FP, Blue: FN)")
            axes[i, 3].axis("off")

            if i == 0:
                from matplotlib.patches import Patch
                legend_elements = [
                    Patch(facecolor='white', label='True Positive'),
                    Patch(facecolor='red', label='False Positive'),
                    Patch(facecolor='blue', label='False Negative')
                ]
                axes[i, 3].legend(handles=legend_elements, loc='upper right', fontsize=8)

        plt.tight_layout()
        plt.show()

        return indices

    print("\nGenerating visualizations...")
    sampled_indices = visualize_predictions_simple(model, test_dataset, num_samples=7)
    print("\nEvaluation completed successfully!")
# Out:
# Using device: cuda
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ================= MODEL SUMMARY =================
#
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# PureViTUNet                                        [8, 1, 256, 256]          --
# ├─FeatureListNet: 1-1                              [8, 64, 64, 96]           --
# │    └─PatchEmbed: 2-1                             [8, 64, 64, 96]           --
# │    │    └─Conv2d: 3-1                            [8, 96, 64, 64]           4,704
# │    │    └─LayerNorm: 3-2                         [8, 64, 64, 96]           192
# │    └─SwinTransformerV2Stage: 2-2                 [8, 64, 64, 96]           --
# │    │    └─Identity: 3-3                          [8, 64, 64, 96]           --
# │    │    └─ModuleList: 3-4                        --                        229,638
# │    └─SwinTransformerV2Stage: 2-3                 [8, 32, 32, 192]          --
# │    │    └─PatchMerging: 3-5                      [8, 32, 32, 192]          74,112
# │    │    └─ModuleList: 3-6                        --                        898,572
# │    └─SwinTransformerV2Stage: 2-4                 [8, 16, 16, 384]          --
# │    │    └─PatchMerging: 3-7                      [8, 16, 16, 384]          295,680
# │    │    └─ModuleList: 3-8                        --                        10,690,632
# │    └─SwinTransformerV2Stage: 2-5                 [8, 8, 8, 768]            --
# │    │    └─PatchMerging: 3-9                      [8, 8, 8, 768]            1,181,184
# │    │    └─ModuleList: 3-10                       --                        14,201,904
# ├─PCBAM_Filter: 1-2                                [8, 96, 64, 64]           --
# │    └─Sequential: 2-6                             [8, 96]                   --
# │    │    └─Linear: 3-11                           [8, 12]                   1,164
# │    │    └─ReLU: 3-12                             [8, 12]                   --
# │    │    └─Linear: 3-13                           [8, 96]                   1,248
# │    └─Sequential: 2-7                             [8, 96]                   (recursive)
# │    │    └─Linear: 3-14                           [8, 12]                   (recursive)
# │    │    └─ReLU: 3-15                             [8, 12]                   --
# │    │    └─Linear: 3-16                           [8, 96]                   (recursive)
# │    └─Conv2d: 2-8                                 [8, 1, 64, 64]            98
# ├─PCBAM_Filter: 1-3                                [8, 192, 32, 32]          --
# │    └─Sequential: 2-9                             [8, 192]                  --
# │    │    └─Linear: 3-17                           [8, 24]                   4,632
# │    │    └─ReLU: 3-18                             [8, 24]                   --
# │    │    └─Linear: 3-19                           [8, 192]                  4,800
# │    └─Sequential: 2-10                            [8, 192]                  (recursive)
# │    │    └─Linear: 3-20                           [8, 24]                   (recursive)
# │    │    └─ReLU: 3-21                             [8, 24]                   --
# │    │    └─Linear: 3-22                           [8, 192]                  (recursive)
# │    └─Conv2d: 2-11                                [8, 1, 32, 32]            98
# ├─PCBAM_Filter: 1-4                                [8, 384, 16, 16]          --
# │    └─Sequential: 2-12                            [8, 384]                  --
# │    │    └─Linear: 3-23                           [8, 48]                   18,480
# │    │    └─ReLU: 3-24                             [8, 48]                   --
# │    │    └─Linear: 3-25                           [8, 384]                  18,816
# │    └─Sequential: 2-13                            [8, 384]                  (recursive)
# │    │    └─Linear: 3-26                           [8, 48]                   (recursive)
# │    │    └─ReLU: 3-27                             [8, 48]                   --
# │    │    └─Linear: 3-28                           [8, 384]                  (recursive)
# │    └─Conv2d: 2-14                                [8, 1, 16, 16]            98
# ├─PCBAM_Filter: 1-5                                [8, 768, 8, 8]            --
# │    └─Sequential: 2-15                            [8, 768]                  --
# │    │    └─Linear: 3-29                           [8, 96]                   73,824
# │    │    └─ReLU: 3-30                             [8, 96]                   --
# │    │    └─Linear: 3-31                           [8, 768]                  74,496
# │    └─Sequential: 2-16                            [8, 768]                  (recursive)
# │    │    └─Linear: 3-32                           [8, 96]                   (recursive)
# │    │    └─ReLU: 3-33                             [8, 96]                   --
# │    │    └─Linear: 3-34                           [8, 768]                  (recursive)
# │    └─Conv2d: 2-17                                [8, 1, 8, 8]              98
# ├─MaxPool2d: 1-6                                   [8, 768, 4, 4]            --
# ├─DoubleConv: 1-7                                  [8, 1024, 4, 4]           --
# │    └─Sequential: 2-18                            [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-35                           [8, 1024, 4, 4]           7,077,888
# │    │    └─BatchNorm2d: 3-36                      [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-37                             [8, 1024, 4, 4]           --
# │    │    └─Conv2d: 3-38                           [8, 1024, 4, 4]           9,437,184
# │    │    └─BatchNorm2d: 3-39                      [8, 1024, 4, 4]           2,048
# │    │    └─ReLU: 3-40                             [8, 1024, 4, 4]           --
# ├─SpatialGateAttention: 1-8                        [8, 1024, 4, 4]           --
# │    └─Conv2d: 2-19                                [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-20                                [8, 128, 4, 4]            131,200
# │    └─Conv2d: 2-21                                [8, 1024, 4, 4]           1,049,600
# │    └─Conv2d: 2-22                                [8, 1024, 4, 4]           1,311,744
# ├─ConvTranspose2d: 1-9                             [8, 512, 8, 8]            2,097,664
# ├─DoubleConv: 1-10                                 [8, 512, 8, 8]            --
# │    └─Sequential: 2-23                            [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-41                           [8, 512, 8, 8]            5,898,240
# │    │    └─BatchNorm2d: 3-42                      [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-43                             [8, 512, 8, 8]            --
# │    │    └─Conv2d: 3-44                           [8, 512, 8, 8]            2,359,296
# │    │    └─BatchNorm2d: 3-45                      [8, 512, 8, 8]            1,024
# │    │    └─ReLU: 3-46                             [8, 512, 8, 8]            --
# ├─ConvTranspose2d: 1-11                            [8, 256, 16, 16]          524,544
# ├─DoubleConv: 1-12                                 [8, 256, 16, 16]          --
# │    └─Sequential: 2-24                            [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-47                           [8, 256, 16, 16]          1,474,560
# │    │    └─BatchNorm2d: 3-48                      [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-49                             [8, 256, 16, 16]          --
# │    │    └─Conv2d: 3-50                           [8, 256, 16, 16]          589,824
# │    │    └─BatchNorm2d: 3-51                      [8, 256, 16, 16]          512
# │    │    └─ReLU: 3-52                             [8, 256, 16, 16]          --
# ├─ConvTranspose2d: 1-13                            [8, 128, 32, 32]          131,200
# ├─DoubleConv: 1-14                                 [8, 128, 32, 32]          --
# │    └─Sequential: 2-25                            [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-53                           [8, 128, 32, 32]          368,640
# │    │    └─BatchNorm2d: 3-54                      [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-55                             [8, 128, 32, 32]          --
# │    │    └─Conv2d: 3-56                           [8, 128, 32, 32]          147,456
# │    │    └─BatchNorm2d: 3-57                      [8, 128, 32, 32]          256
# │    │    └─ReLU: 3-58                             [8, 128, 32, 32]          --
# ├─ConvTranspose2d: 1-15                            [8, 64, 64, 64]           32,832
# ├─DoubleConv: 1-16                                 [8, 64, 64, 64]           --
# │    └─Sequential: 2-26                            [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-59                           [8, 64, 64, 64]           92,160
# │    │    └─BatchNorm2d: 3-60                      [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-61                             [8, 64, 64, 64]           --
# │    │    └─Conv2d: 3-62                           [8, 64, 64, 64]           36,864
# │    │    └─BatchNorm2d: 3-63                      [8, 64, 64, 64]           128
# │    │    └─ReLU: 3-64                             [8, 64, 64, 64]           --
# ├─ConvTranspose2d: 1-17                            [8, 64, 128, 128]         16,448
# ├─DoubleConv: 1-18                                 [8, 64, 128, 128]         --
# │    └─Sequential: 2-27                            [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-65                           [8, 64, 128, 128]         36,864
# │    │    └─BatchNorm2d: 3-66                      [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-67                             [8, 64, 128, 128]         --
# │    │    └─Conv2d: 3-68                           [8, 64, 128, 128]         36,864
# │    │    └─BatchNorm2d: 3-69                      [8, 64, 128, 128]         128
# │    │    └─ReLU: 3-70                             [8, 64, 128, 128]         --
# ├─ConvTranspose2d: 1-19                            [8, 32, 256, 256]         8,224
# ├─DoubleConv: 1-20                                 [8, 32, 256, 256]         --
# │    └─Sequential: 2-28                            [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-71                           [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-72                      [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-73                             [8, 32, 256, 256]         --
# │    │    └─Conv2d: 3-74                           [8, 32, 256, 256]         9,216
# │    │    └─BatchNorm2d: 3-75                      [8, 32, 256, 256]         64
# │    │    └─ReLU: 3-76                             [8, 32, 256, 256]         --
# ├─Conv2d: 1-21                                     [8, 1, 256, 256]          33
# ====================================================================================================
# Total params: 60,791,751
# Trainable params: 60,791,751
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 49.84
# ====================================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 2237.20
# Params size (MB): 217.25
# Estimated Total Size (MB): 2460.75
# ====================================================================================================
# Epoch 1/100 [Train]: 100%|██████████| 65/65 [01:13<00:00,  1.12s/it]
# Epoch 1/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  5.67it/s]
# Epoch 1/100
# Train Loss: 0.5373 | Val Loss: 0.4798
# Train Dice: 0.2367 | Val Dice: 0.2987
# Train IoU : 0.3497 | Val IoU : 0.4913
# ✓ Best model saved (Epoch 1, Val Loss 0.4798)
# Epoch 2/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.32it/s]
# Epoch 2/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.81it/s]
# Epoch 2/100
# Train Loss: 0.4364 | Val Loss: 0.4231
# Train Dice: 0.3196 | Val Dice: 0.3121
# Train IoU : 0.5433 | Val IoU : 0.5243
# ✓ Best model saved (Epoch 2, Val Loss 0.4231)
# Epoch 3/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.33it/s]
# Epoch 3/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.64it/s]
# Epoch 3/100
# Train Loss: 0.4118 | Val Loss: 0.4143
# Train Dice: 0.3377 | Val Dice: 0.3335
# Train IoU : 0.5671 | Val IoU : 0.5426
# ✓ Best model saved (Epoch 3, Val Loss 0.4143)
# Epoch 4/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 4/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.61it/s]
# Epoch 4/100
# Train Loss: 0.3868 | Val Loss: 0.3989
# Train Dice: 0.3695 | Val Dice: 0.3458
# Train IoU : 0.6139 | Val IoU : 0.5884
# ✓ Best model saved (Epoch 4, Val Loss 0.3989)
# Epoch 5/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 5/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.82it/s]
# Epoch 5/100
# Train Loss: 0.3665 | Val Loss: 0.3884
# Train Dice: 0.3905 | Val Dice: 0.3602
# Train IoU : 0.6493 | Val IoU : 0.5774
# ✓ Best model saved (Epoch 5, Val Loss 0.3884)
# Epoch 6/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 6/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.93it/s]
# Epoch 6/100
# Train Loss: 0.3572 | Val Loss: 0.3692
# Train Dice: 0.4013 | Val Dice: 0.3775
# Train IoU : 0.6520 | Val IoU : 0.5763
# ✓ Best model saved (Epoch 6, Val Loss 0.3692)
# Epoch 7/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.31it/s]
# Epoch 7/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.96it/s]
# Epoch 7/100
# Train Loss: 0.3351 | Val Loss: 0.3540
# Train Dice: 0.4280 | Val Dice: 0.3981
# Train IoU : 0.6877 | Val IoU : 0.6253
# ✓ Best model saved (Epoch 7, Val Loss 0.3540)
# Epoch 8/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 8/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.93it/s]
# Epoch 8/100
# Train Loss: 0.3223 | Val Loss: 0.3796
# Train Dice: 0.4441 | Val Dice: 0.4101
# Train IoU : 0.6970 | Val IoU : 0.5595
# Epoch 9/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 9/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.87it/s]
# Epoch 9/100
# Train Loss: 0.3049 | Val Loss: 0.3292
# Train Dice: 0.4684 | Val Dice: 0.4289
# Train IoU : 0.7249 | Val IoU : 0.5872
# ✓ Best model saved (Epoch 9, Val Loss 0.3292)
# Epoch 10/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 10/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.68it/s]
# Epoch 10/100
# Train Loss: 0.2961 | Val Loss: 0.3298
# Train Dice: 0.4810 | Val Dice: 0.4344
# Train IoU : 0.7197 | Val IoU : 0.6070
# Epoch 11/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 11/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.42it/s]
# Epoch 11/100
# Train Loss: 0.2816 | Val Loss: 0.3152
# Train Dice: 0.4991 | Val Dice: 0.4705
# Train IoU : 0.7318 | Val IoU : 0.6178
# ✓ Best model saved (Epoch 11, Val Loss 0.3152)
# Epoch 12/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 12/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.75it/s]
# Epoch 12/100
# Train Loss: 0.2739 | Val Loss: 0.3143
# Train Dice: 0.5125 | Val Dice: 0.4635
# Train IoU : 0.7243 | Val IoU : 0.6168
# ✓ Best model saved (Epoch 12, Val Loss 0.3143)
# Epoch 13/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 13/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.91it/s]
# Epoch 13/100
# Train Loss: 0.2576 | Val Loss: 0.3122
# Train Dice: 0.5345 | Val Dice: 0.4611
# Train IoU : 0.7487 | Val IoU : 0.6105
# ✓ Best model saved (Epoch 13, Val Loss 0.3122)
# Epoch 14/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 14/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.90it/s]
# Epoch 14/100
# Train Loss: 0.2473 | Val Loss: 0.2783
# Train Dice: 0.5500 | Val Dice: 0.5026
# Train IoU : 0.7621 | Val IoU : 0.6196
# ✓ Best model saved (Epoch 14, Val Loss 0.2783)
# Epoch 15/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 15/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.90it/s]
# Epoch 15/100
# Train Loss: 0.2415 | Val Loss: 0.2788
# Train Dice: 0.5598 | Val Dice: 0.5260
# Train IoU : 0.7528 | Val IoU : 0.6294
# Epoch 16/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 16/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.81it/s]
# Epoch 16/100
# Train Loss: 0.2274 | Val Loss: 0.2793
# Train Dice: 0.5851 | Val Dice: 0.5154
# Train IoU : 0.7668 | Val IoU : 0.6284
# Epoch 17/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 17/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.85it/s]
# Epoch 17/100
# Train Loss: 0.2216 | Val Loss: 0.2701
# Train Dice: 0.5957 | Val Dice: 0.5391
# Train IoU : 0.7642 | Val IoU : 0.6338
# ✓ Best model saved (Epoch 17, Val Loss 0.2701)
# Epoch 18/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 18/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.77it/s]
# Epoch 18/100
# Train Loss: 0.2053 | Val Loss: 0.2706
# Train Dice: 0.6208 | Val Dice: 0.5194
# Train IoU : 0.7878 | Val IoU : 0.6038
# Epoch 19/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 19/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.83it/s]
# Epoch 19/100
# Train Loss: 0.1967 | Val Loss: 0.2609
# Train Dice: 0.6354 | Val Dice: 0.5406
# Train IoU : 0.7853 | Val IoU : 0.6050
# ✓ Best model saved (Epoch 19, Val Loss 0.2609)
# Epoch 20/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 20/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.63it/s]
# Epoch 20/100
# Train Loss: 0.1905 | Val Loss: 0.2860
# Train Dice: 0.6485 | Val Dice: 0.5384
# Train IoU : 0.7824 | Val IoU : 0.5835
# Epoch 21/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 21/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.67it/s]
# Epoch 21/100
# Train Loss: 0.1828 | Val Loss: 0.2394
# Train Dice: 0.6607 | Val Dice: 0.5753
# Train IoU : 0.7924 | Val IoU : 0.6369
# ✓ Best model saved (Epoch 21, Val Loss 0.2394)
# Epoch 22/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 22/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.78it/s]
# Epoch 22/100
# Train Loss: 0.1755 | Val Loss: 0.2357
# Train Dice: 0.6764 | Val Dice: 0.5978
# Train IoU : 0.7912 | Val IoU : 0.6258
# ✓ Best model saved (Epoch 22, Val Loss 0.2357)
# Epoch 23/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.27it/s]
# Epoch 23/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.79it/s]
# Epoch 23/100
# Train Loss: 0.1599 | Val Loss: 0.2673
# Train Dice: 0.7035 | Val Dice: 0.5811
# Train IoU : 0.8158 | Val IoU : 0.5873
# Epoch 24/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 24/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.88it/s]
# Epoch 24/100
# Train Loss: 0.1587 | Val Loss: 0.2236
# Train Dice: 0.7055 | Val Dice: 0.6227
# Train IoU : 0.8109 | Val IoU : 0.6428
# ✓ Best model saved (Epoch 24, Val Loss 0.2236)
# Epoch 25/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 25/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.58it/s]
# Epoch 25/100
# Train Loss: 0.1488 | Val Loss: 0.2183
# Train Dice: 0.7234 | Val Dice: 0.6243
# Train IoU : 0.8265 | Val IoU : 0.6378
# ✓ Best model saved (Epoch 25, Val Loss 0.2183)
# Epoch 26/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 26/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.90it/s]
# Epoch 26/100
# Train Loss: 0.1367 | Val Loss: 0.2130
# Train Dice: 0.7447 | Val Dice: 0.6403
# Train IoU : 0.8348 | Val IoU : 0.6425
# ✓ Best model saved (Epoch 26, Val Loss 0.2130)
# Epoch 27/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 27/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.90it/s]
# Epoch 27/100
# Train Loss: 0.1394 | Val Loss: 0.2280
# Train Dice: 0.7437 | Val Dice: 0.6085
# Train IoU : 0.8184 | Val IoU : 0.6109
# Epoch 28/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 28/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.83it/s]
# Epoch 28/100
# Train Loss: 0.1332 | Val Loss: 0.1824
# Train Dice: 0.7529 | Val Dice: 0.6828
# Train IoU : 0.8262 | Val IoU : 0.6964
# ✓ Best model saved (Epoch 28, Val Loss 0.1824)
# Epoch 29/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 29/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.80it/s]
# Epoch 29/100
# Train Loss: 0.1268 | Val Loss: 0.1736
# Train Dice: 0.7677 | Val Dice: 0.6973
# Train IoU : 0.8304 | Val IoU : 0.6974
# ✓ Best model saved (Epoch 29, Val Loss 0.1736)
# Epoch 30/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 30/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.72it/s]
# Epoch 30/100
# Train Loss: 0.1238 | Val Loss: 0.1732
# Train Dice: 0.7742 | Val Dice: 0.7016
# Train IoU : 0.8232 | Val IoU : 0.6972
# ✓ Best model saved (Epoch 30, Val Loss 0.1732)
# Epoch 31/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 31/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.88it/s]
# Epoch 31/100
# Train Loss: 0.1190 | Val Loss: 0.1782
# Train Dice: 0.7818 | Val Dice: 0.6954
# Train IoU : 0.8327 | Val IoU : 0.6872
# Epoch 32/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 32/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.73it/s]
# Epoch 32/100
# Train Loss: 0.1161 | Val Loss: 0.1832
# Train Dice: 0.7900 | Val Dice: 0.7106
# Train IoU : 0.8341 | Val IoU : 0.6843
# Epoch 33/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 33/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.89it/s]
# Epoch 33/100
# Train Loss: 0.1059 | Val Loss: 0.2130
# Train Dice: 0.8087 | Val Dice: 0.6647
# Train IoU : 0.8448 | Val IoU : 0.6271
# Epoch 34/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 34/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.66it/s]
# Epoch 34/100
# Train Loss: 0.1089 | Val Loss: 0.2004
# Train Dice: 0.8022 | Val Dice: 0.6940
# Train IoU : 0.8376 | Val IoU : 0.6412
# Epoch 35/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 35/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.98it/s]
# Epoch 35/100
# Train Loss: 0.1063 | Val Loss: 0.1669
# Train Dice: 0.8104 | Val Dice: 0.7159
# Train IoU : 0.8373 | Val IoU : 0.6927
# ✓ Best model saved (Epoch 35, Val Loss 0.1669)
# Epoch 36/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 36/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.83it/s]
# Epoch 36/100
# Train Loss: 0.0966 | Val Loss: 0.1954
# Train Dice: 0.8251 | Val Dice: 0.6985
# Train IoU : 0.8488 | Val IoU : 0.6355
# Epoch 37/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 37/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.93it/s]
# Epoch 37/100
# Train Loss: 0.0951 | Val Loss: 0.1605
# Train Dice: 0.8293 | Val Dice: 0.7354
# Train IoU : 0.8532 | Val IoU : 0.6875
# ✓ Best model saved (Epoch 37, Val Loss 0.1605)
# Epoch 38/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 38/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.54it/s]
# Epoch 38/100
# Train Loss: 0.0950 | Val Loss: 0.1751
# Train Dice: 0.8295 | Val Dice: 0.7287
# Train IoU : 0.8493 | Val IoU : 0.6595
# Epoch 39/100 [Train]: 100%|██████████| 65/65 [00:20<00:00,  3.24it/s]
# Epoch 39/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.85it/s]
# Epoch 39/100
# Train Loss: 0.0864 | Val Loss: 0.2131
# Train Dice: 0.8448 | Val Dice: 0.6847
# Train IoU : 0.8608 | Val IoU : 0.6185
# Epoch 40/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 40/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.66it/s]
# Epoch 40/100
# Train Loss: 0.0838 | Val Loss: 0.1836
# Train Dice: 0.8500 | Val Dice: 0.7169
# Train IoU : 0.8615 | Val IoU : 0.6532
# Epoch 41/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 41/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.86it/s]
# Epoch 41/100
# Train Loss: 0.0846 | Val Loss: 0.1510
# Train Dice: 0.8487 | Val Dice: 0.7515
# Train IoU : 0.8583 | Val IoU : 0.7049
# ✓ Best model saved (Epoch 41, Val Loss 0.1510)
# Epoch 42/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 42/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.85it/s]
# Epoch 42/100
# Train Loss: 0.0825 | Val Loss: 0.1750
# Train Dice: 0.8536 | Val Dice: 0.7297
# Train IoU : 0.8581 | Val IoU : 0.6560
# Epoch 43/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 43/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.80it/s]
# Epoch 43/100
# Train Loss: 0.0806 | Val Loss: 0.1721
# Train Dice: 0.8573 | Val Dice: 0.7396
# Train IoU : 0.8603 | Val IoU : 0.6634
# Epoch 44/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 44/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.70it/s]
# Epoch 44/100
# Train Loss: 0.0786 | Val Loss: 0.1621
# Train Dice: 0.8619 | Val Dice: 0.7439
# Train IoU : 0.8635 | Val IoU : 0.6753
# Epoch 45/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 45/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.78it/s]
# Epoch 45/100
# Train Loss: 0.0776 | Val Loss: 0.1814
# Train Dice: 0.8656 | Val Dice: 0.7218
# Train IoU : 0.8628 | Val IoU : 0.6437
# Epoch 46/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 46/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.97it/s]
# Epoch 46/100
# Train Loss: 0.0704 | Val Loss: 0.1765
# Train Dice: 0.8762 | Val Dice: 0.7349
# Train IoU : 0.8756 | Val IoU : 0.6505
# Epoch 47/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 47/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.83it/s]
# Epoch 47/100
# Train Loss: 0.0719 | Val Loss: 0.1864
# Train Dice: 0.8734 | Val Dice: 0.7330
# Train IoU : 0.8715 | Val IoU : 0.6424
# Epoch 48/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 48/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.81it/s]
# Epoch 48/100
# Train Loss: 0.0725 | Val Loss: 0.1674
# Train Dice: 0.8755 | Val Dice: 0.7507
# Train IoU : 0.8646 | Val IoU : 0.6607
# Epoch 49/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 49/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.61it/s]
# Epoch 49/100
# Train Loss: 0.0684 | Val Loss: 0.1616
# Train Dice: 0.8829 | Val Dice: 0.7707
# Train IoU : 0.8729 | Val IoU : 0.6746
# Epoch 50/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 50/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.76it/s]
# Epoch 50/100
# Train Loss: 0.0644 | Val Loss: 0.1643
# Train Dice: 0.8879 | Val Dice: 0.7552
# Train IoU : 0.8800 | Val IoU : 0.6572
# Epoch 51/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 51/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.48it/s]
# Epoch 51/100
# Train Loss: 0.0700 | Val Loss: 0.1938
# Train Dice: 0.8814 | Val Dice: 0.7202
# Train IoU : 0.8675 | Val IoU : 0.6244
# Epoch 52/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 52/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.89it/s]
# Epoch 52/100
# Train Loss: 0.0578 | Val Loss: 0.1838
# Train Dice: 0.8984 | Val Dice: 0.7455
# Train IoU : 0.8912 | Val IoU : 0.6479
# Epoch 53/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 53/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.75it/s]
# Epoch 53/100
# Train Loss: 0.0599 | Val Loss: 0.1593
# Train Dice: 0.8959 | Val Dice: 0.7652
# Train IoU : 0.8853 | Val IoU : 0.6722
# Epoch 54/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 54/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.56it/s]
# Epoch 54/100
# Train Loss: 0.0533 | Val Loss: 0.1664
# Train Dice: 0.9056 | Val Dice: 0.7571
# Train IoU : 0.8995 | Val IoU : 0.6641
# Epoch 55/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 55/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.80it/s]
# Epoch 55/100
# Train Loss: 0.0559 | Val Loss: 0.1737
# Train Dice: 0.9028 | Val Dice: 0.7552
# Train IoU : 0.8944 | Val IoU : 0.6597
# Epoch 56/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 56/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.78it/s]
# Epoch 56/100
# Train Loss: 0.0516 | Val Loss: 0.1773
# Train Dice: 0.9089 | Val Dice: 0.7540
# Train IoU : 0.9027 | Val IoU : 0.6530
# Epoch 57/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 57/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.76it/s]
# Epoch 57/100
# Train Loss: 0.0525 | Val Loss: 0.1635
# Train Dice: 0.9093 | Val Dice: 0.7656
# Train IoU : 0.8997 | Val IoU : 0.6707
# Epoch 58/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 58/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.84it/s]
# Epoch 58/100
# Train Loss: 0.0512 | Val Loss: 0.1638
# Train Dice: 0.9115 | Val Dice: 0.7706
# Train IoU : 0.9008 | Val IoU : 0.6729
# Epoch 59/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 59/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.76it/s]
# Epoch 59/100
# Train Loss: 0.0494 | Val Loss: 0.1935
# Train Dice: 0.9130 | Val Dice: 0.7379
# Train IoU : 0.9049 | Val IoU : 0.6334
# Epoch 60/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 60/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.19it/s]
# Epoch 60/100
# Train Loss: 0.0513 | Val Loss: 0.1795
# Train Dice: 0.9085 | Val Dice: 0.7522
# Train IoU : 0.9017 | Val IoU : 0.6471
# Epoch 61/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 61/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.50it/s]
# Epoch 61/100
# Train Loss: 0.0481 | Val Loss: 0.1823
# Train Dice: 0.9156 | Val Dice: 0.7512
# Train IoU : 0.9065 | Val IoU : 0.6495
# Epoch 62/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 62/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.66it/s]
# Epoch 62/100
# Train Loss: 0.0491 | Val Loss: 0.1760
# Train Dice: 0.9151 | Val Dice: 0.7612
# Train IoU : 0.9050 | Val IoU : 0.6561
# Epoch 63/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 63/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.69it/s]
# Epoch 63/100
# Train Loss: 0.0492 | Val Loss: 0.1817
# Train Dice: 0.9163 | Val Dice: 0.7508
# Train IoU : 0.9045 | Val IoU : 0.6460
# Epoch 64/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 64/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.85it/s]
# Epoch 64/100
# Train Loss: 0.0465 | Val Loss: 0.1842
# Train Dice: 0.9197 | Val Dice: 0.7527
# Train IoU : 0.9102 | Val IoU : 0.6480
# Epoch 65/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 65/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.64it/s]
# Epoch 65/100
# Train Loss: 0.0435 | Val Loss: 0.1747
# Train Dice: 0.9239 | Val Dice: 0.7624
# Train IoU : 0.9153 | Val IoU : 0.6595
# Epoch 66/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 66/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.83it/s]
# Epoch 66/100
# Train Loss: 0.0443 | Val Loss: 0.1751
# Train Dice: 0.9223 | Val Dice: 0.7632
# Train IoU : 0.9147 | Val IoU : 0.6611
# Epoch 67/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 67/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.80it/s]
# Epoch 67/100
# Train Loss: 0.0425 | Val Loss: 0.1820
# Train Dice: 0.9259 | Val Dice: 0.7514
# Train IoU : 0.9165 | Val IoU : 0.6440
# Epoch 68/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 68/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.72it/s]
# Epoch 68/100
# Train Loss: 0.0437 | Val Loss: 0.1757
# Train Dice: 0.9241 | Val Dice: 0.7633
# Train IoU : 0.9136 | Val IoU : 0.6605
# Epoch 69/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 69/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.78it/s]
# Epoch 69/100
# Train Loss: 0.0428 | Val Loss: 0.1828
# Train Dice: 0.9244 | Val Dice: 0.7548
# Train IoU : 0.9186 | Val IoU : 0.6485
# Epoch 70/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 70/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.88it/s]
# Epoch 70/100
# Train Loss: 0.0463 | Val Loss: 0.1855
# Train Dice: 0.9221 | Val Dice: 0.7538
# Train IoU : 0.9075 | Val IoU : 0.6478
# Epoch 71/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 71/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.84it/s]
# Epoch 71/100
# Train Loss: 0.0413 | Val Loss: 0.1852
# Train Dice: 0.9267 | Val Dice: 0.7548
# Train IoU : 0.9188 | Val IoU : 0.6477
# Epoch 72/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 72/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.70it/s]
# Epoch 72/100
# Train Loss: 0.0425 | Val Loss: 0.1883
# Train Dice: 0.9270 | Val Dice: 0.7510
# Train IoU : 0.9162 | Val IoU : 0.6423
# Epoch 73/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 73/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.63it/s]
# Epoch 73/100
# Train Loss: 0.0408 | Val Loss: 0.1743
# Train Dice: 0.9275 | Val Dice: 0.7644
# Train IoU : 0.9193 | Val IoU : 0.6589
# Epoch 74/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 74/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.84it/s]
# Epoch 74/100
# Train Loss: 0.0411 | Val Loss: 0.1655
# Train Dice: 0.9285 | Val Dice: 0.7745
# Train IoU : 0.9191 | Val IoU : 0.6697
# Epoch 75/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 75/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.62it/s]
# Epoch 75/100
# Train Loss: 0.0390 | Val Loss: 0.1730
# Train Dice: 0.9322 | Val Dice: 0.7672
# Train IoU : 0.9239 | Val IoU : 0.6634
# Epoch 76/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 76/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.79it/s]
# Epoch 76/100
# Train Loss: 0.0358 | Val Loss: 0.1709
# Train Dice: 0.9371 | Val Dice: 0.7709
# Train IoU : 0.9297 | Val IoU : 0.6672
# Epoch 77/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 77/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.90it/s]
# Epoch 77/100
# Train Loss: 0.0380 | Val Loss: 0.1700
# Train Dice: 0.9337 | Val Dice: 0.7719
# Train IoU : 0.9254 | Val IoU : 0.6674
# Epoch 78/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 78/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.79it/s]
# Epoch 78/100
# Train Loss: 0.0367 | Val Loss: 0.1726
# Train Dice: 0.9354 | Val Dice: 0.7700
# Train IoU : 0.9275 | Val IoU : 0.6640
# Epoch 79/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 79/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.66it/s]
# Epoch 79/100
# Train Loss: 0.0376 | Val Loss: 0.1722
# Train Dice: 0.9350 | Val Dice: 0.7697
# Train IoU : 0.9256 | Val IoU : 0.6637
# Epoch 80/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 80/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.66it/s]
# Epoch 80/100
# Train Loss: 0.0369 | Val Loss: 0.1861
# Train Dice: 0.9355 | Val Dice: 0.7571
# Train IoU : 0.9270 | Val IoU : 0.6499
# Epoch 81/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 81/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.72it/s]
# Epoch 81/100
# Train Loss: 0.0385 | Val Loss: 0.1796
# Train Dice: 0.9324 | Val Dice: 0.7641
# Train IoU : 0.9240 | Val IoU : 0.6566
# Epoch 82/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 82/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.93it/s]
# Epoch 82/100
# Train Loss: 0.0387 | Val Loss: 0.1798
# Train Dice: 0.9327 | Val Dice: 0.7623
# Train IoU : 0.9223 | Val IoU : 0.6544
# Epoch 83/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 83/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.78it/s]
# Epoch 83/100
# Train Loss: 0.0369 | Val Loss: 0.1789
# Train Dice: 0.9358 | Val Dice: 0.7652
# Train IoU : 0.9260 | Val IoU : 0.6583
# Epoch 84/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 84/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.71it/s]
# Epoch 84/100
# Train Loss: 0.0350 | Val Loss: 0.1739
# Train Dice: 0.9382 | Val Dice: 0.7705
# Train IoU : 0.9317 | Val IoU : 0.6632
# Epoch 85/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 85/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.84it/s]
# Epoch 85/100
# Train Loss: 0.0358 | Val Loss: 0.1737
# Train Dice: 0.9375 | Val Dice: 0.7705
# Train IoU : 0.9292 | Val IoU : 0.6635
# Epoch 86/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 86/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.84it/s]
# Epoch 86/100
# Train Loss: 0.0353 | Val Loss: 0.1742
# Train Dice: 0.9381 | Val Dice: 0.7702
# Train IoU : 0.9303 | Val IoU : 0.6627
# Epoch 87/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 87/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.64it/s]
# Epoch 87/100
# Train Loss: 0.0360 | Val Loss: 0.1856
# Train Dice: 0.9367 | Val Dice: 0.7621
# Train IoU : 0.9278 | Val IoU : 0.6526
# Epoch 88/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.30it/s]
# Epoch 88/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.93it/s]
# Epoch 88/100
# Train Loss: 0.0349 | Val Loss: 0.1760
# Train Dice: 0.9390 | Val Dice: 0.7678
# Train IoU : 0.9311 | Val IoU : 0.6589
# Epoch 89/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 89/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.86it/s]
# Epoch 89/100
# Train Loss: 0.0360 | Val Loss: 0.1761
# Train Dice: 0.9374 | Val Dice: 0.7695
# Train IoU : 0.9278 | Val IoU : 0.6612
# Epoch 90/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 90/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.86it/s]
# Epoch 90/100
# Train Loss: 0.0361 | Val Loss: 0.1747
# Train Dice: 0.9369 | Val Dice: 0.7694
# Train IoU : 0.9287 | Val IoU : 0.6610
# Epoch 91/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 91/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.75it/s]
# Epoch 91/100
# Train Loss: 0.0355 | Val Loss: 0.1798
# Train Dice: 0.9378 | Val Dice: 0.7662
# Train IoU : 0.9303 | Val IoU : 0.6567
# Epoch 92/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 92/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.76it/s]
# Epoch 92/100
# Train Loss: 0.0358 | Val Loss: 0.1836
# Train Dice: 0.9374 | Val Dice: 0.7629
# Train IoU : 0.9298 | Val IoU : 0.6535
# Epoch 93/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 93/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.78it/s]
# Epoch 93/100
# Train Loss: 0.0360 | Val Loss: 0.1846
# Train Dice: 0.9376 | Val Dice: 0.7614
# Train IoU : 0.9277 | Val IoU : 0.6509
# Epoch 94/100 [Train]: 100%|██████████| 65/65 [00:20<00:00,  3.24it/s]
# Epoch 94/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.82it/s]
# Epoch 94/100
# Train Loss: 0.0350 | Val Loss: 0.1772
# Train Dice: 0.9372 | Val Dice: 0.7673
# Train IoU : 0.9320 | Val IoU : 0.6592
# Epoch 95/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 95/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.71it/s]
# Epoch 95/100
# Train Loss: 0.0340 | Val Loss: 0.1708
# Train Dice: 0.9402 | Val Dice: 0.7733
# Train IoU : 0.9316 | Val IoU : 0.6636
# Epoch 96/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 96/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.83it/s]
# Epoch 96/100
# Train Loss: 0.0340 | Val Loss: 0.1766
# Train Dice: 0.9411 | Val Dice: 0.7706
# Train IoU : 0.9327 | Val IoU : 0.6619
# Epoch 97/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 97/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.77it/s]
# Epoch 97/100
# Train Loss: 0.0364 | Val Loss: 0.1754
# Train Dice: 0.9365 | Val Dice: 0.7718
# Train IoU : 0.9270 | Val IoU : 0.6630
# Epoch 98/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.28it/s]
# Epoch 98/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.58it/s]
# Epoch 98/100
# Train Loss: 0.0337 | Val Loss: 0.1743
# Train Dice: 0.9408 | Val Dice: 0.7721
# Train IoU : 0.9323 | Val IoU : 0.6637
# Epoch 99/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 99/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.54it/s]
# Epoch 99/100
# Train Loss: 0.0348 | Val Loss: 0.1744
# Train Dice: 0.9394 | Val Dice: 0.7718
# Train IoU : 0.9286 | Val IoU : 0.6627
# Epoch 100/100 [Train]: 100%|██████████| 65/65 [00:19<00:00,  3.29it/s]
# Epoch 100/100 [Val]: 100%|██████████| 8/8 [00:01<00:00,  7.67it/s]
# Epoch 100/100
# Train Loss: 0.0353 | Val Loss: 0.1800
# Train Dice: 0.9380 | Val Dice: 0.7690
# Train IoU : 0.9292 | Val IoU : 0.6595
#
# ============================================================
# Training Completed!
# Best Epoch: 41
# Best Val Loss: 0.1510
# ============================================================
# Loading best model...
# Evaluating on test set...
# Evaluating Test Set: 100%|██████████| 9/9 [00:02<00:00,  3.31it/s]
# ========================================
# TEST SET EVALUATION
# ========================================
# Dice Coefficient: 0.8006
# IoU (Jaccard):    0.6879
# ========================================
#
# Generating visualizations...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.2042701].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0836544..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6399999].
# Evaluation completed successfully!
